# %% [markdown]
# Copyright (c) 2020, salesforce.com, inc.
# All rights reserved.
# SPDX-License-Identifier: BSD-3-Clause
# For full license text, see the LICENSE file in the repo root or https://opensource.org/licenses/BSD-3-Clause

# %% [markdown]
# ### Colab
#
# Try this notebook on [Colab](http://colab.research.google.com/github/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basic.ipynb).

# %% [markdown]
# # Welcome to Foundation!
#
# Foundation is the name of the economic simulator built for the AI Economist ([paper here](https://arxiv.org/abs/2004.13332)). This is the first of several tutorials designed to explain how Foundation works and how it can be used to build simulation environments for studying economic problems.
#
# Just to orient you a bit, Foundation is specially designed for modeling economies in spatial, 2D grid worlds. The AI Economist paper uses a scenario with 4 agents in a world with *Stone* and *Wood*, which can be *collected*, *traded*, and used to build *Houses*. Here's a (nicely rendered) example of what such an environment looks like:
#
# ![Foundation snapshot](assets/foundation_snapshot_rendered.jpg)
#
# This image just shows what you might see spatially. Behind the scenes, agents have inventories of Stone, Wood, and *Coin*, which they can exchange through a commodities marketplace. In addition, they periodically pay taxes on income earned through trading and building.
#
# **We've open-sourced Foundation to foster transparency and to enable others to build on it!** With that goal in mind, this first tutorial should give you enough to see how to create the type of simulation environment described above and how to interact with it. If you're interested to learn how it all works and how to build on it, make sure to check out the advanced tutorial as well! If, after that, you want to understand more about designing the simulation around economic problems, check out our tutorial explaining how the AI Economist uses Foundation to study the optimal taxation problem!

# %% [markdown]
# # Introduction
#
# In this **basic** tutorial, we will demonstrate the basics of how to create an instance of a simulation environment and how to interact with it.
#
# We will cover the following:
# 1. Markov Decision Processes
# 2. Creating a Simulation Environment (a Scenario Instance)
# 3. Interacting with the Simulation
# 4. Sampling and Visualizing an Episode

# %% [markdown]
# ## Dependencies:
# You can install the ai-economist package using
# - the pip package manager OR
# - by cloning the ai-economist package and installing the requirements (we shall use this when running on Colab):

# %%
# import os, signal, sys, time
# IN_COLAB = 'google.colab' in sys.modules

# if IN_COLAB:
#     !git clone https://github.com/salesforce/ai-economist.git

#     %cd ai-economist
#     !pip install -e .
    
#     # Restart the Python runtime to automatically use the installed packages
#     print("\n\nRestarting the Python runtime! Please (re-)run the cells below.")
#     time.sleep(1)
#     os.kill(os.getpid(), signal.SIGKILL)
# else:
#     !pip install ai-economist

# %%
# Import foundation
import os, signal, sys, time

sys.path.append(r'C:\Users\adria\coding\katja\DRL-in-international-economy-ai-economist-')

from ai_economist import foundation

# %%
# Change directory to the tutorials folder
import os, sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    os.chdir("/content/ai-economist/tutorials")
else:
    os.chdir(os.path.dirname(os.path.abspath("__file__"))
)

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython import display
from utils import plotting  # plotting utilities for visualizing env. state

# %% [markdown]
# # 1. Markov Decision Process
#
# Formally, our economic simulation is a key part of a Markov Decision Process (MDP).
#
# MDPs describe episodes in which agents interact with a stateful environment in a continuous feedback loop. At each timestep, agents receive an observation and use a policy to choose actions. The environment then advances to a new state, using the old state and the chosen actions. The agents then receive new observations and rewards. This process repeats over $T$ timesteps (possibly infinite).
#
# The goal of each agent is to maximize its expected sum of future (discounted) rewards, by finding its optimal policy. Intuitively, this means that an agent needs to understand which (sequence of) actions lead to high rewards (in expectation).
#
# ### References
#
# For more information on reinforcement learning and MDPs, check out:
#
# - Richard S. Sutton and Andrew G. Barto, Reinforcement Learning: An Introduction. [http://incompleteideas.net/book/bookdraft2017nov5.pdf](http://incompleteideas.net/book/bookdraft2017nov5.pdf)

# %% [markdown]
# # 2. Creating a Simulation Environment (a Scenario Instance)
#
# The Scenario class implements an economic simulation with multiple agents and (optionally) a social planner.
#
# Scenarios provide a high-level gym-style API that lets agents interact with it. The API supports multi-agent observations, actions, etc.
#
# Each Scenario is stateful and implements two main methods:
#
# - __step__, which advances the simulation to the next state, and
# - __reset__, which puts the simulation back in an initial state.
#
# Each Scenario is customizable: you can specify options in a dictionary. Here is an example for a scenario with 4 agents:
#
# **Note: This config dictionary will likely seem fairly incomprehensible at this point in the tutorials. Don't worry. The advanced tutorial offers much more context. This is just to get things started and to provide a reference for how to create a "free market" economy from the AI Economist.**

# %%
# Define the configuration of the environment that will be built

env_config_original = {
    # ===== SCENARIO CLASS =====
    # Which Scenario class to use: the class's name in the Scenario Registry (foundation.scenarios).
    # The environment object will be an instance of the Scenario class.
    'scenario_name': 'layout_from_file/simple_wood_and_stone',
    
    # ===== COMPONENTS =====
    # Which components to use (specified as list of ("component_name", {component_kwargs}) tuples).
    #   "component_name" refers to the Component class's name in the Component Registry (foundation.components)
    #   {component_kwargs} is a dictionary of kwargs passed to the Component class
    # The order in which components reset, step, and generate obs follows their listed order below.
    'components': [
        # (1) Building houses
        ('Build', {'skill_dist': "pareto", 'payment_max_skill_multiplier': 3}),
        # (2) Trading collectible resources
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        # (3) Movement and resource collection
        ('Gather', {}),
    ],
    
    # ===== SCENARIO CLASS ARGUMENTS =====
    # (optional) kwargs that are added by the Scenario class (i.e. not defined in BaseEnvironment)
    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': True,
    
    # ===== STANDARD ARGUMENTS ======
    # kwargs that are used by every Scenario class (i.e. defined in BaseEnvironment)
    'n_agents': 4,          # Number of non-planner agents (must be > 1)
    'world_size': [25, 25], # [Height, Width] of the env world
    'episode_length': 1000, # Number of timesteps per episode
    
    # In multi-action-mode, the policy selects an action for each action subspace (defined in component code).
    # Otherwise, the policy selects only 1 action.
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    
    # When flattening observations, concatenate scalar & vector observations before output.
    # Otherwise, return observations with minimal processing.
    'flatten_observations': False,
    # When Flattening masks, concatenate each action subspace mask into a single array.
    # Note: flatten_masks = True is required for masking action logits in the code below.
    'flatten_masks': True,
}

# %%
env_config = {
    # ===== SCENARIO CLASS =====
    'scenario_name': 'layout_from_file/simple_wood_and_stone',

    # ===== COMPONENTS =====
    'components': [
        # (1) Building houses (REQUIRES payment when using fixed_four_skill_and_loc=True)
        ('Build', {
            'payment': 10.0,                    # <-- REQUIRED for LayoutFromFile fixed_four_skill_and_loc
            'skill_dist': "pareto",             # <-- REQUIRED
            'payment_max_skill_multiplier': 3   # good
        }),
        # (2) Trading collectible resources
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        # (3) Movement and resource collection
        ('Gather', {}),
    ],

    # ===== SCENARIO CLASS ARGUMENTS =====
    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': True,  # <-- works only if Build.payment is set as above

    # ===== STANDARD ARGUMENTS ======
    'n_agents': 4,
    'world_size': [25, 25],
    'episode_length': 1000,

    # multi-action mode (optional; leaving your choices)
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,

    # flattening options (fine as-is)
    'flatten_observations': False,
    'flatten_masks': True,
}

# %% [markdown]
# ## Debugging

# %%
# Import to trigger the decorators
import ai_economist.foundation.scenarios.simple_wood_and_stone.layout_from_file
import ai_economist.foundation.scenarios.simple_wood_and_stone.dynamic_layout

from ai_economist.foundation.scenarios import scenario_registry as scen_reg
print("Entries:", scen_reg.entries)
print("Has layout_from_file? ", scen_reg.has("layout_from_file/simple_wood_and_stone"))
print("Has split_layout?     ", scen_reg.has("split_layout/simple_wood_and_stone"))
# Out:
# Entries: ['layout_from_file/simple_wood_and_stone', 'multi_zone/simple_wood_and_stone', 'quadrant/simple_wood_and_stone', 'split_layout/simple_wood_and_stone', 'uniform/simple_wood_and_stone']
# Has layout_from_file?  True
# Has split_layout?      True

# %%
import importlib, inspect, sys

# 1) Show where the ai_economist package is loaded from
import ai_economist
print("ai_economist package file:", ai_economist.__file__)

# 2) Try both likely module paths for the two scenario modules
mods_to_try = [
    "ai_economist.foundation.scenarios.layout_from_file",
    "ai_economist.foundation.scenarios.dynamic_layout",
    # If your tree actually has the subfolder as you mentioned, we can try these too:
    "ai_economist.foundation.scenarios.simple_wood_and_stone.layout_from_file",
    "ai_economist.foundation.scenarios.simple_wood_and_stone.dynamic_layout",
]

for mod in mods_to_try:
    try:
        m = importlib.import_module(mod)
        print(f"OK  : {mod:80s} -> {m.__file__}")
    except Exception as e:
        print(f"FAIL: {mod:80s} -> {type(e).__name__}: {e}")

# 3) Compare registry singletons
from ai_economist.foundation.base import base_env, base_env_original
from ai_economist.foundation.scenarios import scenario_registry as scen_reg

print("base_env registry id         :", id(base_env.scenario_registry))
print("base_env_original registry id:", id(base_env_original.scenario_registry))
print("scenarios registry id        :", id(scen_reg))

# 4) (If imports in step 2 succeeded) check which registry each module used
try:
    lff = importlib.import_module("ai_economist.foundation.scenarios.layout_from_file")
    print("layout_from_file registry id :", id(lff.scenario_registry))
except Exception: pass

try:
    dly = importlib.import_module("ai_economist.foundation.scenarios.dynamic_layout")
    print("dynamic_layout registry id   :", id(dly.scenario_registry))
except Exception: pass

# 5) List entries seen through the scenarios package registry
print("Entries:", scen_reg.entries)
print("Has layout_from_file? ", scen_reg.has("layout_from_file/simple_wood_and_stone"))
print("Has split_layout?     ", scen_reg.has("split_layout/simple_wood_and_stone"))
# Out:
# ai_economist package file: C:\Users\adria\coding\katja\DRL-in-international-economy-ai-economist-\ai_economist\__init__.py
# FAIL: ai_economist.foundation.scenarios.layout_from_file                               -> ModuleNotFoundError: No module named 'ai_economist.foundation.scenarios.layout_from_file'
# FAIL: ai_economist.foundation.scenarios.dynamic_layout                                 -> ModuleNotFoundError: No module named 'ai_economist.foundation.scenarios.dynamic_layout'
# OK  : ai_economist.foundation.scenarios.simple_wood_and_stone.layout_from_file         -> C:\Users\adria\coding\katja\DRL-in-international-economy-ai-economist-\ai_economist\foundation\scenarios\simple_wood_and_stone\layout_from_file.py
# OK  : ai_economist.foundation.scenarios.simple_wood_and_stone.dynamic_layout           -> C:\Users\adria\coding\katja\DRL-in-international-economy-ai-economist-\ai_economist\foundation\scenarios\simple_wood_and_stone\dynamic_layout.py
# base_env registry id         : 1436574725008
# base_env_original registry id: 1436574719056
# scenarios registry id        : 1436574725008
# Entries: ['layout_from_file/simple_wood_and_stone', 'multi_zone/simple_wood_and_stone', 'quadrant/simple_wood_and_stone', 'split_layout/simple_wood_and_stone', 'uniform/simple_wood_and_stone']
# Has layout_from_file?  True
# Has split_layout?      True

# %%
import ai_economist.foundation.scenarios.simple_wood_and_stone.layout_from_file
import ai_economist.foundation.scenarios.simple_wood_and_stone.dynamic_layout

from ai_economist import foundation
env = foundation.make_env_instance(**env_config)
obs = env.reset()

# %% [markdown]
# ### debug done

# %% [markdown]
# Create an environment instance using this configuration:

# %%
env = foundation.make_env_instance(**env_config)

# %% [markdown]
# # 3. Interacting with the Simulation

# %% [markdown]
# ### Agents
#
# The Agent class holds the state of agents in the simulation. Each Agent instance represents a _logical_ agent.
#
# _Note that this might be separate from a Policy model that lives outside the Scenario and controls the Agent's behavior._

# %%
env.get_agent(0)

# %% [markdown]
# ### A random policy
#
# Now let's interact with the simulation.
#
# Each Agent needs to choose which actions to execute using a __policy__.
#
# Agents might not always be allowed to execute all actions. For instance, a mobile Agent cannot move beyond the boundary of the world. Hence, in position (0, 0), a mobile cannot move "Left" or "Down". This information is given by a mask, which is provided under ```obs[<agent_id_str>]["action_mask"]``` in the observation dictionary ```obs``` returned by the scenario.
#
# Let's use a random policy to step through the simulation. The methods below implement a random policy.

# %%
# Note: The code for sampling actions (this cell), and playing an episode (below) are general.  
# That is, it doesn't depend on the Scenario and Component classes used in the environment!

def sample_random_action(agent, mask):
    """Sample random UNMASKED action(s) for agent."""
    # Return a list of actions: 1 for each action subspace
    if agent.multi_action_mode:
        split_masks = np.split(mask, agent.action_spaces.cumsum()[:-1])
        return [np.random.choice(np.arange(len(m_)), p=m_/m_.sum()) for m_ in split_masks]

    # Return a single action
    else:
        return np.random.choice(np.arange(agent.action_spaces), p=mask/mask.sum())

def sample_random_actions(env, obs):
    """Samples random UNMASKED actions for each agent in obs."""
        
    actions = {
        a_idx: sample_random_action(env.get_agent(a_idx), a_obs['action_mask'])
        for a_idx, a_obs in obs.items()
    }

    return actions

# %% [markdown]
# Now we're ready to interact with the simulation...
#
# First, environments can be put in an initial state by using __reset__.

# %%
obs = env.reset()

# %% [markdown]
# Then, we call __step__ to advance the state and advance time by one tick.

# %%
actions = sample_random_actions(env, obs)
obs, rew, done, info = env.step(actions)

# %% [markdown]
# Internally, the __step__ method composes several Components (which act almost like modular sub-Environments) that implement various agent affordances and environment dynamics. For more detailed information on Components and how to implement custom Component classes, see the advanced tutorial. For this tutorial, we will continue to inspect the information that __step__ returns and run a full episode in the simulation.

# %% [markdown]
# ### Observation
#
# Each observation is a dictionary that contains information for the $N$ agents and (optionally) social planner (with id "p").

# %%
obs.keys()
# Out:
# dict_keys(['0', '1', '2', '3', 'p'])

# %% [markdown]
# For each agent, the agent-specific observation is a dictionary. Each Component can contribute information to the agent-specific observation. For instance, the Build Component contributes the
#
# - Build-build_payment (float)
# - Build-build_skill (int)
#
# fields, which are defined in the ```generate_observations``` method in [foundation/components/build.py](https://github.com/salesforce/ai-economist/blob/master/ai_economist/foundation/components/build.py).

# %%
for key, val in obs['0'].items(): 
    print("{:50} {}".format(key, type(val)))
# Out:
# world-map                                          <class 'numpy.ndarray'>
# world-idx_map                                      <class 'numpy.ndarray'>
# world-loc-row                                      <class 'float'>
# world-loc-col                                      <class 'float'>
# world-inventory-Coin                               <class 'float'>
# world-inventory-Stone                              <class 'float'>
# world-inventory-Wood                               <class 'float'>
# time                                               <class 'list'>
# Build-build_payment                                <class 'numpy.float64'>
# Build-build_skill                                  <class 'float'>
# ContinuousDoubleAuction-market_rate-Stone          <class 'numpy.float64'>
# ContinuousDoubleAuction-price_history-Stone        <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_asks-Stone       <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_bids-Stone       <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_asks-Stone              <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_bids-Stone              <class 'numpy.ndarray'>
# ContinuousDoubleAuction-market_rate-Wood           <class 'numpy.float64'>
# ContinuousDoubleAuction-price_history-Wood         <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_asks-Wood        <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_bids-Wood        <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_asks-Wood               <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_bids-Wood               <class 'numpy.ndarray'>
# Gather-bonus_gather_prob                           <class 'float'>
# action_mask                                        <class 'numpy.ndarray'>

# %% [markdown]
# ### Reward
#
# For each agent / planner, the reward dictionary contains a scalar reward:

# %%
for agent_idx, reward in rew.items(): 
    print("{:2} {:.3f}".format(agent_idx, reward))
# Out:
# 0  -0.210
# 1  -0.263
# 2  -0.053
# 3  -0.210
# p  0.000

# %% [markdown]
# ### Done
#
# The __done__ object is a dictionary that by default records whether all agents have seen the end of the episode. The default criterion for each agent is to 'stop' their episode once $H$ steps have been executed. Once an agent is 'done', they do not change their state anymore. So, while it's not currently implemented, this could be used to indicate that the episode has ended *for a specific Agent*.
#
# In general, this is useful for telling a Reinforcement Learning framework when to reset the environment and how to organize the trajectories of individual Agents.

# %%
done
# Out:
# {'__all__': False}

# %% [markdown]
# ### Info
#
# The __info__ object can record any auxiliary information from the simulator, which can be useful, e.g., for visualization. By default, this is empty. To modify this behavior, modify the step() method in [foundation/base/base_env.py](https://github.com/salesforce/ai-economist/blob/master/ai_economist/foundation/base/base_env.py).

# %%
info
# Out:
# {'0': {}, '1': {}, '2': {}, '3': {}, 'p': {}}

# %% [markdown]
# # 3. Sampling and Visualizing an Episode
#
# Let's step multiple times with this random policy and visualize the result:

# %%
def do_plot(env, ax, fig):
    """Plots world state during episode sampling."""
    plotting.plot_env_state(env, ax)
    ax.set_aspect('equal')
    display.display(fig)
    display.clear_output(wait=True)

def play_random_episode(env, plot_every=100, do_dense_logging=False):
    """Plays an episode with randomly sampled actions.
    
    Demonstrates gym-style API:
        obs                  <-- env.reset(...)         # Reset
        obs, rew, done, info <-- env.step(actions, ...) # Interaction loop
    
    """
    fig, ax = plt.subplots(1, 1, figsize=(10, 10))

    # Reset
    obs = env.reset(force_dense_logging=do_dense_logging)

    # Interaction loop (w/ plotting)
    for t in range(env.episode_length):
        actions = sample_random_actions(env, obs)
        obs, rew, done, info = env.step(actions)

        if ((t+1) % plot_every) == 0:
            do_plot(env, ax, fig)

    if ((t+1) % plot_every) != 0:
        do_plot(env, ax, fig)

# %%
play_random_episode(env, plot_every=100)

# %% [markdown]
# We see four agents (indicated by a circled __\*__) that move around in the 2-dimensional world. Light brown cells contain Stone, green cells contain Wood. Each agent can build Houses, indicated by corresponding colored cells. Water tiles (blue squares), which prevent movement, divide the map into four quadrants.
#
# Note: this is showing the same information as the image at the top of the tutorial -- it just uses a much more simplistic rendering.

# %% [markdown]
# # Visualize using dense logging
#
# Environments built with Foundation provide a couple tools for logging. Perhaps the most useful are **dense logs**. When you reset the environment, you can tell it to create a dense log for the new episode. This will store Agent states at each point in time along with any Component-specific dense log information (say, about builds, trades, etc.) that the Components provide. In addition, it will periodically store a snapshot of the world state.
#
# We provide a few plotting tools that work well with the type of environment showcased here.

# %%
# Play another episode. This time, tell the environment to do dense logging
play_random_episode(env, plot_every=100, do_dense_logging=True)

# Grab the dense log from the env
dense_log = env.previous_episode_dense_log

# %%
# Show the evolution of the world state from t=0 to t=200
fig = plotting.vis_world_range(dense_log, t0=0, tN=200, N=5)

# %%
# Show the evolution of the world state over the full episode
fig = plotting.vis_world_range(dense_log, N=5)

# %%
# Use the "breakdown" tool to visualize the world state, agent-wise quantities, movement, and trading events
plotting.breakdown(dense_log)
# Out:
# _______________:_ Agent  0 _____|_ Agent  1 _____|_ Agent  2 _____|_ Agent  3 ____
# Cost (Wood)    :   3.85 (n= 75) |   4.32 (n= 50) |   3.54 (n= 24) |   4.83 (n= 48)
# Cost (Stone)   :   7.29 (n=  7) |   6.25 (n=  4) |   7.00 (n=  2) |   8.67 (n=  3)
#
# Income (Wood)  :   4.25 (n= 55) |   4.45 (n= 47) |   3.79 (n= 24) |   4.06 (n= 71)
# Income (Stone) :   5.67 (n=  3) |   8.00 (n=  8) |   5.50 (n=  2) |   8.00 (n=  3)
# Income (Build) :  16.47 (n= 15) |    ~~~~~~~~    |    ~~~~~~~~    |    ~~~~~~~~
# ((<Figure size 1600x300 with 5 Axes>,
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 1600x800 with 8 Axes>),
#  {'Sell Stone': [17, 64, 11, 24],
#   'Buy Stone': [-51, -25, -14, -26],
#   'Sell Wood': [234, 209, 91, 288],
#   'Buy Wood': [-289, -216, -85, -232],
#   'Build': [247.085594205092, 0, 0, 0],
#   'Total': array([158.08559421,  32.        ,   3.        ,  54.        ])},
#  [168, 42, 13, 64],
#  {'Stone': [{'t': 4,
#     't_ask': 4,
#     't_bid': 0,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 5,
#     't_ask': 5,
#     't_bid': 3,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 77,
#     't_ask': 77,
#     't_bid': 53,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 24,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 130,
#     't_ask': 130,
#     't_bid': 109,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 21,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 287,
#     't_ask': 271,
#     't_bid': 287,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 16,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 319,
#     't_ask': 319,
#     't_bid': 273,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 46,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 320,
#     't_ask': 320,
#     't_bid': 284,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 36,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 561,
#     't_ask': 561,
#     't_bid': 529,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 32,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 564,
#     't_ask': 564,
#     't_bid': 526,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 38,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 830,
#     't_ask': 830,
#     't_bid': 822,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 8,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 831,
#     't_ask': 831,
#     't_bid': 810,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 21,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 832,
#     't_ask': 832,
#     't_bid': 809,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 23,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 834,
#     't_ask': 833,
#     't_bid': 834,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 1,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 835,
#     't_ask': 835,
#     't_bid': 835,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 839,
#     't_ask': 836,
#     't_bid': 839,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 3,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 841,
#     't_ask': 841,
#     't_bid': 836,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7}],
#   'Wood': [{'t': 14,
#     't_ask': 14,
#     't_bid': 0,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 14,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 17,
#     't_ask': 17,
#     't_bid': 3,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 14,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 54,
#     't_ask': 54,
#     't_bid': 6,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 48,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 60,
#     't_ask': 60,
#     't_bid': 60,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 114,
#     't_ask': 109,
#     't_bid': 114,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 5,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 117,
#     't_ask': 117,
#     't_bid': 71,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 1,
#     'bid_lifetime': 46,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 120,
#     't_ask': 106,
#     't_bid': 120,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 14,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 121,
#     't_ask': 121,
#     't_bid': 118,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 156,
#     't_ask': 156,
#     't_bid': 123,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 33,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 157,
#     't_ask': 157,
#     't_bid': 109,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 0,
#     'bid_lifetime': 48,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 158,
#     't_ask': 112,
#     't_bid': 158,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 46,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 173,
#     't_ask': 173,
#     't_bid': 163,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 10,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 174,
#     't_ask': 163,
#     't_bid': 174,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 11,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 210,
#     't_ask': 167,
#     't_bid': 210,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 43,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 212,
#     't_ask': 212,
#     't_bid': 212,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 213,
#     't_ask': 213,
#     't_bid': 175,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 38,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 214,
#     't_ask': 214,
#     't_bid': 175,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 39,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 215,
#     't_ask': 179,
#     't_bid': 215,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 36,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 216,
#     't_ask': 216,
#     't_bid': 213,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 3,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 217,
#     't_ask': 217,
#     't_bid': 210,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 7,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 217,
#     't_ask': 217,
#     't_bid': 214,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 1,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 218,
#     't_ask': 218,
#     't_bid': 218,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 236,
#     't_ask': 236,
#     't_bid': 219,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 17,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 274,
#     't_ask': 266,
#     't_bid': 274,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 8,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 275,
#     't_ask': 270,
#     't_bid': 275,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 5,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 311,
#     't_ask': 276,
#     't_bid': 311,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 35,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 320,
#     't_ask': 320,
#     't_bid': 277,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 1,
#     'bid_lifetime': 43,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 321,
#     't_ask': 276,
#     't_bid': 321,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 45,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 325,
#     't_ask': 325,
#     't_bid': 313,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 12,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 327,
#     't_ask': 321,
#     't_bid': 327,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 6,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 328,
#     't_ask': 316,
#     't_bid': 328,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 12,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 329,
#     't_ask': 329,
#     't_bid': 328,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 331,
#     't_ask': 329,
#     't_bid': 331,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 2,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 341,
#     't_ask': 341,
#     't_bid': 316,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 1,
#     'bid_lifetime': 25,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 366,
#     't_ask': 330,
#     't_bid': 366,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 36,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 367,
#     't_ask': 349,
#     't_bid': 367,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 18,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 368,
#     't_ask': 326,
#     't_bid': 368,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 42,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 370,
#     't_ask': 370,
#     't_bid': 368,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 1,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 371,
#     't_ask': 371,
#     't_bid': 371,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 374,
#     't_ask': 374,
#     't_bid': 372,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 375,
#     't_ask': 375,
#     't_bid': 375,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 377,
#     't_ask': 331,
#     't_bid': 377,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 46,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 378,
#     't_ask': 378,
#     't_bid': 377,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 379,
#     't_ask': 376,
#     't_bid': 379,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 3,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 380,
#     't_ask': 333,
#     't_bid': 380,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 47,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 381,
#     't_ask': 381,
#     't_bid': 381,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 382,
#     't_ask': 382,
#     't_bid': 381,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 385,
#     't_ask': 385,
#     't_bid': 384,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 414,
#     't_ask': 414,
#     't_bid': 394,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 20,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 415,
#     't_ask': 415,
#     't_bid': 380,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 35,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 416,
#     't_ask': 382,
#     't_bid': 416,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 34,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 420,
#     't_ask': 391,
#     't_bid': 420,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 29,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 422,
#     't_ask': 422,
#     't_bid': 420,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 433,
#     't_ask': 433,
#     't_bid': 425,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 8,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 434,
#     't_ask': 418,
#     't_bid': 434,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 16,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 436,
#     't_ask': 436,
#     't_bid': 391,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 45,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 437,
#     't_ask': 437,
#     't_bid': 437,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 438,
#     't_ask': 438,
#     't_bid': 395,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 43,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 440,
#     't_ask': 438,
#     't_bid': 440,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 2,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 441,
#     't_ask': 438,
#     't_bid': 441,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 3,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 443,
#     't_ask': 442,
#     't_bid': 443,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 1,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 444,
#     't_ask': 444,
#     't_bid': 435,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 9,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 485,
#     't_ask': 446,
#     't_bid': 485,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 39,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 487,
#     't_ask': 466,
#     't_bid': 487,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 21,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 488,
#     't_ask': 487,
#     't_bid': 488,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 1,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 491,
#     't_ask': 491,
#     't_bid': 491,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 493,
#     't_ask': 493,
#     't_bid': 489,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 497,
#     't_ask': 494,
#     't_bid': 497,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 3,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 498,
#     't_ask': 496,
#     't_bid': 498,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 2,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 499,
#     't_ask': 468,
#     't_bid': 499,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 31,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 501,
#     't_ask': 492,
#     't_bid': 501,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 9,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 502,
#     't_ask': 502,
#     't_bid': 467,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 35,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 546,
#     't_ask': 502,
#     't_bid': 546,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 44,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 547,
#     't_ask': 547,
#     't_bid': 541,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 6,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 550,
#     't_ask': 550,
#     't_bid': 525,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 25,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 551,
#     't_ask': 523,
#     't_bid': 551,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 28,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 553,
#     't_ask': 553,
#     't_bid': 551,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 554,
#     't_ask': 553,
#     't_bid': 554,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 1,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 554,
#     't_ask': 549,
#     't_bid': 554,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 5,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 555,
#     't_ask': 554,
#     't_bid': 555,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 1,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 561,
#     't_ask': 561,
#     't_bid': 544,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 17,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 562,
#     't_ask': 559,
#     't_bid': 562,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 3,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 563,
#     't_ask': 563,
#     't_bid': 558,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 563,
#     't_ask': 563,
#     't_bid': 547,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 16,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 566,
#     't_ask': 566,
#     't_bid': 556,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 567,
#     't_ask': 559,
#     't_bid': 567,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 8,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 570,
#     't_ask': 570,
#     't_bid': 570,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 572,
#     't_ask': 569,
#     't_bid': 572,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 3,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 573,
#     't_ask': 567,
#     't_bid': 573,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 6,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 574,
#     't_ask': 574,
#     't_bid': 556,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 18,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 593,
#     't_ask': 593,
#     't_bid': 565,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 28,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 595,
#     't_ask': 595,
#     't_bid': 558,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 37,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 596,
#     't_ask': 580,
#     't_bid': 596,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 16,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 605,
#     't_ask': 596,
#     't_bid': 605,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 9,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 611,
#     't_ask': 611,
#     't_bid': 564,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 47,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 615,
#     't_ask': 615,
#     't_bid': 575,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 40,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 616,
#     't_ask': 612,
#     't_bid': 616,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 4,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 619,
#     't_ask': 617,
#     't_bid': 619,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 2,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 620,
#     't_ask': 606,
#     't_bid': 620,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 14,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 625,
#     't_ask': 577,
#     't_bid': 625,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 48,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 629,
#     't_ask': 624,
#     't_bid': 629,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 5,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 630,
#     't_ask': 620,
#     't_bid': 630,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 10,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 648,
#     't_ask': 602,
#     't_bid': 648,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 46,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 648,
#     't_ask': 621,
#     't_bid': 648,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 27,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 649,
#     't_ask': 642,
#     't_bid': 649,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 7,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 651,
#     't_ask': 651,
#     't_bid': 649,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 658,
#     't_ask': 658,
#     't_bid': 658,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 659,
#     't_ask': 617,
#     't_bid': 659,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 42,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 660,
#     't_ask': 660,
#     't_bid': 650,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 661,
#     't_ask': 661,
#     't_bid': 661,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 663,
#     't_ask': 663,
#     't_bid': 663,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 666,
#     't_ask': 666,
#     't_bid': 664,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 682,
#     't_ask': 673,
#     't_bid': 682,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 9,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 684,
#     't_ask': 684,
#     't_bid': 682,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 691,
#     't_ask': 663,
#     't_bid': 691,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 28,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 693,
#     't_ask': 693,
#     't_bid': 686,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 7,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 694,
#     't_ask': 694,
#     't_bid': 653,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 41,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 695,
#     't_ask': 695,
#     't_bid': 695,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 696,
#     't_ask': 694,
#     't_bid': 696,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 2,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 697,
#     't_ask': 697,
#     't_bid': 697,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 701,
#     't_ask': 667,
#     't_bid': 701,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 34,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 702,
#     't_ask': 702,
#     't_bid': 698,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 703,
#     't_ask': 667,
#     't_bid': 703,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 36,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 704,
#     't_ask': 704,
#     't_bid': 702,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 704,
#     't_ask': 704,
#     't_bid': 703,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 704,
#     't_ask': 704,
#     't_bid': 675,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 29,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 708,
#     't_ask': 708,
#     't_bid': 697,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 11,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 733,
#     't_ask': 683,
#     't_bid': 733,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 50,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 749,
#     't_ask': 749,
#     't_bid': 728,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 756,
#     't_ask': 756,
#     't_bid': 756,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 756,
#     't_ask': 756,
#     't_bid': 736,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 20,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 757,
#     't_ask': 757,
#     't_bid': 757,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 759,
#     't_ask': 759,
#     't_bid': 759,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 762,
#     't_ask': 762,
#     't_bid': 734,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 28,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 762,
#     't_ask': 762,
#     't_bid': 760,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 763,
#     't_ask': 763,
#     't_bid': 763,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 766,
#     't_ask': 766,
#     't_bid': 766,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 767,
#     't_ask': 767,
#     't_bid': 761,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 6,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 769,
#     't_ask': 751,
#     't_bid': 769,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 18,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 769,
#     't_ask': 765,
#     't_bid': 769,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 4,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 771,
#     't_ask': 771,
#     't_bid': 770,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 772,
#     't_ask': 772,
#     't_bid': 772,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 773,
#     't_ask': 773,
#     't_bid': 768,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 788,
#     't_ask': 788,
#     't_bid': 774,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 14,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 795,
#     't_ask': 795,
#     't_bid': 760,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 35,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 811,
#     't_ask': 796,
#     't_bid': 811,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 15,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 812,
#     't_ask': 812,
#     't_bid': 789,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 23,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 813,
#     't_ask': 813,
#     't_bid': 813,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 814,
#     't_ask': 814,
#     't_bid': 767,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 47,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 815,
#     't_ask': 815,
#     't_bid': 815,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 817,
#     't_ask': 817,
#     't_bid': 774,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 43,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 819,
#     't_ask': 796,
#     't_bid': 819,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 23,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 820,
#     't_ask': 801,
#     't_bid': 820,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 19,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 820,
#     't_ask': 770,
#     't_bid': 820,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 50,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 821,
#     't_ask': 812,
#     't_bid': 821,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 9,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 825,
#     't_ask': 825,
#     't_bid': 823,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 826,
#     't_ask': 826,
#     't_bid': 824,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 829,
#     't_ask': 822,
#     't_bid': 829,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 7,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 831,
#     't_ask': 818,
#     't_bid': 831,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 13,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 834,
#     't_ask': 834,
#     't_bid': 827,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 7,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 835,
#     't_ask': 826,
#     't_bid': 835,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 9,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 859,
#     't_ask': 826,
#     't_bid': 859,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 33,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 860,
#     't_ask': 860,
#     't_bid': 814,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 46,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 867,
#     't_ask': 867,
#     't_bid': 838,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 29,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 868,
#     't_ask': 868,
#     't_bid': 867,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 879,
#     't_ask': 872,
#     't_bid': 879,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 7,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 880,
#     't_ask': 880,
#     't_bid': 880,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 881,
#     't_ask': 881,
#     't_bid': 868,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 13,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 904,
#     't_ask': 904,
#     't_bid': 903,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 914,
#     't_ask': 912,
#     't_bid': 914,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 2,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 920,
#     't_ask': 917,
#     't_bid': 920,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 3,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 921,
#     't_ask': 921,
#     't_bid': 882,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 39,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 922,
#     't_ask': 907,
#     't_bid': 922,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 15,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 923,
#     't_ask': 881,
#     't_bid': 923,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 42,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 925,
#     't_ask': 925,
#     't_bid': 922,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 3,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 926,
#     't_ask': 922,
#     't_bid': 926,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 4,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 926,
#     't_ask': 882,
#     't_bid': 926,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 44,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 927,
#     't_ask': 927,
#     't_bid': 927,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 928,
#     't_ask': 924,
#     't_bid': 928,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 4,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 932,
#     't_ask': 932,
#     't_bid': 925,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 7,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 934,
#     't_ask': 934,
#     't_bid': 933,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 935,
#     't_ask': 935,
#     't_bid': 933,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 936,
#     't_ask': 929,
#     't_bid': 936,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 7,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 941,
#     't_ask': 941,
#     't_bid': 937,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 982,
#     't_ask': 979,
#     't_bid': 982,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 3,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 982,
#     't_ask': 937,
#     't_bid': 982,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 45,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 983,
#     't_ask': 966,
#     't_bid': 983,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 17,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 984,
#     't_ask': 984,
#     't_bid': 984,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 986,
#     't_ask': 986,
#     't_bid': 986,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 986,
#     't_ask': 983,
#     't_bid': 986,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 3,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 987,
#     't_ask': 987,
#     't_bid': 987,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 989,
#     't_ask': 979,
#     't_bid': 989,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 10,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 992,
#     't_ask': 984,
#     't_bid': 992,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 8,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 994,
#     't_ask': 994,
#     't_bid': 985,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 9,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 994,
#     't_ask': 994,
#     't_bid': 990,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 996,
#     't_ask': 980,
#     't_bid': 996,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 16,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 998,
#     't_ask': 998,
#     't_bid': 998,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0}]},
#  [{'t': 131, 'builder': 0, 'loc': [2, 0], 'income': 16.472372947006132},
#   {'t': 168, 'builder': 0, 'loc': [2, 4], 'income': 16.472372947006132},
#   {'t': 178, 'builder': 0, 'loc': [3, 4], 'income': 16.472372947006132},
#   {'t': 258, 'builder': 0, 'loc': [4, 4], 'income': 16.472372947006132},
#   {'t': 265, 'builder': 0, 'loc': [2, 5], 'income': 16.472372947006132},
#   {'t': 297, 'builder': 0, 'loc': [5, 5], 'income': 16.472372947006132},
#   {'t': 328, 'builder': 0, 'loc': [3, 8], 'income': 16.472372947006132},
#   {'t': 566, 'builder': 0, 'loc': [4, 7], 'income': 16.472372947006132},
#   {'t': 594, 'builder': 0, 'loc': [4, 5], 'income': 16.472372947006132},
#   {'t': 665, 'builder': 0, 'loc': [1, 5], 'income': 16.472372947006132},
#   {'t': 710, 'builder': 0, 'loc': [5, 4], 'income': 16.472372947006132},
#   {'t': 723, 'builder': 0, 'loc': [5, 3], 'income': 16.472372947006132},
#   {'t': 735, 'builder': 0, 'loc': [6, 0], 'income': 16.472372947006132},
#   {'t': 790, 'builder': 0, 'loc': [8, 2], 'income': 16.472372947006132},
#   {'t': 845, 'builder': 0, 'loc': [9, 1], 'income': 16.472372947006132}])

# %% [markdown]
# # Next
#
# Now that you've seen how to interact with the simulation and generate episodes, try the next tutorial ([economic_simulation_advanced.ipynb](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_advanced.ipynb)) that explains how the simulation is composed of low-level Components and Entities. This structure enables flexible extensions of the economic simulation.

# %% [markdown]
# # Split-Wold

# %%
#multi_zone/simple_wood_and_stone

# %%
from ai_economist import foundation

# --- 1. Configure the SPLIT-LAYOUT environment ---
env_config_split = {
    'scenario_name': 'split_layout/simple_wood_and_stone',

    'components': [
        ('Build', {'skill_dist': "pareto", 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],

    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': False,

    'n_agents': 4,
    'world_size': [25, 25],
    'episode_length': 1000,

    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,

    'flatten_observations': False,
    'flatten_masks': True,
}

# --- 2. Create environment instance ---
split_env = foundation.make_env_instance(**env_config_split)

# --- 3. Run a random episode & visualize every 100 steps ---
play_random_episode(split_env, plot_every=100)

# %%
obs = split_env.reset(force_dense_logging=True)

for t in range(split_env.episode_length):
    actions = sample_random_actions(split_env, obs)
    obs, rew, done, info = split_env.step(actions)

# %%
dense_log_split = split_env.previous_episode_dense_log

plotting.breakdown(dense_log_split)
# Out:
# _______________:_ Agent  0 _____|_ Agent  1 _____|_ Agent  2 _____|_ Agent  3 ____
# Cost (Wood)    :   9.14 (n=  7) |   4.50 (n=  4) |   6.22 (n=  9) |   5.43 (n= 14)
# Cost (Stone)   :   4.86 (n= 35) |   3.90 (n= 10) |   4.93 (n= 59) |   5.17 (n= 54)
#
# Income (Wood)  :   7.33 (n=  6) |   3.50 (n=  4) |   6.44 (n= 16) |   6.62 (n=  8)
# Income (Stone) :   5.82 (n= 39) |   4.60 (n= 10) |   4.54 (n= 52) |   4.74 (n= 57)
# Income (Build) :  13.28 (n=  1) |    ~~~~~~~~    |  22.27 (n=  8) |  11.34 (n=  6)
# ((<Figure size 1600x300 with 5 Axes>,
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 1600x800 with 8 Axes>),
#  {'Sell Stone': [227, 46, 236, 270],
#   'Buy Stone': [-170, -39, -291, -279],
#   'Sell Wood': [44, 14, 103, 53],
#   'Buy Wood': [-64, -18, -56, -76],
#   'Build': [13.27623062035527, 0, 178.15515460310965, 68.01868204659236],
#   'Total': array([ 50.27623062,   3.        , 170.1551546 ,  36.01868205])},
#  [60, 13, 180, 46],
#  {'Stone': [{'t': 263,
#     't_ask': 263,
#     't_bid': 217,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 46,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 269,
#     't_ask': 269,
#     't_bid': 264,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 270,
#     't_ask': 270,
#     't_bid': 226,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 44,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 272,
#     't_ask': 272,
#     't_bid': 271,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 276,
#     't_ask': 276,
#     't_bid': 275,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 278,
#     't_ask': 245,
#     't_bid': 278,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 33,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 280,
#     't_ask': 279,
#     't_bid': 280,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 1,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 294,
#     't_ask': 294,
#     't_bid': 264,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 30,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 298,
#     't_ask': 298,
#     't_bid': 273,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 25,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 321,
#     't_ask': 321,
#     't_bid': 299,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 22,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 328,
#     't_ask': 328,
#     't_bid': 322,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 6,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 329,
#     't_ask': 329,
#     't_bid': 302,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 27,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 332,
#     't_ask': 332,
#     't_bid': 288,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 44,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 333,
#     't_ask': 333,
#     't_bid': 329,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 333,
#     't_ask': 333,
#     't_bid': 300,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 33,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 334,
#     't_ask': 334,
#     't_bid': 323,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 11,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 334,
#     't_ask': 334,
#     't_bid': 299,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 1,
#     'bid_lifetime': 35,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 335,
#     't_ask': 330,
#     't_bid': 335,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 5,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 373,
#     't_ask': 373,
#     't_bid': 335,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 38,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 382,
#     't_ask': 337,
#     't_bid': 382,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 45,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 386,
#     't_ask': 386,
#     't_bid': 383,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 3,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 387,
#     't_ask': 387,
#     't_bid': 386,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 388,
#     't_ask': 388,
#     't_bid': 387,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 416,
#     't_ask': 374,
#     't_bid': 416,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 42,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 417,
#     't_ask': 390,
#     't_bid': 417,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 27,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 417,
#     't_ask': 389,
#     't_bid': 417,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 28,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 418,
#     't_ask': 387,
#     't_bid': 418,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 31,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 424,
#     't_ask': 419,
#     't_bid': 424,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 5,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 435,
#     't_ask': 435,
#     't_bid': 419,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 16,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 437,
#     't_ask': 399,
#     't_bid': 437,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 38,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 440,
#     't_ask': 440,
#     't_bid': 438,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 441,
#     't_ask': 441,
#     't_bid': 441,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 447,
#     't_ask': 447,
#     't_bid': 438,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 9,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 448,
#     't_ask': 448,
#     't_bid': 427,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 487,
#     't_ask': 487,
#     't_bid': 476,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 11,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 490,
#     't_ask': 490,
#     't_bid': 442,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 48,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 491,
#     't_ask': 491,
#     't_bid': 449,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 42,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 492,
#     't_ask': 492,
#     't_bid': 492,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 493,
#     't_ask': 493,
#     't_bid': 473,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 20,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 495,
#     't_ask': 495,
#     't_bid': 494,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 496,
#     't_ask': 496,
#     't_bid': 496,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 500,
#     't_ask': 497,
#     't_bid': 500,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 3,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 501,
#     't_ask': 501,
#     't_bid': 493,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 8,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 503,
#     't_ask': 493,
#     't_bid': 503,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 10,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 505,
#     't_ask': 504,
#     't_bid': 505,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 1,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 507,
#     't_ask': 471,
#     't_bid': 507,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 36,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 527,
#     't_ask': 508,
#     't_bid': 527,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 19,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 528,
#     't_ask': 497,
#     't_bid': 528,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 31,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 530,
#     't_ask': 529,
#     't_bid': 530,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 1,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 553,
#     't_ask': 553,
#     't_bid': 545,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 8,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 555,
#     't_ask': 555,
#     't_bid': 554,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 556,
#     't_ask': 508,
#     't_bid': 556,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 48,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 559,
#     't_ask': 558,
#     't_bid': 559,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 1,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 560,
#     't_ask': 560,
#     't_bid': 518,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 42,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 561,
#     't_ask': 561,
#     't_bid': 525,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 36,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 562,
#     't_ask': 560,
#     't_bid': 562,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 2,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 579,
#     't_ask': 561,
#     't_bid': 579,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 18,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 580,
#     't_ask': 580,
#     't_bid': 580,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 581,
#     't_ask': 581,
#     't_bid': 540,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 41,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 582,
#     't_ask': 563,
#     't_bid': 582,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 19,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 583,
#     't_ask': 581,
#     't_bid': 583,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 2,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 592,
#     't_ask': 592,
#     't_bid': 584,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 8,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 597,
#     't_ask': 586,
#     't_bid': 597,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 11,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 598,
#     't_ask': 598,
#     't_bid': 593,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 605,
#     't_ask': 600,
#     't_bid': 605,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 5,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 606,
#     't_ask': 606,
#     't_bid': 598,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 8,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 608,
#     't_ask': 608,
#     't_bid': 607,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 610,
#     't_ask': 589,
#     't_bid': 610,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 21,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 633,
#     't_ask': 633,
#     't_bid': 601,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 32,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 635,
#     't_ask': 590,
#     't_bid': 635,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 45,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 637,
#     't_ask': 637,
#     't_bid': 637,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 639,
#     't_ask': 639,
#     't_bid': 634,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 641,
#     't_ask': 634,
#     't_bid': 641,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 7,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 644,
#     't_ask': 644,
#     't_bid': 642,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 645,
#     't_ask': 645,
#     't_bid': 645,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 647,
#     't_ask': 645,
#     't_bid': 647,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 650,
#     't_ask': 650,
#     't_bid': 613,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 37,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 652,
#     't_ask': 652,
#     't_bid': 648,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 659,
#     't_ask': 659,
#     't_bid': 654,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 660,
#     't_ask': 660,
#     't_bid': 660,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 663,
#     't_ask': 663,
#     't_bid': 663,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 698,
#     't_ask': 698,
#     't_bid': 665,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 33,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 699,
#     't_ask': 699,
#     't_bid': 662,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 37,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 701,
#     't_ask': 699,
#     't_bid': 701,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 704,
#     't_ask': 666,
#     't_bid': 704,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 38,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 751,
#     't_ask': 751,
#     't_bid': 751,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 753,
#     't_ask': 753,
#     't_bid': 718,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 35,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 753,
#     't_ask': 753,
#     't_bid': 705,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 48,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 755,
#     't_ask': 755,
#     't_bid': 712,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 43,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 756,
#     't_ask': 756,
#     't_bid': 753,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 757,
#     't_ask': 757,
#     't_bid': 755,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 757,
#     't_ask': 757,
#     't_bid': 736,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 21,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 757,
#     't_ask': 757,
#     't_bid': 754,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 759,
#     't_ask': 759,
#     't_bid': 759,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 761,
#     't_ask': 756,
#     't_bid': 761,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 5,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 762,
#     't_ask': 762,
#     't_bid': 762,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 765,
#     't_ask': 760,
#     't_bid': 765,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 5,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 812,
#     't_ask': 811,
#     't_bid': 812,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 1,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 813,
#     't_ask': 766,
#     't_bid': 813,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 47,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 814,
#     't_ask': 814,
#     't_bid': 793,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 816,
#     't_ask': 816,
#     't_bid': 816,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 818,
#     't_ask': 818,
#     't_bid': 817,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 818,
#     't_ask': 818,
#     't_bid': 818,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 820,
#     't_ask': 820,
#     't_bid': 816,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 822,
#     't_ask': 822,
#     't_bid': 821,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 826,
#     't_ask': 826,
#     't_bid': 821,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 828,
#     't_ask': 828,
#     't_bid': 809,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 19,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 830,
#     't_ask': 830,
#     't_bid': 830,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 838,
#     't_ask': 838,
#     't_bid': 820,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 18,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 839,
#     't_ask': 827,
#     't_bid': 839,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 12,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 865,
#     't_ask': 865,
#     't_bid': 831,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 34,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 867,
#     't_ask': 867,
#     't_bid': 867,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 886,
#     't_ask': 886,
#     't_bid': 878,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 8,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 894,
#     't_ask': 894,
#     't_bid': 882,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 12,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 895,
#     't_ask': 895,
#     't_bid': 870,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 25,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 896,
#     't_ask': 896,
#     't_bid': 871,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 25,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 897,
#     't_ask': 897,
#     't_bid': 875,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 22,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 897,
#     't_ask': 897,
#     't_bid': 887,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 898,
#     't_ask': 898,
#     't_bid': 891,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 7,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 899,
#     't_ask': 899,
#     't_bid': 868,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 31,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 900,
#     't_ask': 898,
#     't_bid': 900,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 2,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 901,
#     't_ask': 896,
#     't_bid': 901,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 5,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 904,
#     't_ask': 874,
#     't_bid': 904,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 30,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 905,
#     't_ask': 905,
#     't_bid': 901,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 906,
#     't_ask': 887,
#     't_bid': 906,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 19,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 907,
#     't_ask': 907,
#     't_bid': 902,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 908,
#     't_ask': 908,
#     't_bid': 904,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 909,
#     't_ask': 909,
#     't_bid': 908,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 911,
#     't_ask': 911,
#     't_bid': 910,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 911,
#     't_ask': 911,
#     't_bid': 909,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 912,
#     't_ask': 876,
#     't_bid': 912,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 36,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 913,
#     't_ask': 913,
#     't_bid': 912,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 914,
#     't_ask': 897,
#     't_bid': 914,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 17,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 915,
#     't_ask': 915,
#     't_bid': 915,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 916,
#     't_ask': 916,
#     't_bid': 913,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 917,
#     't_ask': 917,
#     't_bid': 888,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 29,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 917,
#     't_ask': 917,
#     't_bid': 898,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 19,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 918,
#     't_ask': 918,
#     't_bid': 910,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 8,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 918,
#     't_ask': 918,
#     't_bid': 908,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 2,
#     'bid_lifetime': 10,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 919,
#     't_ask': 918,
#     't_bid': 919,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 1,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 923,
#     't_ask': 923,
#     't_bid': 919,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 924,
#     't_ask': 924,
#     't_bid': 920,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 925,
#     't_ask': 916,
#     't_bid': 925,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 9,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 926,
#     't_ask': 926,
#     't_bid': 926,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 927,
#     't_ask': 927,
#     't_bid': 922,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 927,
#     't_ask': 927,
#     't_bid': 925,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 928,
#     't_ask': 928,
#     't_bid': 928,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 928,
#     't_ask': 916,
#     't_bid': 928,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 12,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 931,
#     't_ask': 931,
#     't_bid': 929,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 932,
#     't_ask': 932,
#     't_bid': 919,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 13,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 934,
#     't_ask': 934,
#     't_bid': 934,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 953,
#     't_ask': 935,
#     't_bid': 953,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 18,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 955,
#     't_ask': 955,
#     't_bid': 938,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 17,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 971,
#     't_ask': 964,
#     't_bid': 971,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 7,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 980,
#     't_ask': 956,
#     't_bid': 980,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 24,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 981,
#     't_ask': 972,
#     't_bid': 981,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 9,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 982,
#     't_ask': 958,
#     't_bid': 982,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 24,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 984,
#     't_ask': 984,
#     't_bid': 984,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2}],
#   'Wood': [{'t': 202,
#     't_ask': 202,
#     't_bid': 158,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 44,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 203,
#     't_ask': 203,
#     't_bid': 170,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 33,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 220,
#     't_ask': 204,
#     't_bid': 220,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 16,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 266,
#     't_ask': 238,
#     't_bid': 266,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 28,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 268,
#     't_ask': 268,
#     't_bid': 221,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 47,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 271,
#     't_ask': 255,
#     't_bid': 271,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 16,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 273,
#     't_ask': 254,
#     't_bid': 273,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 19,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 277,
#     't_ask': 268,
#     't_bid': 277,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 9,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 279,
#     't_ask': 279,
#     't_bid': 274,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 5,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 288,
#     't_ask': 288,
#     't_bid': 278,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 290,
#     't_ask': 290,
#     't_bid': 290,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 291,
#     't_ask': 280,
#     't_bid': 291,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 11,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 292,
#     't_ask': 280,
#     't_bid': 292,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 12,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 300,
#     't_ask': 282,
#     't_bid': 300,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 18,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 343,
#     't_ask': 343,
#     't_bid': 301,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 42,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 346,
#     't_ask': 346,
#     't_bid': 344,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 348,
#     't_ask': 303,
#     't_bid': 348,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 45,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 378,
#     't_ask': 378,
#     't_bid': 377,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 379,
#     't_ask': 379,
#     't_bid': 350,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 29,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 381,
#     't_ask': 381,
#     't_bid': 381,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 400,
#     't_ask': 379,
#     't_bid': 400,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 21,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 535,
#     't_ask': 535,
#     't_bid': 490,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 45,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 536,
#     't_ask': 536,
#     't_bid': 522,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 14,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 538,
#     't_ask': 538,
#     't_bid': 537,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 588,
#     't_ask': 588,
#     't_bid': 556,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 32,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 589,
#     't_ask': 589,
#     't_bid': 539,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 50,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 608,
#     't_ask': 608,
#     't_bid': 594,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 14,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 610,
#     't_ask': 610,
#     't_bid': 604,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 6,
#     'seller': 0,
#     'ask': 10,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 611,
#     't_ask': 611,
#     't_bid': 575,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 36,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 617,
#     't_ask': 612,
#     't_bid': 617,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 5,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 620,
#     't_ask': 620,
#     't_bid': 618,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 622,
#     't_ask': 622,
#     't_bid': 622,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 662,
#     't_ask': 662,
#     't_bid': 642,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 20,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 675,
#     't_ask': 663,
#     't_bid': 675,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 12,
#     'price': 8,
#     'cost': 8,
#     'income': 8}]},
#  [{'t': 297, 'builder': 3, 'loc': [17, 0], 'income': 11.336447007765393},
#   {'t': 380, 'builder': 3, 'loc': [20, 7], 'income': 11.336447007765393},
#   {'t': 392, 'builder': 3, 'loc': [18, 8], 'income': 11.336447007765393},
#   {'t': 408, 'builder': 2, 'loc': [9, 12], 'income': 22.269394325388706},
#   {'t': 422, 'builder': 3, 'loc': [19, 13], 'income': 11.336447007765393},
#   {'t': 435, 'builder': 2, 'loc': [3, 10], 'income': 22.269394325388706},
#   {'t': 518, 'builder': 2, 'loc': [0, 6], 'income': 22.269394325388706},
#   {'t': 537, 'builder': 2, 'loc': [1, 5], 'income': 22.269394325388706},
#   {'t': 542, 'builder': 0, 'loc': [19, 11], 'income': 13.27623062035527},
#   {'t': 544, 'builder': 3, 'loc': [16, 16], 'income': 11.336447007765393},
#   {'t': 596, 'builder': 2, 'loc': [2, 2], 'income': 22.269394325388706},
#   {'t': 599, 'builder': 2, 'loc': [3, 2], 'income': 22.269394325388706},
#   {'t': 687, 'builder': 3, 'loc': [14, 17], 'income': 11.336447007765393},
#   {'t': 965, 'builder': 2, 'loc': [0, 5], 'income': 22.269394325388706},
#   {'t': 997, 'builder': 2, 'loc': [0, 11], 'income': 22.269394325388706}])

# %%
env_config_split_big = {
    'scenario_name': 'split_layout/simple_wood_and_stone',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 4,
    'world_size': [60, 60],
    'episode_length': 1000,
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    'flatten_observations': False,
    'flatten_masks': True,

    # Layout controls
    'env_layout_file': 'random_60x60_ws.txt',
    'fixed_four_skill_and_loc': False,
    'starting_agent_coin': 10,

    # Logging
    'dense_log_frequency': 1,
}


split_env_big = foundation.make_env_instance(**env_config_split_big)


play_random_episode(split_env_big, plot_every=100)

# %%
env_config = {
    'scenario_name': 'layout_from_file/simple_wood_and_stone', #no waterline weeee
    'components': [
        ('Build', {'skill_dist':'pareto', 'payment_max_skill_multiplier':3}),
        ('ContinuousDoubleAuction', {'max_num_orders':5}),
        ('Gather', {})
    ],
    'n_agents': 4,
    'world_size': [25,25],
    'env_layout_file':'quadrant_25x25_20each_30clump.txt',

    # NEW: custom start positions
    'agent_start_locs': [(5,5), (5,20), (20,5), (20,20)],

    'starting_agent_coin': 10,
}
env = foundation.make_env_instance(**env_config)
env.reset()

print([agent.loc for agent in env.world.agents])

env = foundation.make_env_instance(**env_config)


play_random_episode(env, plot_every=100)

# %% [markdown]
# ## this next part might just be deleted

# %% [markdown]
# Creating file

# %%
import os
import numpy as np

def make_random_layout_file(
    H=60, W=60,
    p_wood=0.12, p_stone=0.12, p_water=0.00,
    seed=123,
    out_path="tutorials/map_txt/random_60x60_ws.txt",
):
    """
    Create a HxW layout text file with random W/S/@/space
    respecting the requested densities.
    Lines are joined by ';' (Foundation expects this format).
    """
    assert 0 <= p_wood <= 1 and 0 <= p_stone <= 1 and 0 <= p_water <= 1
    assert p_wood + p_stone + p_water <= 1.0, "Densities sum must be <= 1"
    rng = np.random.RandomState(seed)

    mask = rng.rand(H, W)
    th_w = p_wood
    th_s = p_wood + p_stone
    th_a = th_s   + p_water

    chars = np.full((H, W), ' ', dtype='<U1')
    chars[mask < th_w] = 'W'
    chars[(mask >= th_w) & (mask < th_s)] = 'S'
    chars[(mask >= th_s) & (mask < th_a)] = '@'

    rows = [''.join(chars[r, :].tolist()) for r in range(H)]
    text = ';'.join(rows)

    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    with open(out_path, "w") as f:
        f.write(text)
    return out_path, text

# --- Generate the file ---
#path, _ = make_random_layout_file(
    # H=60, W=60,
    # p_wood=0.12,
    # p_stone=0.12,
    # p_water=0.00,
    # seed=42,
    # out_path="DRL-IN-INTERNATIONAL-ECONOMY-AI-ECONOMIST_/ai_economist/foundation/scenarios/simple_wood_and_stone/map_txt/random_60x60_ws.txt",
#)
#print("Wrote:", path)
# Out:
#   Cell In[32], line 39
#     H=60, W=60,
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# ## Debugging

# %%
env_config = {
    'scenario_name': 'layout_from_file/simple_wood_and_stone',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 4,
    'world_size': [60, 60],
    'episode_length': 1000,

    'randomize_layout': True,
    'wood_density': 0.15,
    'stone_density': 0.12,
    'water_density': 0.02,   # if you want some lakes in plain layout
    'rng_seed': 7,

    'agent_start_locs': None,
    'fixed_four_skill_and_loc': False,
}

env.reset()
print([tuple(a.loc) for a in env.world.agents])  # should match agent_start_locs order

mW = env.world.maps.get("Wood")
mS = env.world.maps.get("Stone")
mA = env.world.maps.get("Water")
H, W = env.world_size
print("World:", H, W)
print("Wood density:", mW.sum() / (H*W))
print("Stone density:", mS.sum() / (H*W))
print("Water density:", mA.sum() / (H*W))

mA = env.world.maps.get("Water")
print("Unique rows with water:", np.unique(np.where(mA>0)[0]))
# Out:
# [(5, 5), (5, 54), (54, 5), (54, 54)]
# World: 60 60
# Wood density: 0.1275
# Stone density: 0.11527777777777778
# Water density: 0.0
# Unique rows with water: []
