# %% [markdown]
# Copyright (c) 2020, salesforce.com, inc.
# All rights reserved.
# SPDX-License-Identifier: BSD-3-Clause
# For full license text, see the LICENSE file in the repo root or https://opensource.org/licenses/BSD-3-Clause

# %% [markdown]
# ### Colab
#
# Try this notebook on [Colab](http://colab.research.google.com/github/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basic.ipynb).

# %% [markdown]
# # Welcome to Foundation!
#
# Foundation is the name of the economic simulator built for the AI Economist ([paper here](https://arxiv.org/abs/2004.13332)). This is the first of several tutorials designed to explain how Foundation works and how it can be used to build simulation environments for studying economic problems.
#
# Just to orient you a bit, Foundation is specially designed for modeling economies in spatial, 2D grid worlds. The AI Economist paper uses a scenario with 4 agents in a world with *Stone* and *Wood*, which can be *collected*, *traded*, and used to build *Houses*. Here's a (nicely rendered) example of what such an environment looks like:
#
# ![Foundation snapshot](assets/foundation_snapshot_rendered.jpg)
#
# This image just shows what you might see spatially. Behind the scenes, agents have inventories of Stone, Wood, and *Coin*, which they can exchange through a commodities marketplace. In addition, they periodically pay taxes on income earned through trading and building.
#
# **We've open-sourced Foundation to foster transparency and to enable others to build on it!** With that goal in mind, this first tutorial should give you enough to see how to create the type of simulation environment described above and how to interact with it. If you're interested to learn how it all works and how to build on it, make sure to check out the advanced tutorial as well! If, after that, you want to understand more about designing the simulation around economic problems, check out our tutorial explaining how the AI Economist uses Foundation to study the optimal taxation problem!

# %% [markdown]
# # Introduction
#
# In this **basic** tutorial, we will demonstrate the basics of how to create an instance of a simulation environment and how to interact with it.
#
# We will cover the following:
# 1. Markov Decision Processes
# 2. Creating a Simulation Environment (a Scenario Instance)
# 3. Interacting with the Simulation
# 4. Sampling and Visualizing an Episode

# %% [markdown]
# ## Dependencies:
# You can install the ai-economist package using
# - the pip package manager OR
# - by cloning the ai-economist package and installing the requirements (we shall use this when running on Colab):

# %%
# import os, signal, sys, time
# IN_COLAB = 'google.colab' in sys.modules

# if IN_COLAB:
#     !git clone https://github.com/salesforce/ai-economist.git

#     %cd ai-economist
#     !pip install -e .
    
#     # Restart the Python runtime to automatically use the installed packages
#     print("\n\nRestarting the Python runtime! Please (re-)run the cells below.")
#     time.sleep(1)
#     os.kill(os.getpid(), signal.SIGKILL)
# else:
#     !pip install ai-economist

# %%
# Import foundation
import os, signal, sys, time

sys.path.append(r'C:\Users\adria\coding\katja\DRL-in-international-economy-ai-economist-')

from ai_economist import foundation

# %%
# Change directory to the tutorials folder
import os, sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    os.chdir("/content/ai-economist/tutorials")
else:
    os.chdir(os.path.dirname(os.path.abspath("__file__"))
)

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython import display
from utils import plotting  # plotting utilities for visualizing env. state

# %% [markdown]
# # 1. Markov Decision Process
#
# Formally, our economic simulation is a key part of a Markov Decision Process (MDP).
#
# MDPs describe episodes in which agents interact with a stateful environment in a continuous feedback loop. At each timestep, agents receive an observation and use a policy to choose actions. The environment then advances to a new state, using the old state and the chosen actions. The agents then receive new observations and rewards. This process repeats over $T$ timesteps (possibly infinite).
#
# The goal of each agent is to maximize its expected sum of future (discounted) rewards, by finding its optimal policy. Intuitively, this means that an agent needs to understand which (sequence of) actions lead to high rewards (in expectation).
#
# ### References
#
# For more information on reinforcement learning and MDPs, check out:
#
# - Richard S. Sutton and Andrew G. Barto, Reinforcement Learning: An Introduction. [http://incompleteideas.net/book/bookdraft2017nov5.pdf](http://incompleteideas.net/book/bookdraft2017nov5.pdf)

# %% [markdown]
# # 2. Creating a Simulation Environment (a Scenario Instance)
#
# The Scenario class implements an economic simulation with multiple agents and (optionally) a social planner.
#
# Scenarios provide a high-level gym-style API that lets agents interact with it. The API supports multi-agent observations, actions, etc.
#
# Each Scenario is stateful and implements two main methods:
#
# - __step__, which advances the simulation to the next state, and
# - __reset__, which puts the simulation back in an initial state.
#
# Each Scenario is customizable: you can specify options in a dictionary. Here is an example for a scenario with 4 agents:
#
# **Note: This config dictionary will likely seem fairly incomprehensible at this point in the tutorials. Don't worry. The advanced tutorial offers much more context. This is just to get things started and to provide a reference for how to create a "free market" economy from the AI Economist.**

# %%
# Define the configuration of the environment that will be built

env_config_original = {
    # ===== SCENARIO CLASS =====
    # Which Scenario class to use: the class's name in the Scenario Registry (foundation.scenarios).
    # The environment object will be an instance of the Scenario class.
    'scenario_name': 'layout_from_file/simple_wood_and_stone',
    
    # ===== COMPONENTS =====
    # Which components to use (specified as list of ("component_name", {component_kwargs}) tuples).
    #   "component_name" refers to the Component class's name in the Component Registry (foundation.components)
    #   {component_kwargs} is a dictionary of kwargs passed to the Component class
    # The order in which components reset, step, and generate obs follows their listed order below.
    'components': [
        # (1) Building houses
        ('Build', {'skill_dist': "pareto", 'payment_max_skill_multiplier': 3}),
        # (2) Trading collectible resources
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        # (3) Movement and resource collection
        ('Gather', {}),
    ],
    
    # ===== SCENARIO CLASS ARGUMENTS =====
    # (optional) kwargs that are added by the Scenario class (i.e. not defined in BaseEnvironment)
    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': True,
    
    # ===== STANDARD ARGUMENTS ======
    # kwargs that are used by every Scenario class (i.e. defined in BaseEnvironment)
    'n_agents': 4,          # Number of non-planner agents (must be > 1)
    'world_size': [25, 25], # [Height, Width] of the env world
    'episode_length': 1000, # Number of timesteps per episode
    
    # In multi-action-mode, the policy selects an action for each action subspace (defined in component code).
    # Otherwise, the policy selects only 1 action.
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    
    # When flattening observations, concatenate scalar & vector observations before output.
    # Otherwise, return observations with minimal processing.
    'flatten_observations': False,
    # When Flattening masks, concatenate each action subspace mask into a single array.
    # Note: flatten_masks = True is required for masking action logits in the code below.
    'flatten_masks': True,
}

# %%
env_config = {
    # ===== SCENARIO CLASS =====
    'scenario_name': 'layout_from_file/simple_wood_and_stone',

    # ===== COMPONENTS =====
    'components': [
        # (1) Building houses (REQUIRES payment when using fixed_four_skill_and_loc=True)
        ('Build', {
            'payment': 10.0,                    # <-- REQUIRED for LayoutFromFile fixed_four_skill_and_loc
            'skill_dist': "pareto",             # <-- REQUIRED
            'payment_max_skill_multiplier': 3   # good
        }),
        # (2) Trading collectible resources
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        # (3) Movement and resource collection
        ('Gather', {}),
    ],

    # ===== SCENARIO CLASS ARGUMENTS =====
    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': True,  # <-- works only if Build.payment is set as above

    # ===== STANDARD ARGUMENTS ======
    'n_agents': 4,
    'world_size': [25, 25],
    'episode_length': 1000,

    # multi-action mode (optional; leaving your choices)
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,

    # flattening options (fine as-is)
    'flatten_observations': False,
    'flatten_masks': True,
}

# %% [markdown]
# Create an environment instance using this configuration:

# %%
env = foundation.make_env_instance(**env_config)

# %% [markdown]
# # 3. Interacting with the Simulation

# %% [markdown]
# ### Agents
#
# The Agent class holds the state of agents in the simulation. Each Agent instance represents a _logical_ agent.
#
# _Note that this might be separate from a Policy model that lives outside the Scenario and controls the Agent's behavior._

# %%
env.get_agent(0)

# %% [markdown]
# ### A random policy
#
# Now let's interact with the simulation.
#
# Each Agent needs to choose which actions to execute using a __policy__.
#
# Agents might not always be allowed to execute all actions. For instance, a mobile Agent cannot move beyond the boundary of the world. Hence, in position (0, 0), a mobile cannot move "Left" or "Down". This information is given by a mask, which is provided under ```obs[<agent_id_str>]["action_mask"]``` in the observation dictionary ```obs``` returned by the scenario.
#
# Let's use a random policy to step through the simulation. The methods below implement a random policy.

# %%
# Note: The code for sampling actions (this cell), and playing an episode (below) are general.  
# That is, it doesn't depend on the Scenario and Component classes used in the environment!

def sample_random_action(agent, mask):
    """Sample random UNMASKED action(s) for agent."""
    # Return a list of actions: 1 for each action subspace
    if agent.multi_action_mode:
        split_masks = np.split(mask, agent.action_spaces.cumsum()[:-1])
        return [np.random.choice(np.arange(len(m_)), p=m_/m_.sum()) for m_ in split_masks]

    # Return a single action
    else:
        return np.random.choice(np.arange(agent.action_spaces), p=mask/mask.sum())

def sample_random_actions(env, obs):
    """Samples random UNMASKED actions for each agent in obs."""
        
    actions = {
        a_idx: sample_random_action(env.get_agent(a_idx), a_obs['action_mask'])
        for a_idx, a_obs in obs.items()
    }

    return actions

# %% [markdown]
# Now we're ready to interact with the simulation...
#
# First, environments can be put in an initial state by using __reset__.

# %%
obs = env.reset()

# %% [markdown]
# Then, we call __step__ to advance the state and advance time by one tick.

# %%
actions = sample_random_actions(env, obs)
obs, rew, done, info = env.step(actions)

# %% [markdown]
# Internally, the __step__ method composes several Components (which act almost like modular sub-Environments) that implement various agent affordances and environment dynamics. For more detailed information on Components and how to implement custom Component classes, see the advanced tutorial. For this tutorial, we will continue to inspect the information that __step__ returns and run a full episode in the simulation.

# %% [markdown]
# ### Observation
#
# Each observation is a dictionary that contains information for the $N$ agents and (optionally) social planner (with id "p").

# %%
obs.keys()
# Out:
# dict_keys(['0', '1', '2', '3', 'p'])

# %% [markdown]
# For each agent, the agent-specific observation is a dictionary. Each Component can contribute information to the agent-specific observation. For instance, the Build Component contributes the
#
# - Build-build_payment (float)
# - Build-build_skill (int)
#
# fields, which are defined in the ```generate_observations``` method in [foundation/components/build.py](https://github.com/salesforce/ai-economist/blob/master/ai_economist/foundation/components/build.py).

# %%
for key, val in obs['0'].items(): 
    print("{:50} {}".format(key, type(val)))
# Out:
# world-map                                          <class 'numpy.ndarray'>
# world-idx_map                                      <class 'numpy.ndarray'>
# world-loc-row                                      <class 'numpy.float64'>
# world-loc-col                                      <class 'numpy.float64'>
# world-inventory-Coin                               <class 'float'>
# world-inventory-Stone                              <class 'float'>
# world-inventory-Wood                               <class 'float'>
# time                                               <class 'list'>
# Build-build_payment                                <class 'numpy.float64'>
# Build-build_skill                                  <class 'float'>
# ContinuousDoubleAuction-market_rate-Stone          <class 'numpy.float64'>
# ContinuousDoubleAuction-price_history-Stone        <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_asks-Stone       <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_bids-Stone       <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_asks-Stone              <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_bids-Stone              <class 'numpy.ndarray'>
# ContinuousDoubleAuction-market_rate-Wood           <class 'numpy.float64'>
# ContinuousDoubleAuction-price_history-Wood         <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_asks-Wood        <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_bids-Wood        <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_asks-Wood               <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_bids-Wood               <class 'numpy.ndarray'>
# Gather-bonus_gather_prob                           <class 'float'>
# action_mask                                        <class 'numpy.ndarray'>

# %% [markdown]
# ### Reward
#
# For each agent / planner, the reward dictionary contains a scalar reward:

# %%
for agent_idx, reward in rew.items(): 
    print("{:2} {:.3f}".format(agent_idx, reward))
# Out:
# 0  -0.263
# 1  -0.053
# 2  -0.263
# 3  -0.053
# p  0.000

# %% [markdown]
# ### Done
#
# The __done__ object is a dictionary that by default records whether all agents have seen the end of the episode. The default criterion for each agent is to 'stop' their episode once $H$ steps have been executed. Once an agent is 'done', they do not change their state anymore. So, while it's not currently implemented, this could be used to indicate that the episode has ended *for a specific Agent*.
#
# In general, this is useful for telling a Reinforcement Learning framework when to reset the environment and how to organize the trajectories of individual Agents.

# %%
done
# Out:
# {'__all__': False}

# %% [markdown]
# ### Info
#
# The __info__ object can record any auxiliary information from the simulator, which can be useful, e.g., for visualization. By default, this is empty. To modify this behavior, modify the step() method in [foundation/base/base_env.py](https://github.com/salesforce/ai-economist/blob/master/ai_economist/foundation/base/base_env.py).

# %%
info
# Out:
# {'0': {}, '1': {}, '2': {}, '3': {}, 'p': {}}

# %%
agent0 = env.get_agent(agent_idx=0)
print(agent0.inventory)
print(agent0.endogenous)
# Out:
# {'Coin': 2.0, 'Stone': 1, 'Wood': 0}
# {'Labor': 1.25}

# %%
planner = env.get_agent(agent_idx='p')
planner.state
agent0.state
# Out:
# {'loc': [np.int32(24), np.int32(0)],
#  'inventory': {'Coin': 2.0, 'Stone': 1, 'Wood': 0},
#  'escrow': {'Coin': 8.0, 'Stone': 0, 'Wood': 0},
#  'endogenous': {'Labor': 1.25},
#  'build_payment': np.float64(13.267112338979295),
#  'build_skill': 0.630928922606679,
#  'bonus_gather_prob': 0.0}

# %%
env.world.agents[0].state
# Out:
# {'loc': [np.int32(24), np.int32(0)],
#  'inventory': {'Coin': 2.0, 'Stone': 1, 'Wood': 0},
#  'escrow': {'Coin': 8.0, 'Stone': 0, 'Wood': 0},
#  'endogenous': {'Labor': 1.25},
#  'build_payment': np.float64(13.267112338979295),
#  'build_skill': 0.630928922606679,
#  'bonus_gather_prob': 0.0}

# %%
metrics = env.get_current_optimization_metrics()
metrics
# Out:
# {0: 6.086118900721934,
#  1: 6.296118900721934,
#  2: 6.086118900721934,
#  3: 6.296118900721934,
#  'p': np.float64(10.0)}

# %% [markdown]
# # 3. Sampling and Visualizing an Episode
#
# Let's step multiple times with this random policy and visualize the result:

# %%
def do_plot(env, ax, fig):
    """Plots world state during episode sampling."""
    plotting.plot_env_state(env, ax)
    ax.set_aspect('equal')
    display.display(fig)
    display.clear_output(wait=True)

def play_random_episode(env, plot_every=100, do_dense_logging=False):
    """Plays an episode with randomly sampled actions.
    
    Demonstrates gym-style API:
        obs                  <-- env.reset(...)         # Reset
        obs, rew, done, info <-- env.step(actions, ...) # Interaction loop
    
    """
    fig, ax = plt.subplots(1, 1, figsize=(10, 10))

    # Reset
    obs = env.reset(force_dense_logging=do_dense_logging)

    env._world_dense_log_frequency = 1 #NEW

    # Interaction loop (w/ plotting)
    for t in range(env.episode_length):
        actions = sample_random_actions(env, obs)
        obs, rew, done, info = env.step(actions)

        if ((t+1) % plot_every) == 0:
            do_plot(env, ax, fig)

    if ((t+1) % plot_every) != 0:
        do_plot(env, ax, fig)

# %%
play_random_episode(env, plot_every=100)

# %% [markdown]
# We see four agents (indicated by a circled __\*__) that move around in the 2-dimensional world. Light brown cells contain Stone, green cells contain Wood. Each agent can build Houses, indicated by corresponding colored cells. Water tiles (blue squares), which prevent movement, divide the map into four quadrants.
#
# Note: this is showing the same information as the image at the top of the tutorial -- it just uses a much more simplistic rendering.

# %% [markdown]
# # Visualize using dense logging
#
# Environments built with Foundation provide a couple tools for logging. Perhaps the most useful are **dense logs**. When you reset the environment, you can tell it to create a dense log for the new episode. This will store Agent states at each point in time along with any Component-specific dense log information (say, about builds, trades, etc.) that the Components provide. In addition, it will periodically store a snapshot of the world state.
#
# We provide a few plotting tools that work well with the type of environment showcased here.

# %%
# Play another episode. This time, tell the environment to do dense logging
play_random_episode(env, plot_every=100, do_dense_logging=True)

# Grab the dense log from the env
dense_log = env.previous_episode_dense_log

plotting.breakdown(dense_log)
# Out:
# _______________:_ Agent  0 _____|_ Agent  1 _____|_ Agent  2 _____|_ Agent  3 ____
# Cost (Wood)    :   6.20 (n= 66) |   5.64 (n= 61) |   6.06 (n= 68) |   6.25 (n= 36)
# Cost (Stone)   :   6.62 (n= 47) |   6.09 (n= 32) |   6.16 (n= 43) |   7.50 (n= 26)
#
# Income (Wood)  :   6.23 (n= 61) |   5.79 (n= 61) |   5.63 (n= 71) |   6.76 (n= 38)
# Income (Stone) :   6.58 (n= 50) |   6.80 (n= 30) |   6.07 (n= 44) |   6.92 (n= 24)
# Income (Build) :  13.27 (n=  9) |  11.33 (n=  2) |  16.47 (n= 15) |  22.25 (n=  3)
# ((<Figure size 1600x300 with 5 Axes>,
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 1600x800 with 8 Axes>),
#  {'Sell Stone': [329, 204, 267, 166],
#   'Buy Stone': [-311, -195, -265, -195],
#   'Sell Wood': [380, 353, 400, 257],
#   'Buy Wood': [-409, -344, -412, -225],
#   'Build': [119.4040110508137,
#    22.663281247180194,
#    247.085594205092,
#    66.7488429131872],
#   'Total': array([108.40401105,  40.66328125, 237.08559421,  69.74884291])},
#  [118, 50, 247, 79],
#  {'Stone': [{'t': 1,
#     't_ask': 1,
#     't_bid': 0,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 61,
#     't_ask': 54,
#     't_bid': 61,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 7,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 70,
#     't_ask': 70,
#     't_bid': 63,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 7,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 71,
#     't_ask': 71,
#     't_bid': 62,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 9,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 102,
#     't_ask': 64,
#     't_bid': 102,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 38,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 103,
#     't_ask': 103,
#     't_bid': 103,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 117,
#     't_ask': 117,
#     't_bid': 71,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 46,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 119,
#     't_ask': 119,
#     't_bid': 118,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 125,
#     't_ask': 125,
#     't_bid': 125,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 159,
#     't_ask': 159,
#     't_bid': 128,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 31,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 160,
#     't_ask': 160,
#     't_bid': 129,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 31,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 166,
#     't_ask': 165,
#     't_bid': 166,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 172,
#     't_ask': 127,
#     't_bid': 172,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 45,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 173,
#     't_ask': 155,
#     't_bid': 173,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 18,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 174,
#     't_ask': 174,
#     't_bid': 132,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 42,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 175,
#     't_ask': 160,
#     't_bid': 175,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 15,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 177,
#     't_ask': 170,
#     't_bid': 177,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 7,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 178,
#     't_ask': 178,
#     't_bid': 175,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 184,
#     't_ask': 179,
#     't_bid': 184,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 5,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 225,
#     't_ask': 225,
#     't_bid': 212,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 232,
#     't_ask': 214,
#     't_bid': 232,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 18,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 233,
#     't_ask': 233,
#     't_bid': 227,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 6,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 234,
#     't_ask': 233,
#     't_bid': 234,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 236,
#     't_ask': 236,
#     't_bid': 231,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 5,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 237,
#     't_ask': 237,
#     't_bid': 237,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 267,
#     't_ask': 229,
#     't_bid': 267,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 38,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 268,
#     't_ask': 268,
#     't_bid': 268,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 269,
#     't_ask': 269,
#     't_bid': 242,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 27,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 271,
#     't_ask': 271,
#     't_bid': 245,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 26,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 272,
#     't_ask': 272,
#     't_bid': 222,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 50,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 275,
#     't_ask': 275,
#     't_bid': 235,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 40,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 277,
#     't_ask': 277,
#     't_bid': 277,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 286,
#     't_ask': 286,
#     't_bid': 273,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 287,
#     't_ask': 287,
#     't_bid': 274,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 13,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 289,
#     't_ask': 287,
#     't_bid': 289,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 290,
#     't_ask': 285,
#     't_bid': 290,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 5,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 292,
#     't_ask': 292,
#     't_bid': 278,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 14,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 294,
#     't_ask': 294,
#     't_bid': 275,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 19,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 295,
#     't_ask': 295,
#     't_bid': 259,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 36,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 296,
#     't_ask': 294,
#     't_bid': 296,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 299,
#     't_ask': 299,
#     't_bid': 297,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 321,
#     't_ask': 321,
#     't_bid': 303,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 18,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 330,
#     't_ask': 280,
#     't_bid': 330,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 50,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 331,
#     't_ask': 292,
#     't_bid': 331,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 39,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 348,
#     't_ask': 348,
#     't_bid': 322,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 26,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 349,
#     't_ask': 349,
#     't_bid': 347,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 351,
#     't_ask': 340,
#     't_bid': 351,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 11,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 352,
#     't_ask': 352,
#     't_bid': 344,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 8,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 354,
#     't_ask': 323,
#     't_bid': 354,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 31,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 376,
#     't_ask': 376,
#     't_bid': 356,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 20,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 377,
#     't_ask': 377,
#     't_bid': 327,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 50,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 380,
#     't_ask': 380,
#     't_bid': 353,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 27,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 383,
#     't_ask': 383,
#     't_bid': 381,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 384,
#     't_ask': 378,
#     't_bid': 384,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 6,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 385,
#     't_ask': 385,
#     't_bid': 384,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 387,
#     't_ask': 387,
#     't_bid': 382,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 5,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 390,
#     't_ask': 390,
#     't_bid': 342,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 48,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 397,
#     't_ask': 391,
#     't_bid': 397,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 6,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 399,
#     't_ask': 399,
#     't_bid': 391,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 8,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 406,
#     't_ask': 386,
#     't_bid': 406,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 20,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 445,
#     't_ask': 445,
#     't_bid': 429,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 16,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 453,
#     't_ask': 453,
#     't_bid': 411,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 42,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 454,
#     't_ask': 408,
#     't_bid': 454,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 46,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 456,
#     't_ask': 456,
#     't_bid': 410,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 46,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 457,
#     't_ask': 439,
#     't_bid': 457,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 10,
#     'ask_lifetime': 18,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 459,
#     't_ask': 459,
#     't_bid': 438,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 463,
#     't_ask': 463,
#     't_bid': 440,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 464,
#     't_ask': 464,
#     't_bid': 430,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 34,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 500,
#     't_ask': 500,
#     't_bid': 457,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 43,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 506,
#     't_ask': 506,
#     't_bid': 466,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 40,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 508,
#     't_ask': 508,
#     't_bid': 508,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 509,
#     't_ask': 509,
#     't_bid': 509,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 510,
#     't_ask': 510,
#     't_bid': 508,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 511,
#     't_ask': 511,
#     't_bid': 463,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 48,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 512,
#     't_ask': 511,
#     't_bid': 512,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 516,
#     't_ask': 516,
#     't_bid': 514,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 519,
#     't_ask': 519,
#     't_bid': 514,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 519,
#     't_ask': 517,
#     't_bid': 519,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 2,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 520,
#     't_ask': 519,
#     't_bid': 520,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 1,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 521,
#     't_ask': 521,
#     't_bid': 520,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 521,
#     't_ask': 521,
#     't_bid': 520,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 523,
#     't_ask': 523,
#     't_bid': 501,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 22,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 554,
#     't_ask': 524,
#     't_bid': 554,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 30,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 566,
#     't_ask': 524,
#     't_bid': 566,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 42,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 567,
#     't_ask': 567,
#     't_bid': 556,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 11,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 568,
#     't_ask': 568,
#     't_bid': 568,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 569,
#     't_ask': 521,
#     't_bid': 569,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 48,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 575,
#     't_ask': 571,
#     't_bid': 575,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 4,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 584,
#     't_ask': 584,
#     't_bid': 575,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 9,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 587,
#     't_ask': 587,
#     't_bid': 576,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 11,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 597,
#     't_ask': 597,
#     't_bid': 577,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 20,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 600,
#     't_ask': 569,
#     't_bid': 600,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 31,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 606,
#     't_ask': 598,
#     't_bid': 606,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 8,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 609,
#     't_ask': 607,
#     't_bid': 609,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 610,
#     't_ask': 610,
#     't_bid': 575,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 35,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 611,
#     't_ask': 570,
#     't_bid': 611,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 41,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 611,
#     't_ask': 598,
#     't_bid': 611,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 13,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 612,
#     't_ask': 612,
#     't_bid': 578,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 34,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 613,
#     't_ask': 613,
#     't_bid': 570,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 43,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 615,
#     't_ask': 566,
#     't_bid': 615,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 49,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 616,
#     't_ask': 616,
#     't_bid': 616,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 620,
#     't_ask': 620,
#     't_bid': 614,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 6,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 622,
#     't_ask': 622,
#     't_bid': 621,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 641,
#     't_ask': 641,
#     't_bid': 618,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 642,
#     't_ask': 642,
#     't_bid': 623,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 19,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 642,
#     't_ask': 642,
#     't_bid': 636,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 6,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 643,
#     't_ask': 623,
#     't_bid': 643,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 20,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 653,
#     't_ask': 643,
#     't_bid': 653,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 10,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 654,
#     't_ask': 654,
#     't_bid': 653,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 655,
#     't_ask': 655,
#     't_bid': 629,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 26,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 660,
#     't_ask': 660,
#     't_bid': 656,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 663,
#     't_ask': 661,
#     't_bid': 663,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 2,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 664,
#     't_ask': 664,
#     't_bid': 654,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 665,
#     't_ask': 656,
#     't_bid': 665,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 9,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 667,
#     't_ask': 667,
#     't_bid': 663,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 668,
#     't_ask': 668,
#     't_bid': 668,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 695,
#     't_ask': 661,
#     't_bid': 695,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 10,
#     'ask_lifetime': 34,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 706,
#     't_ask': 706,
#     't_bid': 665,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 41,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 711,
#     't_ask': 711,
#     't_bid': 696,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 15,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 712,
#     't_ask': 712,
#     't_bid': 697,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 15,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 715,
#     't_ask': 670,
#     't_bid': 715,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 10,
#     'ask_lifetime': 45,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 717,
#     't_ask': 717,
#     't_bid': 669,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 48,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 717,
#     't_ask': 717,
#     't_bid': 670,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 47,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 719,
#     't_ask': 719,
#     't_bid': 719,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 720,
#     't_ask': 720,
#     't_bid': 718,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 749,
#     't_ask': 749,
#     't_bid': 721,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 28,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 774,
#     't_ask': 774,
#     't_bid': 765,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 9,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 775,
#     't_ask': 775,
#     't_bid': 771,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 776,
#     't_ask': 776,
#     't_bid': 771,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 799,
#     't_ask': 781,
#     't_bid': 799,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 18,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 831,
#     't_ask': 800,
#     't_bid': 831,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 31,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 850,
#     't_ask': 833,
#     't_bid': 850,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 10,
#     'ask_lifetime': 17,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 851,
#     't_ask': 851,
#     't_bid': 850,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 853,
#     't_ask': 853,
#     't_bid': 826,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 27,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 864,
#     't_ask': 864,
#     't_bid': 857,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 7,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 865,
#     't_ask': 865,
#     't_bid': 852,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 13,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 894,
#     't_ask': 894,
#     't_bid': 854,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 40,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 895,
#     't_ask': 895,
#     't_bid': 880,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 15,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 896,
#     't_ask': 896,
#     't_bid': 867,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 29,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 897,
#     't_ask': 897,
#     't_bid': 897,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 904,
#     't_ask': 903,
#     't_bid': 904,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 1,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 920,
#     't_ask': 920,
#     't_bid': 919,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 921,
#     't_ask': 917,
#     't_bid': 921,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 4,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 929,
#     't_ask': 924,
#     't_bid': 929,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 5,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 930,
#     't_ask': 930,
#     't_bid': 930,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 935,
#     't_ask': 935,
#     't_bid': 935,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 987,
#     't_ask': 987,
#     't_bid': 985,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 989,
#     't_ask': 989,
#     't_bid': 956,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 33,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10}],
#   'Wood': [{'t': 2,
#     't_ask': 2,
#     't_bid': 0,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 4,
#     't_ask': 3,
#     't_bid': 4,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 1,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 4,
#     't_ask': 3,
#     't_bid': 4,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 5,
#     't_ask': 5,
#     't_bid': 1,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 7,
#     't_ask': 7,
#     't_bid': 3,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 8,
#     't_ask': 8,
#     't_bid': 6,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 10,
#     't_ask': 10,
#     't_bid': 10,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 11,
#     't_ask': 11,
#     't_bid': 2,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 9,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 15,
#     't_ask': 15,
#     't_bid': 13,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 57,
#     't_ask': 9,
#     't_bid': 57,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 48,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 58,
#     't_ask': 14,
#     't_bid': 58,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 44,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 60,
#     't_ask': 19,
#     't_bid': 60,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 41,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 64,
#     't_ask': 23,
#     't_bid': 64,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 41,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 65,
#     't_ask': 65,
#     't_bid': 59,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 6,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 68,
#     't_ask': 68,
#     't_bid': 20,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 1,
#     'bid_lifetime': 48,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 70,
#     't_ask': 58,
#     't_bid': 70,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 12,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 74,
#     't_ask': 74,
#     't_bid': 69,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 76,
#     't_ask': 76,
#     't_bid': 75,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 77,
#     't_ask': 77,
#     't_bid': 62,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 15,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 80,
#     't_ask': 80,
#     't_bid': 79,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 81,
#     't_ask': 81,
#     't_bid': 73,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 8,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 83,
#     't_ask': 83,
#     't_bid': 75,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 8,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 114,
#     't_ask': 81,
#     't_bid': 114,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 33,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 115,
#     't_ask': 115,
#     't_bid': 79,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 36,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 119,
#     't_ask': 119,
#     't_bid': 116,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 121,
#     't_ask': 83,
#     't_bid': 121,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 38,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 122,
#     't_ask': 122,
#     't_bid': 120,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 127,
#     't_ask': 127,
#     't_bid': 125,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 128,
#     't_ask': 128,
#     't_bid': 123,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 129,
#     't_ask': 129,
#     't_bid': 123,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 6,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 131,
#     't_ask': 130,
#     't_bid': 131,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 1,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 135,
#     't_ask': 135,
#     't_bid': 131,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 136,
#     't_ask': 136,
#     't_bid': 126,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 10,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 137,
#     't_ask': 137,
#     't_bid': 136,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 138,
#     't_ask': 138,
#     't_bid': 132,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 6,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 140,
#     't_ask': 134,
#     't_bid': 140,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 10,
#     'ask_lifetime': 6,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 185,
#     't_ask': 185,
#     't_bid': 139,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 46,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 186,
#     't_ask': 186,
#     't_bid': 181,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 186,
#     't_ask': 186,
#     't_bid': 139,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 47,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 191,
#     't_ask': 191,
#     't_bid': 187,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 4,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 194,
#     't_ask': 194,
#     't_bid': 172,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 22,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 220,
#     't_ask': 220,
#     't_bid': 179,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 41,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 223,
#     't_ask': 223,
#     't_bid': 195,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 28,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 228,
#     't_ask': 221,
#     't_bid': 228,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 7,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 229,
#     't_ask': 192,
#     't_bid': 229,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 37,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 238,
#     't_ask': 195,
#     't_bid': 238,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 43,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 240,
#     't_ask': 240,
#     't_bid': 229,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 11,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 246,
#     't_ask': 246,
#     't_bid': 239,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 7,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 247,
#     't_ask': 247,
#     't_bid': 240,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 7,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 247,
#     't_ask': 247,
#     't_bid': 243,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 250,
#     't_ask': 250,
#     't_bid': 237,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 13,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 251,
#     't_ask': 251,
#     't_bid': 242,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 9,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 251,
#     't_ask': 251,
#     't_bid': 230,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 21,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 252,
#     't_ask': 252,
#     't_bid': 248,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 254,
#     't_ask': 254,
#     't_bid': 254,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
# ...
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 707,
#     't_ask': 707,
#     't_bid': 707,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 708,
#     't_ask': 708,
#     't_bid': 708,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 709,
#     't_ask': 709,
#     't_bid': 708,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 710,
#     't_ask': 710,
#     't_bid': 710,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 712,
#     't_ask': 712,
#     't_bid': 710,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 713,
#     't_ask': 713,
#     't_bid': 674,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 39,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 725,
#     't_ask': 718,
#     't_bid': 725,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 7,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 755,
#     't_ask': 755,
#     't_bid': 734,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 757,
#     't_ask': 757,
#     't_bid': 726,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 31,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 758,
#     't_ask': 758,
#     't_bid': 737,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 759,
#     't_ask': 759,
#     't_bid': 759,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 765,
#     't_ask': 765,
#     't_bid': 732,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 33,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 766,
#     't_ask': 766,
#     't_bid': 718,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 48,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 767,
#     't_ask': 767,
#     't_bid': 754,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 768,
#     't_ask': 768,
#     't_bid': 768,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 769,
#     't_ask': 769,
#     't_bid': 769,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 772,
#     't_ask': 772,
#     't_bid': 766,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 6,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 773,
#     't_ask': 773,
#     't_bid': 726,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 47,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 776,
#     't_ask': 776,
#     't_bid': 734,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 42,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 804,
#     't_ask': 804,
#     't_bid': 777,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 27,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 813,
#     't_ask': 813,
#     't_bid': 812,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 814,
#     't_ask': 814,
#     't_bid': 814,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 815,
#     't_ask': 815,
#     't_bid': 802,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 816,
#     't_ask': 816,
#     't_bid': 816,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 817,
#     't_ask': 814,
#     't_bid': 817,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 3,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 821,
#     't_ask': 821,
#     't_bid': 775,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 46,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 822,
#     't_ask': 817,
#     't_bid': 822,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 5,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 823,
#     't_ask': 823,
#     't_bid': 823,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 856,
#     't_ask': 825,
#     't_bid': 856,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 31,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 858,
#     't_ask': 858,
#     't_bid': 822,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 36,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 861,
#     't_ask': 861,
#     't_bid': 861,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 869,
#     't_ask': 863,
#     't_bid': 869,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 6,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 912,
#     't_ask': 912,
#     't_bid': 869,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 43,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 913,
#     't_ask': 913,
#     't_bid': 863,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 50,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 914,
#     't_ask': 914,
#     't_bid': 864,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 50,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 914,
#     't_ask': 914,
#     't_bid': 876,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 38,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 914,
#     't_ask': 914,
#     't_bid': 879,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 35,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 915,
#     't_ask': 915,
#     't_bid': 911,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 916,
#     't_ask': 916,
#     't_bid': 916,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 918,
#     't_ask': 918,
#     't_bid': 918,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 918,
#     't_ask': 918,
#     't_bid': 917,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 922,
#     't_ask': 922,
#     't_bid': 915,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 7,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 923,
#     't_ask': 916,
#     't_bid': 923,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 7,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 925,
#     't_ask': 924,
#     't_bid': 925,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 926,
#     't_ask': 926,
#     't_bid': 876,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 50,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 928,
#     't_ask': 926,
#     't_bid': 928,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 2,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 931,
#     't_ask': 931,
#     't_bid': 929,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 931,
#     't_ask': 931,
#     't_bid': 929,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 932,
#     't_ask': 932,
#     't_bid': 917,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 15,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 966,
#     't_ask': 966,
#     't_bid': 961,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 967,
#     't_ask': 919,
#     't_bid': 967,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 48,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 968,
#     't_ask': 968,
#     't_bid': 935,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 33,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 969,
#     't_ask': 969,
#     't_bid': 969,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 978,
#     't_ask': 978,
#     't_bid': 971,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 7,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 979,
#     't_ask': 979,
#     't_bid': 976,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 980,
#     't_ask': 932,
#     't_bid': 980,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 48,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 981,
#     't_ask': 981,
#     't_bid': 981,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 982,
#     't_ask': 982,
#     't_bid': 981,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 983,
#     't_ask': 983,
#     't_bid': 983,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1}]},
#  [{'t': 49, 'builder': 2, 'loc': [4, 1], 'income': 16.472372947006132},
#   {'t': 61, 'builder': 2, 'loc': [8, 0], 'income': 16.472372947006132},
#   {'t': 93, 'builder': 2, 'loc': [9, 2], 'income': 16.472372947006132},
#   {'t': 110, 'builder': 1, 'loc': [5, 20], 'income': 11.331640623590097},
#   {'t': 191, 'builder': 1, 'loc': [8, 24], 'income': 11.331640623590097},
#   {'t': 263, 'builder': 0, 'loc': [13, 3], 'income': 13.267112338979295},
#   {'t': 287, 'builder': 2, 'loc': [5, 0], 'income': 16.472372947006132},
#   {'t': 299, 'builder': 2, 'loc': [6, 0], 'income': 16.472372947006132},
#   {'t': 304, 'builder': 2, 'loc': [8, 1], 'income': 16.472372947006132},
#   {'t': 306, 'builder': 0, 'loc': [12, 7], 'income': 13.267112338979295},
#   {'t': 328, 'builder': 0, 'loc': [13, 8], 'income': 13.267112338979295},
#   {'t': 348, 'builder': 0, 'loc': [17, 10], 'income': 13.267112338979295},
#   {'t': 351, 'builder': 2, 'loc': [7, 2], 'income': 16.472372947006132},
#   {'t': 392, 'builder': 2, 'loc': [8, 4], 'income': 16.472372947006132},
#   {'t': 431, 'builder': 2, 'loc': [1, 4], 'income': 16.472372947006132},
#   {'t': 491, 'builder': 2, 'loc': [2, 0], 'income': 16.472372947006132},
#   {'t': 534, 'builder': 0, 'loc': [11, 11], 'income': 13.267112338979295},
#   {'t': 568, 'builder': 0, 'loc': [8, 3], 'income': 13.267112338979295},
#   {'t': 593, 'builder': 0, 'loc': [7, 3], 'income': 13.267112338979295},
#   {'t': 603, 'builder': 0, 'loc': [5, 3], 'income': 13.267112338979295},
#   {'t': 613, 'builder': 2, 'loc': [10, 1], 'income': 16.472372947006132},
#   {'t': 621, 'builder': 0, 'loc': [4, 4], 'income': 13.267112338979295},
#   {'t': 657, 'builder': 2, 'loc': [9, 5], 'income': 16.472372947006132},
#   {'t': 677, 'builder': 2, 'loc': [9, 6], 'income': 16.472372947006132},
#   {'t': 678, 'builder': 3, 'loc': [8, 12], 'income': 22.249614304395735},
#   {'t': 699, 'builder': 3, 'loc': [5, 12], 'income': 22.249614304395735},
#   {'t': 718, 'builder': 3, 'loc': [7, 13], 'income': 22.249614304395735},
#   {'t': 751, 'builder': 2, 'loc': [2, 7], 'income': 16.472372947006132},
#   {'t': 937, 'builder': 2, 'loc': [10, 8], 'income': 16.472372947006132}])

# %%
# Show the evolution of the world state from t=0 to t=200
fig = plotting.vis_world_range(dense_log, t0=0, tN=200, N=5)

# %%
# Show the evolution of the world state over the full episode
fig = plotting.vis_world_range(dense_log, N=5)

# %%
# Use the "breakdown" tool to visualize the world state, agent-wise quantities, movement, and trading events
plotting.breakdown(dense_log)
# Out:
# _______________:_ Agent  0 _____|_ Agent  1 _____|_ Agent  2 _____|_ Agent  3 ____
# Cost (Wood)    :   6.20 (n= 66) |   5.64 (n= 61) |   6.06 (n= 68) |   6.25 (n= 36)
# Cost (Stone)   :   6.62 (n= 47) |   6.09 (n= 32) |   6.16 (n= 43) |   7.50 (n= 26)
#
# Income (Wood)  :   6.23 (n= 61) |   5.79 (n= 61) |   5.63 (n= 71) |   6.76 (n= 38)
# Income (Stone) :   6.58 (n= 50) |   6.80 (n= 30) |   6.07 (n= 44) |   6.92 (n= 24)
# Income (Build) :  13.27 (n=  9) |  11.33 (n=  2) |  16.47 (n= 15) |  22.25 (n=  3)
# ((<Figure size 1600x300 with 5 Axes>,
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 1600x800 with 8 Axes>),
#  {'Sell Stone': [329, 204, 267, 166],
#   'Buy Stone': [-311, -195, -265, -195],
#   'Sell Wood': [380, 353, 400, 257],
#   'Buy Wood': [-409, -344, -412, -225],
#   'Build': [119.4040110508137,
#    22.663281247180194,
#    247.085594205092,
#    66.7488429131872],
#   'Total': array([108.40401105,  40.66328125, 237.08559421,  69.74884291])},
#  [118, 50, 247, 79],
#  {'Stone': [{'t': 1,
#     't_ask': 1,
#     't_bid': 0,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 61,
#     't_ask': 54,
#     't_bid': 61,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 7,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 70,
#     't_ask': 70,
#     't_bid': 63,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 7,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 71,
#     't_ask': 71,
#     't_bid': 62,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 9,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 102,
#     't_ask': 64,
#     't_bid': 102,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 38,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 103,
#     't_ask': 103,
#     't_bid': 103,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 117,
#     't_ask': 117,
#     't_bid': 71,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 46,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 119,
#     't_ask': 119,
#     't_bid': 118,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 125,
#     't_ask': 125,
#     't_bid': 125,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 159,
#     't_ask': 159,
#     't_bid': 128,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 31,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 160,
#     't_ask': 160,
#     't_bid': 129,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 31,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 166,
#     't_ask': 165,
#     't_bid': 166,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 172,
#     't_ask': 127,
#     't_bid': 172,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 45,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 173,
#     't_ask': 155,
#     't_bid': 173,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 18,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 174,
#     't_ask': 174,
#     't_bid': 132,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 42,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 175,
#     't_ask': 160,
#     't_bid': 175,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 15,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 177,
#     't_ask': 170,
#     't_bid': 177,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 7,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 178,
#     't_ask': 178,
#     't_bid': 175,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 184,
#     't_ask': 179,
#     't_bid': 184,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 5,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 225,
#     't_ask': 225,
#     't_bid': 212,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 232,
#     't_ask': 214,
#     't_bid': 232,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 18,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 233,
#     't_ask': 233,
#     't_bid': 227,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 6,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 234,
#     't_ask': 233,
#     't_bid': 234,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 236,
#     't_ask': 236,
#     't_bid': 231,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 5,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 237,
#     't_ask': 237,
#     't_bid': 237,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 267,
#     't_ask': 229,
#     't_bid': 267,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 38,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 268,
#     't_ask': 268,
#     't_bid': 268,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 269,
#     't_ask': 269,
#     't_bid': 242,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 27,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 271,
#     't_ask': 271,
#     't_bid': 245,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 26,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 272,
#     't_ask': 272,
#     't_bid': 222,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 50,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 275,
#     't_ask': 275,
#     't_bid': 235,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 40,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 277,
#     't_ask': 277,
#     't_bid': 277,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 286,
#     't_ask': 286,
#     't_bid': 273,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 287,
#     't_ask': 287,
#     't_bid': 274,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 13,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 289,
#     't_ask': 287,
#     't_bid': 289,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 290,
#     't_ask': 285,
#     't_bid': 290,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 5,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 292,
#     't_ask': 292,
#     't_bid': 278,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 14,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 294,
#     't_ask': 294,
#     't_bid': 275,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 19,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 295,
#     't_ask': 295,
#     't_bid': 259,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 36,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 296,
#     't_ask': 294,
#     't_bid': 296,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 299,
#     't_ask': 299,
#     't_bid': 297,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 321,
#     't_ask': 321,
#     't_bid': 303,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 18,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 330,
#     't_ask': 280,
#     't_bid': 330,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 50,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 331,
#     't_ask': 292,
#     't_bid': 331,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 39,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 348,
#     't_ask': 348,
#     't_bid': 322,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 26,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 349,
#     't_ask': 349,
#     't_bid': 347,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 351,
#     't_ask': 340,
#     't_bid': 351,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 11,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 352,
#     't_ask': 352,
#     't_bid': 344,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 8,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 354,
#     't_ask': 323,
#     't_bid': 354,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 31,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 376,
#     't_ask': 376,
#     't_bid': 356,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 20,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 377,
#     't_ask': 377,
#     't_bid': 327,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 50,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 380,
#     't_ask': 380,
#     't_bid': 353,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 27,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 383,
#     't_ask': 383,
#     't_bid': 381,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 384,
#     't_ask': 378,
#     't_bid': 384,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 6,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 385,
#     't_ask': 385,
#     't_bid': 384,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 387,
#     't_ask': 387,
#     't_bid': 382,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 5,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 390,
#     't_ask': 390,
#     't_bid': 342,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 48,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 397,
#     't_ask': 391,
#     't_bid': 397,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 6,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 399,
#     't_ask': 399,
#     't_bid': 391,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 8,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 406,
#     't_ask': 386,
#     't_bid': 406,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 20,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 445,
#     't_ask': 445,
#     't_bid': 429,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 16,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 453,
#     't_ask': 453,
#     't_bid': 411,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 42,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 454,
#     't_ask': 408,
#     't_bid': 454,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 46,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 456,
#     't_ask': 456,
#     't_bid': 410,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 46,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 457,
#     't_ask': 439,
#     't_bid': 457,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 10,
#     'ask_lifetime': 18,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 459,
#     't_ask': 459,
#     't_bid': 438,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 463,
#     't_ask': 463,
#     't_bid': 440,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 464,
#     't_ask': 464,
#     't_bid': 430,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 34,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 500,
#     't_ask': 500,
#     't_bid': 457,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 43,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 506,
#     't_ask': 506,
#     't_bid': 466,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 40,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 508,
#     't_ask': 508,
#     't_bid': 508,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 509,
#     't_ask': 509,
#     't_bid': 509,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 510,
#     't_ask': 510,
#     't_bid': 508,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 511,
#     't_ask': 511,
#     't_bid': 463,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 48,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 512,
#     't_ask': 511,
#     't_bid': 512,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 516,
#     't_ask': 516,
#     't_bid': 514,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 519,
#     't_ask': 519,
#     't_bid': 514,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 519,
#     't_ask': 517,
#     't_bid': 519,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 2,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 520,
#     't_ask': 519,
#     't_bid': 520,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 1,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 521,
#     't_ask': 521,
#     't_bid': 520,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 521,
#     't_ask': 521,
#     't_bid': 520,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 523,
#     't_ask': 523,
#     't_bid': 501,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 22,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 554,
#     't_ask': 524,
#     't_bid': 554,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 30,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 566,
#     't_ask': 524,
#     't_bid': 566,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 42,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 567,
#     't_ask': 567,
#     't_bid': 556,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 11,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 568,
#     't_ask': 568,
#     't_bid': 568,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 569,
#     't_ask': 521,
#     't_bid': 569,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 48,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 575,
#     't_ask': 571,
#     't_bid': 575,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 4,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 584,
#     't_ask': 584,
#     't_bid': 575,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 9,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 587,
#     't_ask': 587,
#     't_bid': 576,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 11,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 597,
#     't_ask': 597,
#     't_bid': 577,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 20,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 600,
#     't_ask': 569,
#     't_bid': 600,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 31,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 606,
#     't_ask': 598,
#     't_bid': 606,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 8,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 609,
#     't_ask': 607,
#     't_bid': 609,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 610,
#     't_ask': 610,
#     't_bid': 575,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 35,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 611,
#     't_ask': 570,
#     't_bid': 611,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 41,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 611,
#     't_ask': 598,
#     't_bid': 611,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 13,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 612,
#     't_ask': 612,
#     't_bid': 578,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 34,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 613,
#     't_ask': 613,
#     't_bid': 570,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 43,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 615,
#     't_ask': 566,
#     't_bid': 615,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 49,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 616,
#     't_ask': 616,
#     't_bid': 616,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 620,
#     't_ask': 620,
#     't_bid': 614,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 6,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 622,
#     't_ask': 622,
#     't_bid': 621,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 641,
#     't_ask': 641,
#     't_bid': 618,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 642,
#     't_ask': 642,
#     't_bid': 623,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 19,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 642,
#     't_ask': 642,
#     't_bid': 636,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 6,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 643,
#     't_ask': 623,
#     't_bid': 643,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 20,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 653,
#     't_ask': 643,
#     't_bid': 653,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 10,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 654,
#     't_ask': 654,
#     't_bid': 653,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 655,
#     't_ask': 655,
#     't_bid': 629,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 26,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 660,
#     't_ask': 660,
#     't_bid': 656,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 663,
#     't_ask': 661,
#     't_bid': 663,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 2,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 664,
#     't_ask': 664,
#     't_bid': 654,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 665,
#     't_ask': 656,
#     't_bid': 665,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 9,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 667,
#     't_ask': 667,
#     't_bid': 663,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 668,
#     't_ask': 668,
#     't_bid': 668,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 695,
#     't_ask': 661,
#     't_bid': 695,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 10,
#     'ask_lifetime': 34,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 706,
#     't_ask': 706,
#     't_bid': 665,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 41,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 711,
#     't_ask': 711,
#     't_bid': 696,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 15,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 712,
#     't_ask': 712,
#     't_bid': 697,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 15,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 715,
#     't_ask': 670,
#     't_bid': 715,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 10,
#     'ask_lifetime': 45,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 717,
#     't_ask': 717,
#     't_bid': 669,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 48,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 717,
#     't_ask': 717,
#     't_bid': 670,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 47,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 719,
#     't_ask': 719,
#     't_bid': 719,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 720,
#     't_ask': 720,
#     't_bid': 718,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 749,
#     't_ask': 749,
#     't_bid': 721,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 28,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 774,
#     't_ask': 774,
#     't_bid': 765,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 9,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 775,
#     't_ask': 775,
#     't_bid': 771,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 776,
#     't_ask': 776,
#     't_bid': 771,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 799,
#     't_ask': 781,
#     't_bid': 799,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 18,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 831,
#     't_ask': 800,
#     't_bid': 831,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 31,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 850,
#     't_ask': 833,
#     't_bid': 850,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 10,
#     'ask_lifetime': 17,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 851,
#     't_ask': 851,
#     't_bid': 850,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 853,
#     't_ask': 853,
#     't_bid': 826,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 27,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 864,
#     't_ask': 864,
#     't_bid': 857,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 7,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 865,
#     't_ask': 865,
#     't_bid': 852,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 13,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 894,
#     't_ask': 894,
#     't_bid': 854,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 40,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 895,
#     't_ask': 895,
#     't_bid': 880,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 15,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 896,
#     't_ask': 896,
#     't_bid': 867,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 29,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 897,
#     't_ask': 897,
#     't_bid': 897,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 904,
#     't_ask': 903,
#     't_bid': 904,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 1,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 920,
#     't_ask': 920,
#     't_bid': 919,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 921,
#     't_ask': 917,
#     't_bid': 921,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 4,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 929,
#     't_ask': 924,
#     't_bid': 929,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 5,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 930,
#     't_ask': 930,
#     't_bid': 930,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 935,
#     't_ask': 935,
#     't_bid': 935,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 987,
#     't_ask': 987,
#     't_bid': 985,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 989,
#     't_ask': 989,
#     't_bid': 956,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 33,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10}],
#   'Wood': [{'t': 2,
#     't_ask': 2,
#     't_bid': 0,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 4,
#     't_ask': 3,
#     't_bid': 4,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 1,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 4,
#     't_ask': 3,
#     't_bid': 4,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 5,
#     't_ask': 5,
#     't_bid': 1,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 7,
#     't_ask': 7,
#     't_bid': 3,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 8,
#     't_ask': 8,
#     't_bid': 6,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 10,
#     't_ask': 10,
#     't_bid': 10,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 11,
#     't_ask': 11,
#     't_bid': 2,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 9,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 15,
#     't_ask': 15,
#     't_bid': 13,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 57,
#     't_ask': 9,
#     't_bid': 57,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 48,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 58,
#     't_ask': 14,
#     't_bid': 58,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 44,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 60,
#     't_ask': 19,
#     't_bid': 60,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 41,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 64,
#     't_ask': 23,
#     't_bid': 64,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 41,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 65,
#     't_ask': 65,
#     't_bid': 59,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 6,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 68,
#     't_ask': 68,
#     't_bid': 20,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 1,
#     'bid_lifetime': 48,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 70,
#     't_ask': 58,
#     't_bid': 70,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 12,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 74,
#     't_ask': 74,
#     't_bid': 69,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 76,
#     't_ask': 76,
#     't_bid': 75,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 77,
#     't_ask': 77,
#     't_bid': 62,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 15,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 80,
#     't_ask': 80,
#     't_bid': 79,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 81,
#     't_ask': 81,
#     't_bid': 73,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 8,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 83,
#     't_ask': 83,
#     't_bid': 75,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 8,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 114,
#     't_ask': 81,
#     't_bid': 114,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 33,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 115,
#     't_ask': 115,
#     't_bid': 79,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 36,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 119,
#     't_ask': 119,
#     't_bid': 116,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 121,
#     't_ask': 83,
#     't_bid': 121,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 38,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 122,
#     't_ask': 122,
#     't_bid': 120,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 127,
#     't_ask': 127,
#     't_bid': 125,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 128,
#     't_ask': 128,
#     't_bid': 123,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 129,
#     't_ask': 129,
#     't_bid': 123,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 6,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 131,
#     't_ask': 130,
#     't_bid': 131,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 1,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 135,
#     't_ask': 135,
#     't_bid': 131,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 136,
#     't_ask': 136,
#     't_bid': 126,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 10,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 137,
#     't_ask': 137,
#     't_bid': 136,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 138,
#     't_ask': 138,
#     't_bid': 132,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 6,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 140,
#     't_ask': 134,
#     't_bid': 140,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 10,
#     'ask_lifetime': 6,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 185,
#     't_ask': 185,
#     't_bid': 139,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 46,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 186,
#     't_ask': 186,
#     't_bid': 181,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 186,
#     't_ask': 186,
#     't_bid': 139,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 47,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 191,
#     't_ask': 191,
#     't_bid': 187,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 4,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 194,
#     't_ask': 194,
#     't_bid': 172,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 22,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 220,
#     't_ask': 220,
#     't_bid': 179,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 41,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 223,
#     't_ask': 223,
#     't_bid': 195,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 28,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 228,
#     't_ask': 221,
#     't_bid': 228,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 7,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 229,
#     't_ask': 192,
#     't_bid': 229,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 37,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 238,
#     't_ask': 195,
#     't_bid': 238,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 43,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 240,
#     't_ask': 240,
#     't_bid': 229,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 11,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 246,
#     't_ask': 246,
#     't_bid': 239,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 7,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 247,
#     't_ask': 247,
#     't_bid': 240,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 7,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 247,
#     't_ask': 247,
#     't_bid': 243,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 250,
#     't_ask': 250,
#     't_bid': 237,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 13,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 251,
#     't_ask': 251,
#     't_bid': 242,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 9,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 251,
#     't_ask': 251,
#     't_bid': 230,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 21,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 252,
#     't_ask': 252,
#     't_bid': 248,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 254,
#     't_ask': 254,
#     't_bid': 254,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
# ...
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 707,
#     't_ask': 707,
#     't_bid': 707,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 708,
#     't_ask': 708,
#     't_bid': 708,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 709,
#     't_ask': 709,
#     't_bid': 708,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 710,
#     't_ask': 710,
#     't_bid': 710,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 712,
#     't_ask': 712,
#     't_bid': 710,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 713,
#     't_ask': 713,
#     't_bid': 674,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 39,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 725,
#     't_ask': 718,
#     't_bid': 725,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 7,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 755,
#     't_ask': 755,
#     't_bid': 734,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 757,
#     't_ask': 757,
#     't_bid': 726,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 31,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 758,
#     't_ask': 758,
#     't_bid': 737,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 759,
#     't_ask': 759,
#     't_bid': 759,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 765,
#     't_ask': 765,
#     't_bid': 732,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 33,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 766,
#     't_ask': 766,
#     't_bid': 718,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 48,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 767,
#     't_ask': 767,
#     't_bid': 754,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 768,
#     't_ask': 768,
#     't_bid': 768,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 769,
#     't_ask': 769,
#     't_bid': 769,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 772,
#     't_ask': 772,
#     't_bid': 766,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 6,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 773,
#     't_ask': 773,
#     't_bid': 726,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 47,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 776,
#     't_ask': 776,
#     't_bid': 734,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 42,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 804,
#     't_ask': 804,
#     't_bid': 777,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 27,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 813,
#     't_ask': 813,
#     't_bid': 812,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 814,
#     't_ask': 814,
#     't_bid': 814,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 815,
#     't_ask': 815,
#     't_bid': 802,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 816,
#     't_ask': 816,
#     't_bid': 816,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 817,
#     't_ask': 814,
#     't_bid': 817,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 3,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 821,
#     't_ask': 821,
#     't_bid': 775,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 46,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 822,
#     't_ask': 817,
#     't_bid': 822,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 5,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 823,
#     't_ask': 823,
#     't_bid': 823,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 856,
#     't_ask': 825,
#     't_bid': 856,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 31,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 858,
#     't_ask': 858,
#     't_bid': 822,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 36,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 861,
#     't_ask': 861,
#     't_bid': 861,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 869,
#     't_ask': 863,
#     't_bid': 869,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 6,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 912,
#     't_ask': 912,
#     't_bid': 869,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 43,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 913,
#     't_ask': 913,
#     't_bid': 863,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 50,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 914,
#     't_ask': 914,
#     't_bid': 864,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 50,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 914,
#     't_ask': 914,
#     't_bid': 876,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 38,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 914,
#     't_ask': 914,
#     't_bid': 879,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 35,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 915,
#     't_ask': 915,
#     't_bid': 911,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 916,
#     't_ask': 916,
#     't_bid': 916,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 918,
#     't_ask': 918,
#     't_bid': 918,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 918,
#     't_ask': 918,
#     't_bid': 917,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 922,
#     't_ask': 922,
#     't_bid': 915,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 7,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 923,
#     't_ask': 916,
#     't_bid': 923,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 7,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 925,
#     't_ask': 924,
#     't_bid': 925,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 926,
#     't_ask': 926,
#     't_bid': 876,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 50,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 928,
#     't_ask': 926,
#     't_bid': 928,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 2,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 931,
#     't_ask': 931,
#     't_bid': 929,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 931,
#     't_ask': 931,
#     't_bid': 929,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 932,
#     't_ask': 932,
#     't_bid': 917,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 15,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 966,
#     't_ask': 966,
#     't_bid': 961,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 967,
#     't_ask': 919,
#     't_bid': 967,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 48,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 968,
#     't_ask': 968,
#     't_bid': 935,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 33,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 969,
#     't_ask': 969,
#     't_bid': 969,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 978,
#     't_ask': 978,
#     't_bid': 971,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 7,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 979,
#     't_ask': 979,
#     't_bid': 976,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 980,
#     't_ask': 932,
#     't_bid': 980,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 48,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 981,
#     't_ask': 981,
#     't_bid': 981,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 982,
#     't_ask': 982,
#     't_bid': 981,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 983,
#     't_ask': 983,
#     't_bid': 983,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1}]},
#  [{'t': 49, 'builder': 2, 'loc': [4, 1], 'income': 16.472372947006132},
#   {'t': 61, 'builder': 2, 'loc': [8, 0], 'income': 16.472372947006132},
#   {'t': 93, 'builder': 2, 'loc': [9, 2], 'income': 16.472372947006132},
#   {'t': 110, 'builder': 1, 'loc': [5, 20], 'income': 11.331640623590097},
#   {'t': 191, 'builder': 1, 'loc': [8, 24], 'income': 11.331640623590097},
#   {'t': 263, 'builder': 0, 'loc': [13, 3], 'income': 13.267112338979295},
#   {'t': 287, 'builder': 2, 'loc': [5, 0], 'income': 16.472372947006132},
#   {'t': 299, 'builder': 2, 'loc': [6, 0], 'income': 16.472372947006132},
#   {'t': 304, 'builder': 2, 'loc': [8, 1], 'income': 16.472372947006132},
#   {'t': 306, 'builder': 0, 'loc': [12, 7], 'income': 13.267112338979295},
#   {'t': 328, 'builder': 0, 'loc': [13, 8], 'income': 13.267112338979295},
#   {'t': 348, 'builder': 0, 'loc': [17, 10], 'income': 13.267112338979295},
#   {'t': 351, 'builder': 2, 'loc': [7, 2], 'income': 16.472372947006132},
#   {'t': 392, 'builder': 2, 'loc': [8, 4], 'income': 16.472372947006132},
#   {'t': 431, 'builder': 2, 'loc': [1, 4], 'income': 16.472372947006132},
#   {'t': 491, 'builder': 2, 'loc': [2, 0], 'income': 16.472372947006132},
#   {'t': 534, 'builder': 0, 'loc': [11, 11], 'income': 13.267112338979295},
#   {'t': 568, 'builder': 0, 'loc': [8, 3], 'income': 13.267112338979295},
#   {'t': 593, 'builder': 0, 'loc': [7, 3], 'income': 13.267112338979295},
#   {'t': 603, 'builder': 0, 'loc': [5, 3], 'income': 13.267112338979295},
#   {'t': 613, 'builder': 2, 'loc': [10, 1], 'income': 16.472372947006132},
#   {'t': 621, 'builder': 0, 'loc': [4, 4], 'income': 13.267112338979295},
#   {'t': 657, 'builder': 2, 'loc': [9, 5], 'income': 16.472372947006132},
#   {'t': 677, 'builder': 2, 'loc': [9, 6], 'income': 16.472372947006132},
#   {'t': 678, 'builder': 3, 'loc': [8, 12], 'income': 22.249614304395735},
#   {'t': 699, 'builder': 3, 'loc': [5, 12], 'income': 22.249614304395735},
#   {'t': 718, 'builder': 3, 'loc': [7, 13], 'income': 22.249614304395735},
#   {'t': 751, 'builder': 2, 'loc': [2, 7], 'income': 16.472372947006132},
#   {'t': 937, 'builder': 2, 'loc': [10, 8], 'income': 16.472372947006132}])

# %% [markdown]
# # Next
#
# Now that you've seen how to interact with the simulation and generate episodes, try the next tutorial ([economic_simulation_advanced.ipynb](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_advanced.ipynb)) that explains how the simulation is composed of low-level Components and Entities. This structure enables flexible extensions of the economic simulation.

# %% [markdown]
# # Split-Wold

# %%
#multi_zone/simple_wood_and_stone

# %%
from ai_economist import foundation

# --- 1. Configure the SPLIT-LAYOUT environment ---
env_config_split = {
    'scenario_name': 'split_layout/simple_wood_and_stone',

    'components': [
        ('Build', {'skill_dist': "pareto", 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],

    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': False,

    'n_agents': 4,
    'world_size': [25, 25],
    'episode_length': 1000,

    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,

    'flatten_observations': False,
    'flatten_masks': True,
}

# --- 2. Create environment instance ---
split_env = foundation.make_env_instance(**env_config_split)

# --- 3. Run a random episode & visualize every 100 steps ---
play_random_episode(split_env, plot_every=100)

# %%
obs = split_env.reset(force_dense_logging=True)

for t in range(split_env.episode_length):
    actions = sample_random_actions(split_env, obs)
    obs, rew, done, info = split_env.step(actions)

# %%
# obs = split_env.reset(force_dense_logging=True)

# for t in range(split_env.episode_length):
#     actions = sample_random_actions(split_env, obs)
#     obs, rew, done, info = split_env.step(actions)

dense_log_split = split_env.previous_episode_dense_log

plotting.breakdown(dense_log_split)
# Out:
# _______________:_ Agent  0 _____|_ Agent  1 _____|_ Agent  2 _____|_ Agent  3 ____
# Cost (Wood)    :   5.43 (n= 35) |   6.44 (n= 34) |   6.57 (n= 58) |   6.02 (n= 49)
# Cost (Stone)   :   6.30 (n= 23) |   5.92 (n= 24) |   6.52 (n= 29) |   6.29 (n= 31)
#
# Income (Wood)  :   6.59 (n= 32) |   6.26 (n= 31) |   6.18 (n= 50) |   5.89 (n= 63)
# Income (Stone) :   6.30 (n= 20) |   6.11 (n= 35) |   6.00 (n= 30) |   6.86 (n= 22)
# Income (Build) :  11.34 (n=  3) |  13.27 (n=  1) |  16.48 (n=  8) |  22.27 (n=  9)
# ((<Figure size 1600x300 with 5 Axes>,
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 1600x800 with 8 Axes>),
#  {'Sell Stone': [126, 214, 180, 151],
#   'Buy Stone': [-145, -142, -189, -195],
#   'Sell Wood': [211, 194, 309, 371],
#   'Buy Wood': [-190, -219, -381, -295],
#   'Build': [34.019053064851754,
#    13.270394727189798,
#    131.8084798124621,
#    200.47043200339274],
#   'Total': array([ 36.01905306,  60.27039473,  50.80847981, 232.470432  ])},
#  [46, 70, 60, 242],
#  {'Stone': [{'t': 52,
#     't_ask': 52,
#     't_bid': 2,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 50,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 58,
#     't_ask': 58,
#     't_bid': 53,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 59,
#     't_ask': 59,
#     't_bid': 53,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 6,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 110,
#     't_ask': 110,
#     't_bid': 66,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 44,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 112,
#     't_ask': 112,
#     't_bid': 67,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 45,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 113,
#     't_ask': 112,
#     't_bid': 113,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 1,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 118,
#     't_ask': 118,
#     't_bid': 116,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 119,
#     't_ask': 114,
#     't_bid': 119,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 5,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 124,
#     't_ask': 76,
#     't_bid': 124,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 48,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 127,
#     't_ask': 127,
#     't_bid': 123,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 4,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 128,
#     't_ask': 128,
#     't_bid': 120,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 8,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 128,
#     't_ask': 128,
#     't_bid': 123,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 1,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 129,
#     't_ask': 129,
#     't_bid': 129,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 133,
#     't_ask': 125,
#     't_bid': 133,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 8,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 161,
#     't_ask': 161,
#     't_bid': 136,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 25,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 163,
#     't_ask': 163,
#     't_bid': 163,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 165,
#     't_ask': 130,
#     't_bid': 165,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 35,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 177,
#     't_ask': 164,
#     't_bid': 177,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 13,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 215,
#     't_ask': 215,
#     't_bid': 215,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 216,
#     't_ask': 166,
#     't_bid': 216,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 50,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 229,
#     't_ask': 217,
#     't_bid': 229,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 12,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 240,
#     't_ask': 240,
#     't_bid': 230,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 10,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 252,
#     't_ask': 231,
#     't_bid': 252,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 21,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 256,
#     't_ask': 242,
#     't_bid': 256,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 14,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 267,
#     't_ask': 267,
#     't_bid': 259,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 8,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 268,
#     't_ask': 268,
#     't_bid': 258,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 10,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 268,
#     't_ask': 268,
#     't_bid': 234,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 34,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 271,
#     't_ask': 271,
#     't_bid': 244,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 27,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 293,
#     't_ask': 293,
#     't_bid': 286,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 7,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 294,
#     't_ask': 257,
#     't_bid': 294,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 37,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 296,
#     't_ask': 296,
#     't_bid': 296,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 320,
#     't_ask': 320,
#     't_bid': 274,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 46,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 324,
#     't_ask': 324,
#     't_bid': 324,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 325,
#     't_ask': 325,
#     't_bid': 321,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 326,
#     't_ask': 326,
#     't_bid': 326,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 327,
#     't_ask': 277,
#     't_bid': 327,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 50,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 327,
#     't_ask': 282,
#     't_bid': 327,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 45,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 328,
#     't_ask': 294,
#     't_bid': 328,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 34,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 330,
#     't_ask': 330,
#     't_bid': 329,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 332,
#     't_ask': 332,
#     't_bid': 331,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 337,
#     't_ask': 294,
#     't_bid': 337,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 43,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 340,
#     't_ask': 340,
#     't_bid': 340,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 349,
#     't_ask': 349,
#     't_bid': 339,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 10,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 377,
#     't_ask': 338,
#     't_bid': 377,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 39,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 378,
#     't_ask': 333,
#     't_bid': 378,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 45,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 379,
#     't_ask': 379,
#     't_bid': 378,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 379,
#     't_ask': 379,
#     't_bid': 342,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 37,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 379,
#     't_ask': 379,
#     't_bid': 350,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 29,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 380,
#     't_ask': 380,
#     't_bid': 360,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 20,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 381,
#     't_ask': 381,
#     't_bid': 333,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 48,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 384,
#     't_ask': 384,
#     't_bid': 373,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 11,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 394,
#     't_ask': 375,
#     't_bid': 394,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 19,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 402,
#     't_ask': 390,
#     't_bid': 402,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 12,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 403,
#     't_ask': 403,
#     't_bid': 395,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 8,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 404,
#     't_ask': 404,
#     't_bid': 404,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 433,
#     't_ask': 433,
#     't_bid': 405,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 28,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 434,
#     't_ask': 434,
#     't_bid': 388,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 46,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 435,
#     't_ask': 435,
#     't_bid': 435,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 435,
#     't_ask': 435,
#     't_bid': 422,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 436,
#     't_ask': 436,
#     't_bid': 434,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 437,
#     't_ask': 437,
#     't_bid': 436,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 457,
#     't_ask': 457,
#     't_bid': 438,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 19,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 459,
#     't_ask': 459,
#     't_bid': 458,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 480,
#     't_ask': 480,
#     't_bid': 446,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 34,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 481,
#     't_ask': 481,
#     't_bid': 470,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 11,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 487,
#     't_ask': 484,
#     't_bid': 487,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 10,
#     'ask_lifetime': 3,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 541,
#     't_ask': 540,
#     't_bid': 541,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 1,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 562,
#     't_ask': 535,
#     't_bid': 562,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 27,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 563,
#     't_ask': 563,
#     't_bid': 558,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 563,
#     't_ask': 563,
#     't_bid': 536,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 27,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 564,
#     't_ask': 564,
#     't_bid': 537,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 27,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 565,
#     't_ask': 565,
#     't_bid': 542,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 567,
#     't_ask': 567,
#     't_bid': 567,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 617,
#     't_ask': 617,
#     't_bid': 569,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 48,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 618,
#     't_ask': 618,
#     't_bid': 615,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 619,
#     't_ask': 619,
#     't_bid': 590,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 29,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 620,
#     't_ask': 620,
#     't_bid': 608,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 12,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 621,
#     't_ask': 621,
#     't_bid': 585,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 36,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 622,
#     't_ask': 622,
#     't_bid': 622,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 623,
#     't_ask': 623,
#     't_bid': 596,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 27,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 624,
#     't_ask': 624,
#     't_bid': 621,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 3,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 642,
#     't_ask': 642,
#     't_bid': 641,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 643,
#     't_ask': 643,
#     't_bid': 626,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 17,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 644,
#     't_ask': 644,
#     't_bid': 643,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 644,
#     't_ask': 644,
#     't_bid': 616,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 28,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 645,
#     't_ask': 645,
#     't_bid': 645,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 649,
#     't_ask': 647,
#     't_bid': 649,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 2,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 674,
#     't_ask': 647,
#     't_bid': 674,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 27,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 677,
#     't_ask': 677,
#     't_bid': 631,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 46,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 701,
#     't_ask': 701,
#     't_bid': 697,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 702,
#     't_ask': 702,
#     't_bid': 701,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 721,
#     't_ask': 702,
#     't_bid': 721,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 19,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 732,
#     't_ask': 703,
#     't_bid': 732,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 10,
#     'ask_lifetime': 29,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 734,
#     't_ask': 734,
#     't_bid': 733,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 735,
#     't_ask': 735,
#     't_bid': 722,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 13,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 741,
#     't_ask': 741,
#     't_bid': 695,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 46,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 777,
#     't_ask': 742,
#     't_bid': 777,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 35,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 795,
#     't_ask': 778,
#     't_bid': 795,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 17,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 796,
#     't_ask': 796,
#     't_bid': 780,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 16,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 803,
#     't_ask': 798,
#     't_bid': 803,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 5,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 982,
#     't_ask': 982,
#     't_bid': 956,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 26,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 986,
#     't_ask': 986,
#     't_bid': 984,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 992,
#     't_ask': 992,
#     't_bid': 959,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 33,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 994,
#     't_ask': 994,
#     't_bid': 957,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 37,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 995,
#     't_ask': 995,
#     't_bid': 955,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 40,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 998,
#     't_ask': 998,
#     't_bid': 980,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 18,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 999,
#     't_ask': 999,
#     't_bid': 999,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4}],
#   'Wood': [{'t': 60,
#     't_ask': 60,
#     't_bid': 60,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 62,
#     't_ask': 62,
#     't_bid': 62,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 63,
#     't_ask': 63,
#     't_bid': 51,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 12,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 104,
#     't_ask': 104,
#     't_bid': 61,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 43,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 109,
#     't_ask': 105,
#     't_bid': 109,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 4,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 112,
#     't_ask': 112,
#     't_bid': 67,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 45,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 116,
#     't_ask': 116,
#     't_bid': 116,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 121,
#     't_ask': 117,
#     't_bid': 121,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 4,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 123,
#     't_ask': 113,
#     't_bid': 123,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 10,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 158,
#     't_ask': 158,
#     't_bid': 130,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 28,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 159,
#     't_ask': 159,
#     't_bid': 124,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 35,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 160,
#     't_ask': 160,
#     't_bid': 110,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 50,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 167,
#     't_ask': 164,
#     't_bid': 167,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 3,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 169,
#     't_ask': 169,
#     't_bid': 168,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 170,
#     't_ask': 170,
#     't_bid': 132,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 38,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 191,
#     't_ask': 167,
#     't_bid': 191,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 24,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 192,
#     't_ask': 171,
#     't_bid': 192,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 21,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 219,
#     't_ask': 171,
#     't_bid': 219,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 48,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 221,
#     't_ask': 192,
#     't_bid': 221,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 29,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 224,
#     't_ask': 224,
#     't_bid': 220,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 227,
#     't_ask': 227,
#     't_bid': 193,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 34,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 228,
#     't_ask': 208,
#     't_bid': 228,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 20,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 230,
#     't_ask': 229,
#     't_bid': 230,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 1,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 239,
#     't_ask': 239,
#     't_bid': 213,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 26,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 240,
#     't_ask': 240,
#     't_bid': 234,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 6,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 241,
#     't_ask': 212,
#     't_bid': 241,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 29,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 243,
#     't_ask': 242,
#     't_bid': 243,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 1,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 244,
#     't_ask': 244,
#     't_bid': 233,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 11,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 245,
#     't_ask': 245,
#     't_bid': 245,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 245,
#     't_ask': 245,
#     't_bid': 232,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 13,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 247,
#     't_ask': 247,
#     't_bid': 233,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 14,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 248,
#     't_ask': 246,
#     't_bid': 248,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 2,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 262,
#     't_ask': 262,
#     't_bid': 262,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 263,
#     't_ask': 263,
#     't_bid': 221,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 42,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 265,
#     't_ask': 249,
#     't_bid': 265,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 16,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 276,
#     't_ask': 266,
#     't_bid': 276,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 10,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 277,
#     't_ask': 277,
#     't_bid': 277,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 297,
#     't_ask': 297,
#     't_bid': 264,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 33,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 301,
#     't_ask': 301,
#     't_bid': 301,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 302,
#     't_ask': 299,
#     't_bid': 302,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 3,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 303,
#     't_ask': 303,
#     't_bid': 303,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 304,
#     't_ask': 304,
#     't_bid': 304,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 305,
#     't_ask': 267,
#     't_bid': 305,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 38,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 325,
#     't_ask': 325,
#     't_bid': 320,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 329,
#     't_ask': 329,
#     't_bid': 320,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 9,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 330,
#     't_ask': 330,
#     't_bid': 330,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 335,
#     't_ask': 306,
#     't_bid': 335,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 29,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 336,
#     't_ask': 336,
#     't_bid': 332,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 352,
#     't_ask': 352,
#     't_bid': 349,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 354,
#     't_ask': 354,
#     't_bid': 354,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 355,
#     't_ask': 355,
#     't_bid': 337,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 18,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 358,
#     't_ask': 358,
#     't_bid': 327,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 31,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 359,
#     't_ask': 359,
#     't_bid': 359,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 360,
#     't_ask': 337,
#     't_bid': 360,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 23,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 361,
#     't_ask': 361,
#     't_bid': 361,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 362,
#     't_ask': 362,
#     't_bid': 362,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 363,
#     't_ask': 363,
#     't_bid': 349,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 14,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 363,
#     't_ask': 363,
#     't_bid': 359,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 379,
#     't_ask': 356,
#     't_bid': 379,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 23,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 380,
#     't_ask': 380,
#     't_bid': 380,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 383,
#     't_ask': 383,
#     't_bid': 381,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 384,
#     't_ask': 384,
#     't_bid': 381,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 385,
#     't_ask': 385,
#     't_bid': 338,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 47,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 386,
#     't_ask': 358,
#     't_bid': 386,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 28,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 387,
#     't_ask': 387,
#     't_bid': 387,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 388,
#     't_ask': 388,
#     't_bid': 388,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 389,
#     't_ask': 389,
#     't_bid': 383,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 6,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 390,
#     't_ask': 389,
#     't_bid': 390,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 414,
#     't_ask': 414,
#     't_bid': 407,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 7,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 415,
#     't_ask': 415,
#     't_bid': 392,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 418,
#     't_ask': 418,
#     't_bid': 417,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 442,
#     't_ask': 442,
#     't_bid': 439,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 3,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 442,
#     't_ask': 442,
#     't_bid': 441,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 443,
#     't_ask': 443,
#     't_bid': 443,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 444,
#     't_ask': 444,
#     't_bid': 408,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 36,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 445,
#     't_ask': 445,
#     't_bid': 445,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 447,
#     't_ask': 447,
#     't_bid': 446,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 448,
#     't_ask': 442,
#     't_bid': 448,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 6,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 466,
#     't_ask': 466,
#     't_bid': 466,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 467,
#     't_ask': 467,
#     't_bid': 449,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 18,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 467,
#     't_ask': 467,
#     't_bid': 445,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 22,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 468,
#     't_ask': 468,
#     't_bid': 468,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 469,
#     't_ask': 420,
#     't_bid': 469,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 49,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 471,
#     't_ask': 471,
#     't_bid': 450,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 21,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 473,
#     't_ask': 473,
#     't_bid': 473,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 474,
#     't_ask': 474,
#     't_bid': 472,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 490,
#     't_ask': 471,
#     't_bid': 490,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 19,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 492,
#     't_ask': 492,
#     't_bid': 491,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 494,
#     't_ask': 467,
#     't_bid': 494,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 27,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 495,
#     't_ask': 495,
#     't_bid': 495,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 519,
#     't_ask': 475,
#     't_bid': 519,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 44,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 520,
#     't_ask': 520,
#     't_bid': 499,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 21,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 521,
#     't_ask': 493,
#     't_bid': 521,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 28,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 522,
#     't_ask': 522,
#     't_bid': 522,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 524,
#     't_ask': 524,
#     't_bid': 521,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 3,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 525,
#     't_ask': 525,
#     't_bid': 525,
#     'commodity': 'Wood',
# ...
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 693,
#     't_ask': 693,
#     't_bid': 687,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 6,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 715,
#     't_ask': 695,
#     't_bid': 715,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 20,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 731,
#     't_ask': 717,
#     't_bid': 731,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 14,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 734,
#     't_ask': 734,
#     't_bid': 733,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 735,
#     't_ask': 735,
#     't_bid': 699,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 36,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 739,
#     't_ask': 739,
#     't_bid': 690,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 49,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 754,
#     't_ask': 754,
#     't_bid': 736,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 18,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 757,
#     't_ask': 757,
#     't_bid': 738,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 19,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 758,
#     't_ask': 758,
#     't_bid': 736,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 22,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 759,
#     't_ask': 759,
#     't_bid': 759,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 760,
#     't_ask': 760,
#     't_bid': 760,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 788,
#     't_ask': 788,
#     't_bid': 788,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 789,
#     't_ask': 789,
#     't_bid': 767,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 22,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 797,
#     't_ask': 789,
#     't_bid': 797,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 8,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 798,
#     't_ask': 786,
#     't_bid': 798,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 12,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 800,
#     't_ask': 800,
#     't_bid': 798,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 801,
#     't_ask': 801,
#     't_bid': 789,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 12,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 802,
#     't_ask': 801,
#     't_bid': 802,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 1,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 806,
#     't_ask': 806,
#     't_bid': 805,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 812,
#     't_ask': 812,
#     't_bid': 807,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 813,
#     't_ask': 813,
#     't_bid': 803,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 814,
#     't_ask': 814,
#     't_bid': 814,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 834,
#     't_ask': 814,
#     't_bid': 834,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 20,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 835,
#     't_ask': 835,
#     't_bid': 813,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 22,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 836,
#     't_ask': 836,
#     't_bid': 807,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 29,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 837,
#     't_ask': 837,
#     't_bid': 810,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 27,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 861,
#     't_ask': 861,
#     't_bid': 861,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 862,
#     't_ask': 862,
#     't_bid': 840,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 22,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 863,
#     't_ask': 863,
#     't_bid': 859,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 864,
#     't_ask': 864,
#     't_bid': 864,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 864,
#     't_ask': 864,
#     't_bid': 842,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 22,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 865,
#     't_ask': 865,
#     't_bid': 865,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 870,
#     't_ask': 870,
#     't_bid': 866,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 871,
#     't_ask': 871,
#     't_bid': 868,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 3,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 872,
#     't_ask': 872,
#     't_bid': 872,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 873,
#     't_ask': 873,
#     't_bid': 866,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 7,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 874,
#     't_ask': 874,
#     't_bid': 874,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 892,
#     't_ask': 892,
#     't_bid': 890,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 914,
#     't_ask': 914,
#     't_bid': 912,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 915,
#     't_ask': 915,
#     't_bid': 875,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 40,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 918,
#     't_ask': 918,
#     't_bid': 889,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 29,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 926,
#     't_ask': 923,
#     't_bid': 926,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 3,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 927,
#     't_ask': 927,
#     't_bid': 915,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 12,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 928,
#     't_ask': 928,
#     't_bid': 881,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 47,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 929,
#     't_ask': 929,
#     't_bid': 914,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 15,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 930,
#     't_ask': 930,
#     't_bid': 919,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 11,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 931,
#     't_ask': 931,
#     't_bid': 930,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 933,
#     't_ask': 933,
#     't_bid': 919,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 14,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 936,
#     't_ask': 936,
#     't_bid': 896,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 40,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 942,
#     't_ask': 934,
#     't_bid': 942,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 8,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 945,
#     't_ask': 945,
#     't_bid': 900,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 45,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 967,
#     't_ask': 947,
#     't_bid': 967,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 20,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 983,
#     't_ask': 968,
#     't_bid': 983,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 15,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 988,
#     't_ask': 988,
#     't_bid': 984,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 989,
#     't_ask': 989,
#     't_bid': 984,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 5,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 989,
#     't_ask': 989,
#     't_bid': 940,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 49,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 991,
#     't_ask': 990,
#     't_bid': 991,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 995,
#     't_ask': 995,
#     't_bid': 984,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 11,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 996,
#     't_ask': 983,
#     't_bid': 996,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 13,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 997,
#     't_ask': 997,
#     't_bid': 997,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 998,
#     't_ask': 998,
#     't_bid': 997,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 999,
#     't_ask': 999,
#     't_bid': 995,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4}]},
#  [{'t': 125, 'builder': 2, 'loc': [20, 6], 'income': 16.476059976557764},
#   {'t': 223, 'builder': 2, 'loc': [13, 8], 'income': 16.476059976557764},
#   {'t': 234, 'builder': 3, 'loc': [1, 4], 'income': 22.274492444821412},
#   {'t': 322, 'builder': 3, 'loc': [3, 6], 'income': 22.274492444821412},
#   {'t': 341, 'builder': 3, 'loc': [0, 5], 'income': 22.274492444821412},
#   {'t': 351, 'builder': 2, 'loc': [22, 6], 'income': 16.476059976557764},
#   {'t': 368, 'builder': 0, 'loc': [21, 24], 'income': 11.339684354950585},
#   {'t': 384, 'builder': 3, 'loc': [1, 8], 'income': 22.274492444821412},
#   {'t': 406, 'builder': 3, 'loc': [0, 6], 'income': 22.274492444821412},
#   {'t': 439, 'builder': 3, 'loc': [4, 6], 'income': 22.274492444821412},
#   {'t': 476, 'builder': 2, 'loc': [21, 5], 'income': 16.476059976557764},
#   {'t': 483, 'builder': 2, 'loc': [22, 1], 'income': 16.476059976557764},
#   {'t': 549, 'builder': 3, 'loc': [1, 15], 'income': 22.274492444821412},
#   {'t': 576, 'builder': 2, 'loc': [20, 0], 'income': 16.476059976557764},
#   {'t': 619, 'builder': 2, 'loc': [23, 4], 'income': 16.476059976557764},
#   {'t': 630, 'builder': 1, 'loc': [24, 1], 'income': 13.270394727189798},
#   {'t': 631, 'builder': 3, 'loc': [1, 13], 'income': 22.274492444821412},
#   {'t': 643, 'builder': 0, 'loc': [13, 15], 'income': 11.339684354950585},
#   {'t': 666, 'builder': 3, 'loc': [3, 17], 'income': 22.274492444821412},
#   {'t': 745, 'builder': 0, 'loc': [19, 15], 'income': 11.339684354950585},
#   {'t': 808, 'builder': 2, 'loc': [23, 9], 'income': 16.476059976557764}])

# %%
env_config_split_big = {
    'scenario_name': 'split_layout/simple_wood_and_stone',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 4,
    'world_size': [60, 60],
    'episode_length': 1000,
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    'flatten_observations': False,
    'flatten_masks': True,

    # Layout controls
    'env_layout_file': 'random_60x60_ws.txt',
    'fixed_four_skill_and_loc': False,
    'starting_agent_coin': 10,

    # Logging
    'dense_log_frequency': 1,
}


split_env_big = foundation.make_env_instance(**env_config_split_big)


play_random_episode(split_env_big, plot_every=100)

# %%
env_config = {
    'scenario_name': 'layout_from_file/simple_wood_and_stone', #no waterline weeee
    'components': [
        ('Build', {'skill_dist':'pareto', 'payment_max_skill_multiplier':3}),
        ('ContinuousDoubleAuction', {'max_num_orders':5}),
        ('Gather', {})
    ],
    'n_agents': 4,
    'world_size': [25,25],
    'env_layout_file':'quadrant_25x25_20each_30clump.txt',

    # NEW: custom start positions
    'agent_start_locs': [(5,5), (5,20), (20,5), (20,20)],

    'starting_agent_coin': 10,
}
env = foundation.make_env_instance(**env_config)
env.reset()

print([agent.loc for agent in env.world.agents])

env = foundation.make_env_instance(**env_config)


play_random_episode(env, plot_every=100)

# %% [markdown]
# ## this next part might just be deleted

# %% [markdown]
# Creating file

# %%
import os
import numpy as np

def make_random_layout_file(
    H=60, W=60,
    p_wood=0.12, p_stone=0.12, p_water=0.00,
    seed=123,
    out_path="tutorials/map_txt/random_60x60_ws.txt",
):
    """
    Create a HxW layout text file with random W/S/@/space
    respecting the requested densities.
    Lines are joined by ';' (Foundation expects this format).
    """
    assert 0 <= p_wood <= 1 and 0 <= p_stone <= 1 and 0 <= p_water <= 1
    assert p_wood + p_stone + p_water <= 1.0, "Densities sum must be <= 1"
    rng = np.random.RandomState(seed)

    mask = rng.rand(H, W)
    th_w = p_wood
    th_s = p_wood + p_stone
    th_a = th_s   + p_water

    chars = np.full((H, W), ' ', dtype='<U1')
    chars[mask < th_w] = 'W'
    chars[(mask >= th_w) & (mask < th_s)] = 'S'
    chars[(mask >= th_s) & (mask < th_a)] = '@'

    rows = [''.join(chars[r, :].tolist()) for r in range(H)]
    text = ';'.join(rows)

    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    with open(out_path, "w") as f:
        f.write(text)
    return out_path, text

# --- Generate the file ---
#path, _ = make_random_layout_file(
    # H=60, W=60,
    # p_wood=0.12,
    # p_stone=0.12,
    # p_water=0.00,
    # seed=42,
    # out_path="DRL-IN-INTERNATIONAL-ECONOMY-AI-ECONOMIST-/ai_economist/foundation/scenarios/simple_wood_and_stone/map_txt/random_60x60_ws.txt",
#)
#print("Wrote:", path)

# %% [markdown]
# # begining my multi-world adventures

# %%
def clear_vertical_water_stripes(src_path, dst_path, cols_to_clear):
    # reads a ; separated map file, clears '@' in those columns, writes to new file
    with open(src_path, 'r', encoding='utf-8') as f:
        text = f.read().rstrip(';')
    rows = text.split(';')
    H = len(rows)
    W = max(len(r) for r in rows)
    rows = [r + ' '*(W - len(r)) for r in rows]
    arr = [list(r) for r in rows]
    for r in range(H):
        for c in cols_to_clear:
            if 0 <= c < W and arr[r][c] == '@':
                arr[r][c] = ' '
    rows_out = [''.join(arr[r]) for r in range(H)]
    with open(dst_path, 'w', encoding='utf-8') as f:
        f.write(';'.join(rows_out))

# # Example: clear column 25 if that’s your solid water column
# clear_vertical_water_stripes(
#     src_path='DRL-IN-INTERNATIONAL-ECONOMY-AI-ECONOMIST-/ai_economist/foundation/scenarios/simple_wood_and_stone/map_txt/multi_world_100x50.txt',
#     dst_path='DRL-IN-INTERNATIONAL-ECONOMY-AI-ECONOMIST-/ai_economist/foundation/scenarios/simple_wood_and_stone/map_txt/multi_world_100x50_noV.txt',
#     cols_to_clear=[25]
# )

# %% [markdown]
# I still need to deal with waterlines not showing up in splitwold - this is just changing the code

# %% [markdown]
# Height × Width = 100 × 50
# Wood tiles ≈ 168
# Stone tiles ≈ 160
# Water tiles ≈ 344

# %%
from ai_economist import foundation
import random

starting_loc= [(random.randint(1, 100), random.randint(1, 50)) for _ in range(20)]

env_config = {
    'scenario_name': 'split_layout/simple_wood_and_stone',  # or layout_from_file/...
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 20,
    'world_size': [100, 50],                 # must match the file
    'env_layout_file': 'multi_world_100x50.txt',
    'episode_length': 1000,
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    'flatten_observations': False,
    'flatten_masks': True,
    'starting_agent_coin': 10,
    'dense_log_frequency': 1,                # optional but handy for debugging
    'agent_start_locs': starting_loc,

}

env = foundation.make_env_instance(**env_config)
obs = env.reset(force_dense_logging=True)

play_random_episode(env, plot_every=100)

# %%
import random
from ai_economist import foundation
import numpy as np

H, W = 100, 50

# Avoid the horizontal waterline row 50, and stay inside the map.
def safe_random_start(H=100, W=50, avoid_rows={50}):
    while True:
        r = random.randrange(0, H)      # 0..H-1
        c = random.randrange(0, W)      # 0..W-1
        if r not in avoid_rows:
            return (r, c)

starting_loc = [safe_random_start(H, W, avoid_rows={50}) for _ in range(4)]

env_config = {
    'scenario_name': 'custom/split_overlay_from_file',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 4,
    'world_size': [H, W],
    'env_layout_file': 'map_100x50_water_gaps_1p5_wood_1p_stone.txt',

    # Overlay the split. Note:
    # - add_vertical_line=True overlays a *new* vertical line (it does NOT "keep from file").
    #   If your file already has a vertical line and you want to preserve it ONLY, set this to False.
    'water_row': 50,
    'add_vertical_line': True,

    # Custom starts
    'agent_start_locs': starting_loc,
}

env = foundation.make_env_instance(**env_config)

obs = env.reset(force_dense_logging=True)

# Run an episode
play_random_episode(env, plot_every=100)

# %% [markdown]
# i still have issues with the Wood/Stone titles, but i cant be bothered to fix it right now v- also fix the original labourt plot it sucks

# %% [markdown]
# map_100x50_water_gaps_1p5_wood_1p_stone.txt

# %%
env_config = {
    'scenario_name': 'custom/layout_with_starts',
    'components': [
        ('Build', {'skill_dist':'pareto', 'payment_max_skill_multiplier':3}),
        ('ContinuousDoubleAuction', {'max_num_orders':5}),
        ('Gather', {}),
    ],
    'n_agents': 8,
    'world_size': [100, 50],
    'episode_length': 1000,
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    'flatten_observations': False,
    'flatten_masks': True,

    # Layout controls
    'env_layout_file': 'map_100x50_water_gaps_1p5_wood_1p_stone.txt',
    'fixed_four_skill_and_loc': False,
    'starting_agent_coin': 10,

    # Logging
    'dense_log_frequency': 1,

    #staring locations
    'agent_start_locs': [(10,10), (10,40), (80,10), (80,40), (20,20), (20,30), (70,20), (70,30)],
}

env = foundation.make_env_instance(**env_config)
#env.reset()


play_random_episode(env, plot_every=100)

# %%
obs = env.reset(force_dense_logging=True)

for t in range(env.episode_length):
    actions = sample_random_actions(env, obs)
    obs, rew, done, info = env.step(actions)

dense_log = env.previous_episode_dense_log

plotting.breakdown(dense_log)
# Out:
# _______________:_ Agent  0 _____|_ Agent  1 _____|_ Agent  2 _____|_ Agent  3 _____|_ Agent  4 _____|_ Agent  5 _____|_ Agent  6 _____|_ Agent  7 ____
# Cost (Wood)    :   5.34 (n= 32) |   5.92 (n= 24) |   5.59 (n= 32) |   7.45 (n= 31) |   6.03 (n= 36) |   6.00 (n= 12) |   6.12 (n= 33) |   7.05 (n= 37)
# Cost (Stone)   :   5.79 (n= 38) |   4.72 (n= 25) |   4.98 (n= 41) |   4.89 (n= 47) |   4.70 (n= 40) |   5.65 (n= 26) |   5.48 (n= 46) |   5.12 (n= 51)
#
# Income (Wood)  :   5.89 (n= 28) |   6.43 (n= 28) |   6.41 (n= 32) |   6.64 (n= 28) |   5.43 (n= 30) |   5.27 (n= 11) |   5.89 (n= 38) |   7.00 (n= 42)
# Income (Stone) :   5.45 (n= 38) |   4.57 (n= 28) |   4.55 (n= 38) |   5.11 (n= 47) |   5.63 (n= 41) |   5.50 (n= 28) |   5.77 (n= 43) |   4.69 (n= 51)
# Income (Build) :  11.76 (n=  6) |    ~~~~~~~~    |  10.45 (n=  8) |  13.74 (n=  5) |  13.86 (n=  6) |  10.28 (n=  4) |  14.01 (n=  4) |  22.76 (n=  4)
# ((<Figure size 1600x300 with 5 Axes>,
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 1600x800 with 8 Axes>),
#  {'Sell Stone': [207, 128, 173, 240, 231, 154, 248, 239],
#   'Buy Stone': [-220, -118, -204, -230, -188, -147, -252, -261],
#   'Sell Wood': [165, 180, 205, 186, 163, 58, 224, 294],
#   'Buy Wood': [-171, -142, -179, -231, -217, -72, -202, -261],
#   'Build': [70.54334120280988,
#    0,
#    83.57177610794345,
#    68.70828905830083,
#    83.18318090993655,
#    41.108379558623,
#    56.024678879693454,
#    91.05564551462618],
#   'Total': array([ 51.5433412 ,  48.        ,  78.57177611,  33.70828906,
#           72.18318091,  34.10837956,  74.02467888, 102.05564551])},
#  [61, 58, 88, 43, 82, 44, 84, 112],
#  {'Stone': [{'t': 64,
#     't_ask': 64,
#     't_bid': 56,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 8,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 106,
#     't_ask': 106,
#     't_bid': 105,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 107,
#     't_ask': 107,
#     't_bid': 65,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 42,
#     'seller': 5,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 109,
#     't_ask': 109,
#     't_bid': 108,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 110,
#     't_ask': 110,
#     't_bid': 109,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 111,
#     't_ask': 111,
#     't_bid': 108,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 3,
#     'seller': 6,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 112,
#     't_ask': 112,
#     't_bid': 110,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 5,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 112,
#     't_ask': 112,
#     't_bid': 110,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 2,
#     'seller': 4,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 113,
#     't_ask': 113,
#     't_bid': 110,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 3,
#     'bid_lifetime': 3,
#     'seller': 4,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 115,
#     't_ask': 115,
#     't_bid': 115,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 115,
#     't_ask': 115,
#     't_bid': 112,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 3,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 118,
#     't_ask': 118,
#     't_bid': 116,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 119,
#     't_ask': 116,
#     't_bid': 119,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 6,
#     'ask_lifetime': 3,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 121,
#     't_ask': 121,
#     't_bid': 117,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 122,
#     't_ask': 122,
#     't_bid': 116,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 6,
#     'seller': 4,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 123,
#     't_ask': 123,
#     't_bid': 113,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 3,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 128,
#     't_ask': 128,
#     't_bid': 122,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 6,
#     'seller': 6,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 164,
#     't_ask': 164,
#     't_bid': 124,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 40,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 168,
#     't_ask': 168,
#     't_bid': 121,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 3,
#     'bid_lifetime': 47,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 170,
#     't_ask': 168,
#     't_bid': 170,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 174,
#     't_ask': 174,
#     't_bid': 155,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 19,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 176,
#     't_ask': 172,
#     't_bid': 176,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 5,
#     'ask_lifetime': 4,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 178,
#     't_ask': 173,
#     't_bid': 178,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 5,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 179,
#     't_ask': 170,
#     't_bid': 179,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 6,
#     'ask_lifetime': 9,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 198,
#     't_ask': 181,
#     't_bid': 198,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 4,
#     'ask_lifetime': 17,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 199,
#     't_ask': 199,
#     't_bid': 155,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 3,
#     'bid_lifetime': 44,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 216,
#     't_ask': 216,
#     't_bid': 179,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 3,
#     'bid_lifetime': 37,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 217,
#     't_ask': 217,
#     't_bid': 171,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 2,
#     'bid_lifetime': 46,
#     'seller': 7,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 225,
#     't_ask': 220,
#     't_bid': 225,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 5,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 226,
#     't_ask': 220,
#     't_bid': 226,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 5,
#     'ask_lifetime': 6,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 227,
#     't_ask': 218,
#     't_bid': 227,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 9,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 229,
#     't_ask': 229,
#     't_bid': 209,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 3,
#     'bid_lifetime': 20,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 231,
#     't_ask': 228,
#     't_bid': 231,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 3,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 234,
#     't_ask': 234,
#     't_bid': 232,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 235,
#     't_ask': 235,
#     't_bid': 235,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 236,
#     't_ask': 236,
#     't_bid': 232,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 4,
#     'seller': 6,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 267,
#     't_ask': 230,
#     't_bid': 267,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 37,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 268,
#     't_ask': 268,
#     't_bid': 238,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 5,
#     'bid_lifetime': 30,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 278,
#     't_ask': 278,
#     't_bid': 238,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 3,
#     'bid_lifetime': 40,
#     'seller': 4,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 279,
#     't_ask': 271,
#     't_bid': 279,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 4,
#     'ask_lifetime': 8,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 285,
#     't_ask': 272,
#     't_bid': 285,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 4,
#     'ask_lifetime': 13,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 286,
#     't_ask': 286,
#     't_bid': 286,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 288,
#     't_ask': 288,
#     't_bid': 288,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 288,
#     't_ask': 286,
#     't_bid': 288,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 4,
#     'ask_lifetime': 2,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 289,
#     't_ask': 274,
#     't_bid': 289,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 15,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 290,
#     't_ask': 290,
#     't_bid': 290,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 293,
#     't_ask': 293,
#     't_bid': 293,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 294,
#     't_ask': 294,
#     't_bid': 269,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 25,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 295,
#     't_ask': 290,
#     't_bid': 295,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 5,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 298,
#     't_ask': 298,
#     't_bid': 290,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 4,
#     'bid_lifetime': 8,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 304,
#     't_ask': 295,
#     't_bid': 304,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 9,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 305,
#     't_ask': 305,
#     't_bid': 270,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 35,
#     'seller': 5,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 306,
#     't_ask': 306,
#     't_bid': 306,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 307,
#     't_ask': 307,
#     't_bid': 279,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 28,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 315,
#     't_ask': 287,
#     't_bid': 315,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 28,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 317,
#     't_ask': 317,
#     't_bid': 313,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 4,
#     'seller': 7,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 318,
#     't_ask': 318,
#     't_bid': 318,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 321,
#     't_ask': 287,
#     't_bid': 321,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 6,
#     'ask_lifetime': 34,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 322,
#     't_ask': 299,
#     't_bid': 322,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 6,
#     'ask_lifetime': 23,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 326,
#     't_ask': 286,
#     't_bid': 326,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 7,
#     'ask_lifetime': 40,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 327,
#     't_ask': 327,
#     't_bid': 279,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 3,
#     'bid_lifetime': 48,
#     'seller': 7,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 330,
#     't_ask': 289,
#     't_bid': 330,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 7,
#     'ask_lifetime': 41,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 332,
#     't_ask': 299,
#     't_bid': 332,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 33,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 337,
#     't_ask': 337,
#     't_bid': 335,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 339,
#     't_ask': 339,
#     't_bid': 328,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 5,
#     'bid_lifetime': 11,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 340,
#     't_ask': 340,
#     't_bid': 340,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 344,
#     't_ask': 341,
#     't_bid': 344,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 3,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 347,
#     't_ask': 347,
#     't_bid': 347,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 348,
#     't_ask': 305,
#     't_bid': 348,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 7,
#     'ask_lifetime': 43,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 348,
#     't_ask': 335,
#     't_bid': 348,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 13,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 370,
#     't_ask': 370,
#     't_bid': 354,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 16,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 371,
#     't_ask': 371,
#     't_bid': 333,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 38,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 374,
#     't_ask': 374,
#     't_bid': 349,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 4,
#     'bid_lifetime': 25,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 380,
#     't_ask': 380,
#     't_bid': 376,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 4,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 381,
#     't_ask': 340,
#     't_bid': 381,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 41,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 382,
#     't_ask': 382,
#     't_bid': 352,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 30,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 383,
#     't_ask': 383,
#     't_bid': 383,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 384,
#     't_ask': 384,
#     't_bid': 360,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 4,
#     'bid_lifetime': 24,
#     'seller': 6,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 400,
#     't_ask': 400,
#     't_bid': 372,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 28,
#     'seller': 6,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 401,
#     't_ask': 401,
#     't_bid': 382,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 19,
#     'seller': 6,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 402,
#     't_ask': 402,
#     't_bid': 385,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 4,
#     'bid_lifetime': 17,
#     'seller': 6,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 404,
#     't_ask': 403,
#     't_bid': 404,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 1,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 420,
#     't_ask': 409,
#     't_bid': 420,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 11,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 421,
#     't_ask': 379,
#     't_bid': 421,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 7,
#     'ask_lifetime': 42,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 422,
#     't_ask': 422,
#     't_bid': 373,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 3,
#     'bid_lifetime': 49,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 422,
#     't_ask': 422,
#     't_bid': 391,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 3,
#     'bid_lifetime': 31,
#     'seller': 4,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 423,
#     't_ask': 423,
#     't_bid': 423,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 427,
#     't_ask': 427,
#     't_bid': 423,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 6,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 428,
#     't_ask': 428,
#     't_bid': 423,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 5,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 429,
#     't_ask': 428,
#     't_bid': 429,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 4,
#     'ask_lifetime': 1,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 432,
#     't_ask': 429,
#     't_bid': 432,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 5,
#     'ask_lifetime': 3,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 433,
#     't_ask': 433,
#     't_bid': 403,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 3,
#     'bid_lifetime': 30,
#     'seller': 4,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 434,
#     't_ask': 434,
#     't_bid': 434,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 435,
#     't_ask': 435,
#     't_bid': 404,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 3,
#     'bid_lifetime': 31,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 435,
#     't_ask': 435,
#     't_bid': 435,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 436,
#     't_ask': 434,
#     't_bid': 436,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 2,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 437,
#     't_ask': 436,
#     't_bid': 437,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 4,
#     'ask_lifetime': 1,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 439,
#     't_ask': 439,
#     't_bid': 439,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 440,
#     't_ask': 440,
#     't_bid': 440,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 441,
#     't_ask': 438,
#     't_bid': 441,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 3,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 441,
#     't_ask': 436,
#     't_bid': 441,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 5,
#     'ask_lifetime': 5,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 442,
#     't_ask': 440,
#     't_bid': 442,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 445,
#     't_ask': 445,
#     't_bid': 443,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 4,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 448,
#     't_ask': 448,
#     't_bid': 437,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 11,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 449,
#     't_ask': 446,
#     't_bid': 449,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 5,
#     'ask_lifetime': 3,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 450,
#     't_ask': 450,
#     't_bid': 450,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 452,
#     't_ask': 452,
#     't_bid': 452,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 459,
#     't_ask': 438,
#     't_bid': 459,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 6,
#     'ask_lifetime': 21,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 460,
#     't_ask': 442,
#     't_bid': 460,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 6,
#     'ask_lifetime': 18,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 462,
#     't_ask': 462,
#     't_bid': 455,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 7,
#     'seller': 4,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 463,
#     't_ask': 442,
#     't_bid': 463,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 21,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 477,
#     't_ask': 473,
#     't_bid': 477,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 4,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 481,
#     't_ask': 452,
#     't_bid': 481,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 6,
#     'ask_lifetime': 29,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 486,
#     't_ask': 486,
#     't_bid': 478,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 8,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 487,
#     't_ask': 487,
#     't_bid': 487,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 488,
#     't_ask': 464,
#     't_bid': 488,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 24,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 492,
#     't_ask': 492,
#     't_bid': 489,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 3,
#     'seller': 5,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 493,
#     't_ask': 493,
#     't_bid': 454,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 39,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 494,
#     't_ask': 465,
#     't_bid': 494,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 6,
#     'ask_lifetime': 29,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 495,
#     't_ask': 495,
#     't_bid': 476,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 19,
#     'seller': 4,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 497,
#     't_ask': 487,
#     't_bid': 497,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 10,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 497,
#     't_ask': 449,
#     't_bid': 497,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 48,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 498,
#     't_ask': 498,
#     't_bid': 498,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 501,
#     't_ask': 501,
#     't_bid': 501,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 503,
#     't_ask': 503,
#     't_bid': 503,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 505,
#     't_ask': 505,
#     't_bid': 496,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 9,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 506,
#     't_ask': 478,
#     't_bid': 506,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 28,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 507,
#     't_ask': 507,
#     't_bid': 504,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 3,
#     'seller': 6,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 508,
#     't_ask': 508,
#     't_bid': 482,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 4,
#     'bid_lifetime': 26,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 512,
#     't_ask': 508,
#     't_bid': 512,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 4,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 513,
#     't_ask': 510,
#     't_bid': 513,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 3,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 513,
#     't_ask': 511,
#     't_bid': 513,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 7,
#     'ask_lifetime': 2,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 514,
#     't_ask': 514,
#     't_bid': 514,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 527,
#     't_ask': 527,
#     't_bid': 515,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 12,
#     'seller': 7,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 528,
#     't_ask': 528,
#     't_bid': 488,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 4,
#     'bid_lifetime': 40,
#     'seller': 7,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 530,
#     't_ask': 528,
#     't_bid': 530,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 2,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 534,
#     't_ask': 534,
#     't_bid': 489,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 45,
#     'seller': 6,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 538,
#     't_ask': 532,
#     't_bid': 538,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 6,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 540,
#     't_ask': 536,
#     't_bid': 540,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 4,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 547,
#     't_ask': 547,
#     't_bid': 508,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 4,
#     'bid_lifetime': 39,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 547,
#     't_ask': 547,
#     't_bid': 509,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 4,
#     'bid_lifetime': 38,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 548,
#     't_ask': 548,
#     't_bid': 548,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 548,
#     't_ask': 548,
#     't_bid': 510,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 38,
#     'seller': 4,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 549,
#     't_ask': 549,
#     't_bid': 515,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 34,
#     'seller': 5,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 550,
#     't_ask': 550,
#     't_bid': 542,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 4,
#     'bid_lifetime': 8,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 551,
#     't_ask': 540,
#     't_bid': 551,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 11,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 553,
#     't_ask': 552,
#     't_bid': 553,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 1,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 553,
#     't_ask': 552,
#     't_bid': 553,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 1,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 554,
#     't_ask': 554,
#     't_bid': 549,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 5,
#     'seller': 7,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 556,
#     't_ask': 536,
#     't_bid': 556,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 7,
#     'ask_lifetime': 20,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 557,
#     't_ask': 557,
#     't_bid': 509,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 48,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 557,
#     't_ask': 557,
#     't_bid': 524,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 33,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 558,
#     't_ask': 541,
#     't_bid': 558,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 6,
#     'ask_lifetime': 17,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 559,
#     't_ask': 559,
#     't_bid': 559,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 559,
#     't_ask': 559,
#     't_bid': 558,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 562,
#     't_ask': 562,
#     't_bid': 559,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 4,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 563,
#     't_ask': 560,
#     't_bid': 563,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 3,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 564,
#     't_ask': 564,
#     't_bid': 564,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 565,
#     't_ask': 563,
#     't_bid': 565,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 566,
#     't_ask': 547,
#     't_bid': 566,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 7,
#     'ask_lifetime': 19,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 567,
#     't_ask': 567,
#     't_bid': 567,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 569,
#     't_ask': 561,
#     't_bid': 569,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 8,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 570,
#     't_ask': 570,
#     't_bid': 568,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 571,
#     't_ask': 571,
#     't_bid': 565,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 6,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 584,
#     't_ask': 584,
#     't_bid': 569,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 15,
#     'seller': 7,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 593,
#     't_ask': 585,
#     't_bid': 593,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 8,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 597,
#     't_ask': 570,
#     't_bid': 597,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 7,
#     'ask_lifetime': 27,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 599,
#     't_ask': 599,
#     't_bid': 583,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 16,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 600,
#     't_ask': 580,
#     't_bid': 600,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 7,
#     'ask_lifetime': 20,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 601,
#     't_ask': 601,
#     't_bid': 573,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 28,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 602,
#     't_ask': 602,
#     't_bid': 586,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 5,
#     'bid_lifetime': 16,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 602,
#     't_ask': 602,
#     't_bid': 601,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 6,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 603,
#     't_ask': 587,
#     't_bid': 603,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 7,
#     'ask_lifetime': 16,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 603,
#     't_ask': 596,
#     't_bid': 603,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 7,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 603,
#     't_ask': 597,
#     't_bid': 603,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 7,
#     'ask_lifetime': 6,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 604,
#     't_ask': 604,
#     't_bid': 604,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 605,
#     't_ask': 605,
#     't_bid': 561,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 4,
#     'bid_lifetime': 44,
#     'seller': 5,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 606,
#     't_ask': 606,
#     't_bid': 606,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 606,
#     't_ask': 604,
#     't_bid': 606,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 608,
#     't_ask': 608,
#     't_bid': 607,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 5,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 610,
#     't_ask': 598,
#     't_bid': 610,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 7,
#     'ask_lifetime': 12,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 611,
#     't_ask': 599,
#     't_bid': 611,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 7,
#     'ask_lifetime': 12,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 612,
#     't_ask': 612,
#     't_bid': 612,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 612,
#     't_ask': 612,
#     't_bid': 608,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 613,
#     't_ask': 613,
#     't_bid': 563,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 50,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 613,
#     't_ask': 613,
#     't_bid': 573,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 40,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 614,
#     't_ask': 614,
#     't_bid': 614,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 615,
#     't_ask': 609,
#     't_bid': 615,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 6,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 616,
#     't_ask': 613,
#     't_bid': 616,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 7,
#     'ask_lifetime': 3,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 616,
#     't_ask': 600,
#     't_bid': 616,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 8,
#     'ask_lifetime': 16,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 616,
#     't_ask': 603,
#     't_bid': 616,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 8,
#     'ask_lifetime': 13,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 617,
#     't_ask': 617,
#     't_bid': 614,
#     'commodity': 'Stone',
#     'buyer': 6,
#     'bid': 6,
#     'bid_lifetime': 3,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 619,
#     't_ask': 619,
#     't_bid': 619,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 620,
#     't_ask': 613,
#     't_bid': 620,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 8,
#     'ask_lifetime': 7,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 621,
#     't_ask': 621,
#     't_bid': 618,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 7,
#     'bid_lifetime': 3,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 622,
#     't_ask': 622,
#     't_bid': 622,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 623,
#     't_ask': 623,
#     't_bid': 623,
#     'commodity': 'Stone',
#     'buyer': 4,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 654,
#     't_ask': 654,
#     't_bid': 653,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 655,
#     't_ask': 655,
#     't_bid': 655,
#     'commodity': 'Stone',
#     'buyer': 7,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 659,
#     't_ask': 659,
#     't_bid': 616,
#     'commodity': 'Stone',
#     'buyer': 5,
#     'bid': 6,
# ...
#     't_ask': 714,
#     't_bid': 674,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 40,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 717,
#     't_ask': 717,
#     't_bid': 717,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 719,
#     't_ask': 719,
#     't_bid': 718,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 720,
#     't_ask': 720,
#     't_bid': 708,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 7,
#     'bid_lifetime': 12,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 720,
#     't_ask': 720,
#     't_bid': 718,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 6,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 722,
#     't_ask': 722,
#     't_bid': 721,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 736,
#     't_ask': 736,
#     't_bid': 726,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 10,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 737,
#     't_ask': 737,
#     't_bid': 736,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 7,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 742,
#     't_ask': 742,
#     't_bid': 741,
#     'commodity': 'Wood',
#     'buyer': 4,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 752,
#     't_ask': 752,
#     't_bid': 750,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 2,
#     'seller': 4,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 753,
#     't_ask': 753,
#     't_bid': 736,
#     'commodity': 'Wood',
#     'buyer': 5,
#     'bid': 8,
#     'bid_lifetime': 17,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 754,
#     't_ask': 754,
#     't_bid': 726,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 28,
#     'seller': 6,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 756,
#     't_ask': 756,
#     't_bid': 756,
#     'commodity': 'Wood',
#     'buyer': 4,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 757,
#     't_ask': 757,
#     't_bid': 756,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 758,
#     't_ask': 758,
#     't_bid': 755,
#     'commodity': 'Wood',
#     'buyer': 6,
#     'bid': 8,
#     'bid_lifetime': 3,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 759,
#     't_ask': 759,
#     't_bid': 759,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 4,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 766,
#     't_ask': 766,
#     't_bid': 763,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 3,
#     'seller': 7,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 767,
#     't_ask': 767,
#     't_bid': 767,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 768,
#     't_ask': 768,
#     't_bid': 763,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 770,
#     't_ask': 770,
#     't_bid': 769,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 1,
#     'seller': 7,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 771,
#     't_ask': 771,
#     't_bid': 743,
#     'commodity': 'Wood',
#     'buyer': 5,
#     'bid': 7,
#     'bid_lifetime': 28,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 774,
#     't_ask': 774,
#     't_bid': 758,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 16,
#     'seller': 7,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 775,
#     't_ask': 772,
#     't_bid': 775,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 9,
#     'ask_lifetime': 3,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 776,
#     't_ask': 776,
#     't_bid': 775,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 791,
#     't_ask': 791,
#     't_bid': 777,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 8,
#     'bid_lifetime': 14,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 792,
#     't_ask': 792,
#     't_bid': 792,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 808,
#     't_ask': 790,
#     't_bid': 808,
#     'commodity': 'Wood',
#     'buyer': 4,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 9,
#     'ask_lifetime': 18,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 823,
#     't_ask': 823,
#     't_bid': 822,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 824,
#     't_ask': 824,
#     't_bid': 814,
#     'commodity': 'Wood',
#     'buyer': 6,
#     'bid': 9,
#     'bid_lifetime': 10,
#     'seller': 7,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 828,
#     't_ask': 828,
#     't_bid': 804,
#     'commodity': 'Wood',
#     'buyer': 5,
#     'bid': 8,
#     'bid_lifetime': 24,
#     'seller': 6,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 831,
#     't_ask': 831,
#     't_bid': 831,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 5,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 847,
#     't_ask': 847,
#     't_bid': 841,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 6,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 848,
#     't_ask': 848,
#     't_bid': 848,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 850,
#     't_ask': 801,
#     't_bid': 850,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 10,
#     'ask_lifetime': 49,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 851,
#     't_ask': 851,
#     't_bid': 844,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 7,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 852,
#     't_ask': 852,
#     't_bid': 849,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 3,
#     'seller': 7,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 852,
#     't_ask': 852,
#     't_bid': 849,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 9,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 853,
#     't_ask': 853,
#     't_bid': 851,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 9,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 876,
#     't_ask': 876,
#     't_bid': 854,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 22,
#     'seller': 7,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 896,
#     't_ask': 896,
#     't_bid': 857,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 9,
#     'bid_lifetime': 39,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 897,
#     't_ask': 897,
#     't_bid': 856,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 41,
#     'seller': 7,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 928,
#     't_ask': 928,
#     't_bid': 898,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 30,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 928,
#     't_ask': 928,
#     't_bid': 915,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 13,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 955,
#     't_ask': 955,
#     't_bid': 924,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 31,
#     'seller': 7,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 956,
#     't_ask': 956,
#     't_bid': 953,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 3,
#     'seller': 7,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 956,
#     't_ask': 956,
#     't_bid': 907,
#     'commodity': 'Wood',
#     'buyer': 6,
#     'bid': 9,
#     'bid_lifetime': 49,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 958,
#     't_ask': 958,
#     't_bid': 913,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 45,
#     'seller': 6,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 959,
#     't_ask': 959,
#     't_bid': 929,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 30,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 960,
#     't_ask': 960,
#     't_bid': 929,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 9,
#     'bid_lifetime': 31,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 961,
#     't_ask': 961,
#     't_bid': 935,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 26,
#     'seller': 7,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 962,
#     't_ask': 962,
#     't_bid': 962,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 965,
#     't_ask': 965,
#     't_bid': 930,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 9,
#     'bid_lifetime': 35,
#     'seller': 6,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 966,
#     't_ask': 966,
#     't_bid': 966,
#     'commodity': 'Wood',
#     'buyer': 6,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 7,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 968,
#     't_ask': 968,
#     't_bid': 965,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 3,
#     'seller': 7,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 969,
#     't_ask': 969,
#     't_bid': 959,
#     'commodity': 'Wood',
#     'buyer': 4,
#     'bid': 8,
#     'bid_lifetime': 10,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 980,
#     't_ask': 968,
#     't_bid': 980,
#     'commodity': 'Wood',
#     'buyer': 7,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 6,
#     'ask': 10,
#     'ask_lifetime': 12,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 981,
#     't_ask': 981,
#     't_bid': 963,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 18,
#     'seller': 7,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8}]},
#  [{'t': 52, 'builder': 2, 'loc': [85, 8], 'income': 10.446472013492931},
#   {'t': 163, 'builder': 2, 'loc': [72, 8], 'income': 10.446472013492931},
#   {'t': 225, 'builder': 4, 'loc': [17, 32], 'income': 13.863863484989425},
#   {'t': 293, 'builder': 3, 'loc': [98, 36], 'income': 13.741657811660168},
#   {'t': 463, 'builder': 2, 'loc': [86, 19], 'income': 10.446472013492931},
#   {'t': 484, 'builder': 6, 'loc': [70, 23], 'income': 14.006169719923363},
#   {'t': 518, 'builder': 0, 'loc': [9, 24], 'income': 11.757223533801646},
#   {'t': 526, 'builder': 0, 'loc': [8, 21], 'income': 11.757223533801646},
#   {'t': 567, 'builder': 0, 'loc': [2, 22], 'income': 11.757223533801646},
#   {'t': 575, 'builder': 5, 'loc': [19, 37], 'income': 10.27709488965575},
#   {'t': 580, 'builder': 2, 'loc': [87, 20], 'income': 10.446472013492931},
#   {'t': 606, 'builder': 4, 'loc': [13, 30], 'income': 13.863863484989425},
#   {'t': 628, 'builder': 4, 'loc': [11, 26], 'income': 13.863863484989425},
#   {'t': 637, 'builder': 6, 'loc': [66, 19], 'income': 14.006169719923363},
#   {'t': 645, 'builder': 5, 'loc': [24, 33], 'income': 10.27709488965575},
#   {'t': 678, 'builder': 5, 'loc': [28, 31], 'income': 10.27709488965575},
#   {'t': 681, 'builder': 3, 'loc': [92, 35], 'income': 13.741657811660168},
#   {'t': 696, 'builder': 0, 'loc': [1, 23], 'income': 11.757223533801646},
#   {'t': 713, 'builder': 0, 'loc': [0, 22], 'income': 11.757223533801646},
#   {'t': 717, 'builder': 3, 'loc': [89, 34], 'income': 13.741657811660168},
#   {'t': 735, 'builder': 5, 'loc': [31, 28], 'income': 10.27709488965575},
#   {'t': 749, 'builder': 2, 'loc': [81, 20], 'income': 10.446472013492931},
#   {'t': 759, 'builder': 3, 'loc': [90, 33], 'income': 13.741657811660168},
#   {'t': 772, 'builder': 2, 'loc': [79, 22], 'income': 10.446472013492931},
#   {'t': 779, 'builder': 2, 'loc': [78, 24], 'income': 10.446472013492931},
#   {'t': 785, 'builder': 7, 'loc': [59, 35], 'income': 22.763911378656545},
#   {'t': 797, 'builder': 0, 'loc': [10, 23], 'income': 11.757223533801646},
#   {'t': 809, 'builder': 6, 'loc': [59, 29], 'income': 14.006169719923363},
#   {'t': 814, 'builder': 4, 'loc': [19, 31], 'income': 13.863863484989425},
#   {'t': 819, 'builder': 4, 'loc': [18, 30], 'income': 13.863863484989425},
#   {'t': 832, 'builder': 7, 'loc': [66, 38], 'income': 22.763911378656545},
#   {'t': 836, 'builder': 3, 'loc': [88, 34], 'income': 13.741657811660168},
#   {'t': 874, 'builder': 7, 'loc': [64, 32], 'income': 22.763911378656545},
#   {'t': 926, 'builder': 2, 'loc': [80, 18], 'income': 10.446472013492931},
#   {'t': 933, 'builder': 7, 'loc': [62, 30], 'income': 22.763911378656545},
#   {'t': 948, 'builder': 6, 'loc': [51, 26], 'income': 14.006169719923363},
#   {'t': 975, 'builder': 4, 'loc': [11, 37], 'income': 13.863863484989425}])

# %%
fig = plotting.vis_world_range(dense_log, N=5)
