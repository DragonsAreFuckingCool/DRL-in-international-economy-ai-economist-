# %% [markdown]
# Copyright (c) 2020, salesforce.com, inc.
# All rights reserved.
# SPDX-License-Identifier: BSD-3-Clause
# For full license text, see the LICENSE file in the repo root or https://opensource.org/licenses/BSD-3-Clause

# %% [markdown]
# ### Colab
#
# Try this notebook on [Colab](http://colab.research.google.com/github/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basic.ipynb).

# %% [markdown]
# # Welcome to Foundation!
#
# Foundation is the name of the economic simulator built for the AI Economist ([paper here](https://arxiv.org/abs/2004.13332)). This is the first of several tutorials designed to explain how Foundation works and how it can be used to build simulation environments for studying economic problems.
#
# Just to orient you a bit, Foundation is specially designed for modeling economies in spatial, 2D grid worlds. The AI Economist paper uses a scenario with 4 agents in a world with *Stone* and *Wood*, which can be *collected*, *traded*, and used to build *Houses*. Here's a (nicely rendered) example of what such an environment looks like:
#
# ![Foundation snapshot](assets/foundation_snapshot_rendered.jpg)
#
# This image just shows what you might see spatially. Behind the scenes, agents have inventories of Stone, Wood, and *Coin*, which they can exchange through a commodities marketplace. In addition, they periodically pay taxes on income earned through trading and building.
#
# **We've open-sourced Foundation to foster transparency and to enable others to build on it!** With that goal in mind, this first tutorial should give you enough to see how to create the type of simulation environment described above and how to interact with it. If you're interested to learn how it all works and how to build on it, make sure to check out the advanced tutorial as well! If, after that, you want to understand more about designing the simulation around economic problems, check out our tutorial explaining how the AI Economist uses Foundation to study the optimal taxation problem!

# %% [markdown]
# # Introduction
#
# In this **basic** tutorial, we will demonstrate the basics of how to create an instance of a simulation environment and how to interact with it.
#
# We will cover the following:
# 1. Markov Decision Processes
# 2. Creating a Simulation Environment (a Scenario Instance)
# 3. Interacting with the Simulation
# 4. Sampling and Visualizing an Episode

# %% [markdown]
# ## Dependencies:
# You can install the ai-economist package using
# - the pip package manager OR
# - by cloning the ai-economist package and installing the requirements (we shall use this when running on Colab):

# %%
# import os, signal, sys, time
# IN_COLAB = 'google.colab' in sys.modules

# if IN_COLAB:
#     !git clone https://github.com/salesforce/ai-economist.git

#     %cd ai-economist
#     !pip install -e .
    
#     # Restart the Python runtime to automatically use the installed packages
#     print("\n\nRestarting the Python runtime! Please (re-)run the cells below.")
#     time.sleep(1)
#     os.kill(os.getpid(), signal.SIGKILL)
# else:
#     !pip install ai-economist

# %%
# Import foundation
import os, signal, sys, time

sys.path.append(r'C:\Users\adria\coding\katja\DRL-in-international-economy-ai-economist-')

from ai_economist import foundation

# %%
# Change directory to the tutorials folder
import os, sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    os.chdir("/content/ai-economist/tutorials")
else:
    os.chdir(os.path.dirname(os.path.abspath("__file__"))
)

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython import display
from utils import plotting  # plotting utilities for visualizing env. state

# %% [markdown]
# # 1. Markov Decision Process
#
# Formally, our economic simulation is a key part of a Markov Decision Process (MDP).
#
# MDPs describe episodes in which agents interact with a stateful environment in a continuous feedback loop. At each timestep, agents receive an observation and use a policy to choose actions. The environment then advances to a new state, using the old state and the chosen actions. The agents then receive new observations and rewards. This process repeats over $T$ timesteps (possibly infinite).
#
# The goal of each agent is to maximize its expected sum of future (discounted) rewards, by finding its optimal policy. Intuitively, this means that an agent needs to understand which (sequence of) actions lead to high rewards (in expectation).
#
# ### References
#
# For more information on reinforcement learning and MDPs, check out:
#
# - Richard S. Sutton and Andrew G. Barto, Reinforcement Learning: An Introduction. [http://incompleteideas.net/book/bookdraft2017nov5.pdf](http://incompleteideas.net/book/bookdraft2017nov5.pdf)

# %% [markdown]
# # 2. Creating a Simulation Environment (a Scenario Instance)
#
# The Scenario class implements an economic simulation with multiple agents and (optionally) a social planner.
#
# Scenarios provide a high-level gym-style API that lets agents interact with it. The API supports multi-agent observations, actions, etc.
#
# Each Scenario is stateful and implements two main methods:
#
# - __step__, which advances the simulation to the next state, and
# - __reset__, which puts the simulation back in an initial state.
#
# Each Scenario is customizable: you can specify options in a dictionary. Here is an example for a scenario with 4 agents:
#
# **Note: This config dictionary will likely seem fairly incomprehensible at this point in the tutorials. Don't worry. The advanced tutorial offers much more context. This is just to get things started and to provide a reference for how to create a "free market" economy from the AI Economist.**

# %%
# Define the configuration of the environment that will be built

env_config_original = {
    # ===== SCENARIO CLASS =====
    # Which Scenario class to use: the class's name in the Scenario Registry (foundation.scenarios).
    # The environment object will be an instance of the Scenario class.
    'scenario_name': 'layout_from_file/simple_wood_and_stone',
    
    # ===== COMPONENTS =====
    # Which components to use (specified as list of ("component_name", {component_kwargs}) tuples).
    #   "component_name" refers to the Component class's name in the Component Registry (foundation.components)
    #   {component_kwargs} is a dictionary of kwargs passed to the Component class
    # The order in which components reset, step, and generate obs follows their listed order below.
    'components': [
        # (1) Building houses
        ('Build', {'skill_dist': "pareto", 'payment_max_skill_multiplier': 3}),
        # (2) Trading collectible resources
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        # (3) Movement and resource collection
        ('Gather', {}),
    ],
    
    # ===== SCENARIO CLASS ARGUMENTS =====
    # (optional) kwargs that are added by the Scenario class (i.e. not defined in BaseEnvironment)
    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': True,
    
    # ===== STANDARD ARGUMENTS ======
    # kwargs that are used by every Scenario class (i.e. defined in BaseEnvironment)
    'n_agents': 4,          # Number of non-planner agents (must be > 1)
    'world_size': [25, 25], # [Height, Width] of the env world
    'episode_length': 1000, # Number of timesteps per episode
    
    # In multi-action-mode, the policy selects an action for each action subspace (defined in component code).
    # Otherwise, the policy selects only 1 action.
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    
    # When flattening observations, concatenate scalar & vector observations before output.
    # Otherwise, return observations with minimal processing.
    'flatten_observations': False,
    # When Flattening masks, concatenate each action subspace mask into a single array.
    # Note: flatten_masks = True is required for masking action logits in the code below.
    'flatten_masks': True,
}

# %%
env_config = {
    # ===== SCENARIO CLASS =====
    'scenario_name': 'layout_from_file/simple_wood_and_stone',

    # ===== COMPONENTS =====
    'components': [
        # (1) Building houses (REQUIRES payment when using fixed_four_skill_and_loc=True)
        ('Build', {
            'payment': 10.0,                    # <-- REQUIRED for LayoutFromFile fixed_four_skill_and_loc
            'skill_dist': "pareto",             # <-- REQUIRED
            'payment_max_skill_multiplier': 3   # good
        }),
        # (2) Trading collectible resources
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        # (3) Movement and resource collection
        ('Gather', {}),
    ],

    # ===== SCENARIO CLASS ARGUMENTS =====
    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': True,  # <-- works only if Build.payment is set as above

    # ===== STANDARD ARGUMENTS ======
    'n_agents': 4,
    'world_size': [25, 25],
    'episode_length': 1000,

    # multi-action mode (optional; leaving your choices)
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,

    # flattening options (fine as-is)
    'flatten_observations': False,
    'flatten_masks': True,
}

# %% [markdown]
# ## Debugging

# %%
# Import to trigger the decorators
import ai_economist.foundation.scenarios.simple_wood_and_stone.layout_from_file
import ai_economist.foundation.scenarios.simple_wood_and_stone.dynamic_layout

from ai_economist.foundation.scenarios import scenario_registry as scen_reg
print("Entries:", scen_reg.entries)
print("Has layout_from_file? ", scen_reg.has("layout_from_file/simple_wood_and_stone"))
print("Has split_layout?     ", scen_reg.has("split_layout/simple_wood_and_stone"))
# Out:
# Entries: ['custom/split_overlay_from_file', 'layout_from_file/simple_wood_and_stone', 'multi_zone/simple_wood_and_stone', 'quadrant/simple_wood_and_stone', 'split_layout/simple_wood_and_stone', 'uniform/simple_wood_and_stone']
# Has layout_from_file?  True
# Has split_layout?      True

# %%
import importlib, inspect, sys

# 1) Show where the ai_economist package is loaded from
import ai_economist
print("ai_economist package file:", ai_economist.__file__)

# 2) Try both likely module paths for the two scenario modules
mods_to_try = [
    "ai_economist.foundation.scenarios.layout_from_file",
    "ai_economist.foundation.scenarios.dynamic_layout",
    # If your tree actually has the subfolder as you mentioned, we can try these too:
    "ai_economist.foundation.scenarios.simple_wood_and_stone.layout_from_file",
    "ai_economist.foundation.scenarios.simple_wood_and_stone.dynamic_layout",
]

for mod in mods_to_try:
    try:
        m = importlib.import_module(mod)
        print(f"OK  : {mod:80s} -> {m.__file__}")
    except Exception as e:
        print(f"FAIL: {mod:80s} -> {type(e).__name__}: {e}")

# 3) Compare registry singletons
from ai_economist.foundation.base import base_env, base_env_original
from ai_economist.foundation.scenarios import scenario_registry as scen_reg

print("base_env registry id         :", id(base_env.scenario_registry))
print("base_env_original registry id:", id(base_env_original.scenario_registry))
print("scenarios registry id        :", id(scen_reg))

# 4) (If imports in step 2 succeeded) check which registry each module used
try:
    lff = importlib.import_module("ai_economist.foundation.scenarios.layout_from_file")
    print("layout_from_file registry id :", id(lff.scenario_registry))
except Exception: pass

try:
    dly = importlib.import_module("ai_economist.foundation.scenarios.dynamic_layout")
    print("dynamic_layout registry id   :", id(dly.scenario_registry))
except Exception: pass

# 5) List entries seen through the scenarios package registry
print("Entries:", scen_reg.entries)
print("Has layout_from_file? ", scen_reg.has("layout_from_file/simple_wood_and_stone"))
print("Has split_layout?     ", scen_reg.has("split_layout/simple_wood_and_stone"))
# Out:
# ai_economist package file: C:\Users\adria\coding\katja\DRL-in-international-economy-ai-economist-\ai_economist\__init__.py
# FAIL: ai_economist.foundation.scenarios.layout_from_file                               -> ModuleNotFoundError: No module named 'ai_economist.foundation.scenarios.layout_from_file'
# FAIL: ai_economist.foundation.scenarios.dynamic_layout                                 -> ModuleNotFoundError: No module named 'ai_economist.foundation.scenarios.dynamic_layout'
# OK  : ai_economist.foundation.scenarios.simple_wood_and_stone.layout_from_file         -> C:\Users\adria\coding\katja\DRL-in-international-economy-ai-economist-\ai_economist\foundation\scenarios\simple_wood_and_stone\layout_from_file.py
# OK  : ai_economist.foundation.scenarios.simple_wood_and_stone.dynamic_layout           -> C:\Users\adria\coding\katja\DRL-in-international-economy-ai-economist-\ai_economist\foundation\scenarios\simple_wood_and_stone\dynamic_layout.py
# base_env registry id         : 1715375421136
# base_env_original registry id: 1715375415184
# scenarios registry id        : 1715375421136
# Entries: ['custom/split_overlay_from_file', 'layout_from_file/simple_wood_and_stone', 'multi_zone/simple_wood_and_stone', 'quadrant/simple_wood_and_stone', 'split_layout/simple_wood_and_stone', 'uniform/simple_wood_and_stone']
# Has layout_from_file?  True
# Has split_layout?      True

# %%
import ai_economist.foundation.scenarios.simple_wood_and_stone.layout_from_file
import ai_economist.foundation.scenarios.simple_wood_and_stone.dynamic_layout

from ai_economist import foundation
env = foundation.make_env_instance(**env_config)
obs = env.reset()

# %% [markdown]
# ### debug done

# %% [markdown]
# Create an environment instance using this configuration:

# %%
env = foundation.make_env_instance(**env_config)

# %% [markdown]
# # 3. Interacting with the Simulation

# %% [markdown]
# ### Agents
#
# The Agent class holds the state of agents in the simulation. Each Agent instance represents a _logical_ agent.
#
# _Note that this might be separate from a Policy model that lives outside the Scenario and controls the Agent's behavior._

# %%
env.get_agent(0)

# %% [markdown]
# ### A random policy
#
# Now let's interact with the simulation.
#
# Each Agent needs to choose which actions to execute using a __policy__.
#
# Agents might not always be allowed to execute all actions. For instance, a mobile Agent cannot move beyond the boundary of the world. Hence, in position (0, 0), a mobile cannot move "Left" or "Down". This information is given by a mask, which is provided under ```obs[<agent_id_str>]["action_mask"]``` in the observation dictionary ```obs``` returned by the scenario.
#
# Let's use a random policy to step through the simulation. The methods below implement a random policy.

# %%
# Note: The code for sampling actions (this cell), and playing an episode (below) are general.  
# That is, it doesn't depend on the Scenario and Component classes used in the environment!

def sample_random_action(agent, mask):
    """Sample random UNMASKED action(s) for agent."""
    # Return a list of actions: 1 for each action subspace
    if agent.multi_action_mode:
        split_masks = np.split(mask, agent.action_spaces.cumsum()[:-1])
        return [np.random.choice(np.arange(len(m_)), p=m_/m_.sum()) for m_ in split_masks]

    # Return a single action
    else:
        return np.random.choice(np.arange(agent.action_spaces), p=mask/mask.sum())

def sample_random_actions(env, obs):
    """Samples random UNMASKED actions for each agent in obs."""
        
    actions = {
        a_idx: sample_random_action(env.get_agent(a_idx), a_obs['action_mask'])
        for a_idx, a_obs in obs.items()
    }

    return actions

# %% [markdown]
# Now we're ready to interact with the simulation...
#
# First, environments can be put in an initial state by using __reset__.

# %%
obs = env.reset()

# %% [markdown]
# Then, we call __step__ to advance the state and advance time by one tick.

# %%
actions = sample_random_actions(env, obs)
obs, rew, done, info = env.step(actions)

# %% [markdown]
# Internally, the __step__ method composes several Components (which act almost like modular sub-Environments) that implement various agent affordances and environment dynamics. For more detailed information on Components and how to implement custom Component classes, see the advanced tutorial. For this tutorial, we will continue to inspect the information that __step__ returns and run a full episode in the simulation.

# %% [markdown]
# ### Observation
#
# Each observation is a dictionary that contains information for the $N$ agents and (optionally) social planner (with id "p").

# %%
obs.keys()
# Out:
# dict_keys(['0', '1', '2', '3', 'p'])

# %% [markdown]
# For each agent, the agent-specific observation is a dictionary. Each Component can contribute information to the agent-specific observation. For instance, the Build Component contributes the
#
# - Build-build_payment (float)
# - Build-build_skill (int)
#
# fields, which are defined in the ```generate_observations``` method in [foundation/components/build.py](https://github.com/salesforce/ai-economist/blob/master/ai_economist/foundation/components/build.py).

# %%
for key, val in obs['0'].items(): 
    print("{:50} {}".format(key, type(val)))
# Out:
# world-map                                          <class 'numpy.ndarray'>
# world-idx_map                                      <class 'numpy.ndarray'>
# world-loc-row                                      <class 'numpy.float64'>
# world-loc-col                                      <class 'numpy.float64'>
# world-inventory-Coin                               <class 'float'>
# world-inventory-Stone                              <class 'float'>
# world-inventory-Wood                               <class 'float'>
# time                                               <class 'list'>
# Build-build_payment                                <class 'numpy.float64'>
# Build-build_skill                                  <class 'float'>
# ContinuousDoubleAuction-market_rate-Stone          <class 'numpy.float64'>
# ContinuousDoubleAuction-price_history-Stone        <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_asks-Stone       <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_bids-Stone       <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_asks-Stone              <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_bids-Stone              <class 'numpy.ndarray'>
# ContinuousDoubleAuction-market_rate-Wood           <class 'numpy.float64'>
# ContinuousDoubleAuction-price_history-Wood         <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_asks-Wood        <class 'numpy.ndarray'>
# ContinuousDoubleAuction-available_bids-Wood        <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_asks-Wood               <class 'numpy.ndarray'>
# ContinuousDoubleAuction-my_bids-Wood               <class 'numpy.ndarray'>
# Gather-bonus_gather_prob                           <class 'float'>
# action_mask                                        <class 'numpy.ndarray'>

# %% [markdown]
# ### Reward
#
# For each agent / planner, the reward dictionary contains a scalar reward:

# %%
for agent_idx, reward in rew.items(): 
    print("{:2} {:.3f}".format(agent_idx, reward))
# Out:
# 0  -0.053
# 1  -0.263
# 2  -0.263
# 3  -0.053
# p  0.000

# %% [markdown]
# ### Done
#
# The __done__ object is a dictionary that by default records whether all agents have seen the end of the episode. The default criterion for each agent is to 'stop' their episode once $H$ steps have been executed. Once an agent is 'done', they do not change their state anymore. So, while it's not currently implemented, this could be used to indicate that the episode has ended *for a specific Agent*.
#
# In general, this is useful for telling a Reinforcement Learning framework when to reset the environment and how to organize the trajectories of individual Agents.

# %%
done
# Out:
# {'__all__': False}

# %% [markdown]
# ### Info
#
# The __info__ object can record any auxiliary information from the simulator, which can be useful, e.g., for visualization. By default, this is empty. To modify this behavior, modify the step() method in [foundation/base/base_env.py](https://github.com/salesforce/ai-economist/blob/master/ai_economist/foundation/base/base_env.py).

# %%
info
# Out:
# {'0': {}, '1': {}, '2': {}, '3': {}, 'p': {}}

# %% [markdown]
# # 3. Sampling and Visualizing an Episode
#
# Let's step multiple times with this random policy and visualize the result:

# %%
def do_plot(env, ax, fig):
    """Plots world state during episode sampling."""
    plotting.plot_env_state(env, ax)
    ax.set_aspect('equal')
    display.display(fig)
    display.clear_output(wait=True)

def play_random_episode(env, plot_every=100, do_dense_logging=False):
    """Plays an episode with randomly sampled actions.
    
    Demonstrates gym-style API:
        obs                  <-- env.reset(...)         # Reset
        obs, rew, done, info <-- env.step(actions, ...) # Interaction loop
    
    """
    fig, ax = plt.subplots(1, 1, figsize=(10, 10))

    # Reset
    obs = env.reset(force_dense_logging=do_dense_logging)

    # Interaction loop (w/ plotting)
    for t in range(env.episode_length):
        actions = sample_random_actions(env, obs)
        obs, rew, done, info = env.step(actions)

        if ((t+1) % plot_every) == 0:
            do_plot(env, ax, fig)

    if ((t+1) % plot_every) != 0:
        do_plot(env, ax, fig)

# %%
play_random_episode(env, plot_every=100)

# %% [markdown]
# We see four agents (indicated by a circled __\*__) that move around in the 2-dimensional world. Light brown cells contain Stone, green cells contain Wood. Each agent can build Houses, indicated by corresponding colored cells. Water tiles (blue squares), which prevent movement, divide the map into four quadrants.
#
# Note: this is showing the same information as the image at the top of the tutorial -- it just uses a much more simplistic rendering.

# %% [markdown]
# # Visualize using dense logging
#
# Environments built with Foundation provide a couple tools for logging. Perhaps the most useful are **dense logs**. When you reset the environment, you can tell it to create a dense log for the new episode. This will store Agent states at each point in time along with any Component-specific dense log information (say, about builds, trades, etc.) that the Components provide. In addition, it will periodically store a snapshot of the world state.
#
# We provide a few plotting tools that work well with the type of environment showcased here.

# %%
# Play another episode. This time, tell the environment to do dense logging
play_random_episode(env, plot_every=100, do_dense_logging=True)

# Grab the dense log from the env
dense_log = env.previous_episode_dense_log

# %%
# Show the evolution of the world state from t=0 to t=200
fig = plotting.vis_world_range(dense_log, t0=0, tN=200, N=5)

# %%
# Show the evolution of the world state over the full episode
fig = plotting.vis_world_range(dense_log, N=5)

# %%
# Use the "breakdown" tool to visualize the world state, agent-wise quantities, movement, and trading events
plotting.breakdown(dense_log)
# Out:
# _______________:_ Agent  0 _____|_ Agent  1 _____|_ Agent  2 _____|_ Agent  3 ____
# Cost (Wood)    :   4.39 (n= 56) |   4.73 (n= 73) |   4.59 (n= 44) |   3.60 (n= 48)
# Cost (Stone)   :   7.17 (n= 29) |   7.08 (n= 36) |   7.50 (n= 14) |   6.82 (n= 11)
#
# Income (Wood)  :   4.53 (n= 43) |   4.24 (n= 75) |   4.70 (n= 57) |   4.02 (n= 46)
# Income (Stone) :   7.28 (n= 36) |   6.77 (n= 30) |   7.83 (n= 12) |   7.00 (n= 12)
# Income (Build) :  13.27 (n= 11) |  16.47 (n= 13) |  22.25 (n=  2) |  11.33 (n=  2)
# ((<Figure size 1600x300 with 5 Axes>,
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 1600x800 with 8 Axes>),
#  {'Sell Stone': [262, 203, 94, 84],
#   'Buy Stone': [-208, -255, -105, -75],
#   'Sell Wood': [195, 318, 268, 185],
#   'Buy Wood': [-246, -345, -202, -173],
#   'Build': [145.9382357287723,
#    214.14084831107974,
#    44.49922860879147,
#    22.663281247180194],
#   'Total': array([148.93823573, 135.14084831,  99.49922861,  43.66328125])},
#  [158, 145, 109, 53],
#  {'Stone': [{'t': 1,
#     't_ask': 1,
#     't_bid': 1,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 108,
#     't_ask': 108,
#     't_bid': 105,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 3,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 115,
#     't_ask': 115,
#     't_bid': 112,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 117,
#     't_ask': 117,
#     't_bid': 113,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 119,
#     't_ask': 118,
#     't_bid': 119,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 1,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 157,
#     't_ask': 157,
#     't_bid': 125,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 32,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 159,
#     't_ask': 159,
#     't_bid': 117,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 42,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 161,
#     't_ask': 120,
#     't_bid': 161,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 41,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 162,
#     't_ask': 162,
#     't_bid': 162,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 164,
#     't_ask': 164,
#     't_bid': 163,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 169,
#     't_ask': 169,
#     't_bid': 166,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 180,
#     't_ask': 180,
#     't_bid': 176,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 184,
#     't_ask': 170,
#     't_bid': 184,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 14,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 185,
#     't_ask': 185,
#     't_bid': 178,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 7,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 186,
#     't_ask': 186,
#     't_bid': 167,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 19,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 223,
#     't_ask': 211,
#     't_bid': 223,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 12,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 235,
#     't_ask': 235,
#     't_bid': 224,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 11,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 287,
#     't_ask': 287,
#     't_bid': 275,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 12,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 289,
#     't_ask': 289,
#     't_bid': 266,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 292,
#     't_ask': 290,
#     't_bid': 292,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 2,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 293,
#     't_ask': 293,
#     't_bid': 280,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 13,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 509,
#     't_ask': 509,
#     't_bid': 498,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 11,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 555,
#     't_ask': 510,
#     't_bid': 555,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 45,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 561,
#     't_ask': 561,
#     't_bid': 524,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 37,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 568,
#     't_ask': 568,
#     't_bid': 557,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 11,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 569,
#     't_ask': 569,
#     't_bid': 569,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 572,
#     't_ask': 572,
#     't_bid': 570,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 654,
#     't_ask': 654,
#     't_bid': 615,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 39,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 656,
#     't_ask': 656,
#     't_bid': 610,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 46,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 699,
#     't_ask': 699,
#     't_bid': 672,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 27,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 711,
#     't_ask': 711,
#     't_bid': 685,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 26,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 714,
#     't_ask': 714,
#     't_bid': 698,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 16,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 716,
#     't_ask': 716,
#     't_bid': 701,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 15,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 716,
#     't_ask': 716,
#     't_bid': 701,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 15,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 717,
#     't_ask': 717,
#     't_bid': 708,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 9,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 718,
#     't_ask': 718,
#     't_bid': 718,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 719,
#     't_ask': 719,
#     't_bid': 719,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 763,
#     't_ask': 763,
#     't_bid': 724,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 39,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 773,
#     't_ask': 773,
#     't_bid': 764,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 9,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 774,
#     't_ask': 774,
#     't_bid': 760,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 14,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 774,
#     't_ask': 774,
#     't_bid': 771,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 3,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 775,
#     't_ask': 775,
#     't_bid': 765,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 779,
#     't_ask': 779,
#     't_bid': 733,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 46,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 789,
#     't_ask': 789,
#     't_bid': 772,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 17,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 789,
#     't_ask': 789,
#     't_bid': 780,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 9,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 791,
#     't_ask': 791,
#     't_bid': 767,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 24,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 793,
#     't_ask': 793,
#     't_bid': 777,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 16,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 795,
#     't_ask': 795,
#     't_bid': 768,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 27,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 823,
#     't_ask': 793,
#     't_bid': 823,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 30,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 824,
#     't_ask': 824,
#     't_bid': 775,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 49,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 825,
#     't_ask': 825,
#     't_bid': 825,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 827,
#     't_ask': 827,
#     't_bid': 826,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 828,
#     't_ask': 828,
#     't_bid': 827,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 828,
#     't_ask': 828,
#     't_bid': 778,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 50,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 830,
#     't_ask': 830,
#     't_bid': 824,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 6,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 832,
#     't_ask': 832,
#     't_bid': 791,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 41,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 835,
#     't_ask': 796,
#     't_bid': 835,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 39,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 837,
#     't_ask': 837,
#     't_bid': 837,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 841,
#     't_ask': 841,
#     't_bid': 840,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 842,
#     't_ask': 798,
#     't_bid': 842,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 44,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 843,
#     't_ask': 843,
#     't_bid': 841,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 844,
#     't_ask': 844,
#     't_bid': 805,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 39,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 867,
#     't_ask': 867,
#     't_bid': 836,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 31,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 877,
#     't_ask': 846,
#     't_bid': 877,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 31,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 880,
#     't_ask': 880,
#     't_bid': 878,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 881,
#     't_ask': 845,
#     't_bid': 881,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 36,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 887,
#     't_ask': 878,
#     't_bid': 887,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 9,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 888,
#     't_ask': 888,
#     't_bid': 877,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 11,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 889,
#     't_ask': 889,
#     't_bid': 889,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 890,
#     't_ask': 890,
#     't_bid': 890,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 894,
#     't_ask': 894,
#     't_bid': 890,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 895,
#     't_ask': 895,
#     't_bid': 895,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 896,
#     't_ask': 896,
#     't_bid': 896,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 897,
#     't_ask': 897,
#     't_bid': 885,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 12,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 898,
#     't_ask': 898,
#     't_bid': 898,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 899,
#     't_ask': 899,
#     't_bid': 895,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 900,
#     't_ask': 899,
#     't_bid': 900,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 1,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 905,
#     't_ask': 905,
#     't_bid': 902,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 920,
#     't_ask': 920,
#     't_bid': 919,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 924,
#     't_ask': 881,
#     't_bid': 924,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 43,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 933,
#     't_ask': 933,
#     't_bid': 906,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 27,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 951,
#     't_ask': 951,
#     't_bid': 934,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 17,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 952,
#     't_ask': 942,
#     't_bid': 952,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 10,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 960,
#     't_ask': 925,
#     't_bid': 960,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 35,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 961,
#     't_ask': 961,
#     't_bid': 959,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 973,
#     't_ask': 973,
#     't_bid': 953,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 20,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 974,
#     't_ask': 974,
#     't_bid': 962,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 12,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 975,
#     't_ask': 975,
#     't_bid': 953,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 22,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 976,
#     't_ask': 976,
#     't_bid': 976,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 979,
#     't_ask': 934,
#     't_bid': 979,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 10,
#     'ask_lifetime': 45,
#     'price': 10,
#     'cost': 10,
#     'income': 10}],
#   'Wood': [{'t': 8,
#     't_ask': 8,
#     't_bid': 1,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 7,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 10,
#     't_ask': 10,
#     't_bid': 4,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 6,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 60,
#     't_ask': 60,
#     't_bid': 11,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 49,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 65,
#     't_ask': 62,
#     't_bid': 65,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 3,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 69,
#     't_ask': 69,
#     't_bid': 68,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 79,
#     't_ask': 79,
#     't_bid': 70,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 9,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 81,
#     't_ask': 81,
#     't_bid': 56,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 25,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 83,
#     't_ask': 82,
#     't_bid': 83,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 1,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 110,
#     't_ask': 110,
#     't_bid': 107,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 3,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 112,
#     't_ask': 71,
#     't_bid': 112,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 41,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 122,
#     't_ask': 122,
#     't_bid': 120,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 136,
#     't_ask': 86,
#     't_bid': 136,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 50,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 137,
#     't_ask': 137,
#     't_bid': 116,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 21,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 167,
#     't_ask': 167,
#     't_bid': 134,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 2,
#     'bid_lifetime': 33,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 167,
#     't_ask': 167,
#     't_bid': 162,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 168,
#     't_ask': 163,
#     't_bid': 168,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 5,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 171,
#     't_ask': 171,
#     't_bid': 171,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 174,
#     't_ask': 174,
#     't_bid': 174,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 175,
#     't_ask': 165,
#     't_bid': 175,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 10,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 176,
#     't_ask': 175,
#     't_bid': 176,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 1,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 189,
#     't_ask': 172,
#     't_bid': 189,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 17,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 190,
#     't_ask': 190,
#     't_bid': 178,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 12,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 216,
#     't_ask': 180,
#     't_bid': 216,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 36,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 217,
#     't_ask': 217,
#     't_bid': 192,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 25,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 231,
#     't_ask': 231,
#     't_bid': 230,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 232,
#     't_ask': 232,
#     't_bid': 187,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 45,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 234,
#     't_ask': 191,
#     't_bid': 234,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 43,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 236,
#     't_ask': 236,
#     't_bid': 235,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 237,
#     't_ask': 237,
#     't_bid': 237,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 238,
#     't_ask': 238,
#     't_bid': 219,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 19,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 239,
#     't_ask': 239,
#     't_bid': 218,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 241,
#     't_ask': 241,
#     't_bid': 240,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 245,
#     't_ask': 240,
#     't_bid': 245,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 5,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 247,
#     't_ask': 247,
#     't_bid': 220,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 2,
#     'bid_lifetime': 27,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 248,
#     't_ask': 248,
#     't_bid': 248,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 254,
#     't_ask': 252,
#     't_bid': 254,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 2,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 255,
#     't_ask': 219,
#     't_bid': 255,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 36,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 256,
#     't_ask': 239,
#     't_bid': 256,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 17,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 257,
#     't_ask': 257,
#     't_bid': 257,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 268,
#     't_ask': 268,
#     't_bid': 256,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 12,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 270,
#     't_ask': 270,
#     't_bid': 270,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 278,
#     't_ask': 271,
#     't_bid': 278,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 7,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 291,
#     't_ask': 258,
#     't_bid': 291,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 33,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 292,
#     't_ask': 292,
#     't_bid': 246,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 2,
#     'bid_lifetime': 46,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 322,
#     't_ask': 293,
#     't_bid': 322,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 29,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 323,
#     't_ask': 302,
#     't_bid': 323,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 21,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 325,
#     't_ask': 325,
#     't_bid': 323,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 326,
#     't_ask': 326,
#     't_bid': 326,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 327,
#     't_ask': 327,
#     't_bid': 282,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 45,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 328,
#     't_ask': 326,
#     't_bid': 328,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 2,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 329,
#     't_ask': 329,
#     't_bid': 329,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 329,
#     't_ask': 329,
#     't_bid': 309,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 20,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 331,
#     't_ask': 281,
#     't_bid': 331,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 50,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 335,
#     't_ask': 335,
#     't_bid': 330,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 5,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 336,
#     't_ask': 336,
#     't_bid': 336,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 357,
#     't_ask': 357,
#     't_bid': 337,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 20,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 362,
#     't_ask': 362,
#     't_bid': 338,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 24,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 364,
#     't_ask': 364,
#     't_bid': 336,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 28,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 379,
#     't_ask': 379,
#     't_bid': 332,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 47,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 380,
#     't_ask': 330,
#     't_bid': 380,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 50,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 381,
#     't_ask': 381,
#     't_bid': 337,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 44,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 395,
#     't_ask': 395,
#     't_bid': 383,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 12,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 396,
#     't_ask': 381,
#     't_bid': 396,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 15,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 397,
#     't_ask': 397,
#     't_bid': 397,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 416,
#     't_ask': 416,
#     't_bid': 416,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 417,
#     't_ask': 417,
#     't_bid': 399,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 18,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 418,
#     't_ask': 398,
#     't_bid': 418,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 20,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 419,
#     't_ask': 381,
#     't_bid': 419,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 38,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 420,
#     't_ask': 405,
#     't_bid': 420,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 15,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 431,
#     't_ask': 431,
#     't_bid': 397,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 34,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 433,
#     't_ask': 433,
#     't_bid': 421,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 12,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 434,
#     't_ask': 433,
#     't_bid': 434,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 435,
#     't_ask': 435,
#     't_bid': 435,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 460,
#     't_ask': 460,
#     't_bid': 436,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 24,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 461,
#     't_ask': 461,
#     't_bid': 437,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 24,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 463,
#     't_ask': 432,
#     't_bid': 463,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 31,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 464,
#     't_ask': 421,
#     't_bid': 464,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 43,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 469,
#     't_ask': 433,
#     't_bid': 469,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 36,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 470,
#     't_ask': 470,
#     't_bid': 470,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 471,
#     't_ask': 471,
#     't_bid': 471,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 471,
#     't_ask': 471,
#     't_bid': 437,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 34,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 472,
#     't_ask': 472,
#     't_bid': 472,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 486,
#     't_ask': 486,
#     't_bid': 465,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 21,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 487,
#     't_ask': 474,
#     't_bid': 487,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 13,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 488,
#     't_ask': 488,
#     't_bid': 467,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 21,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 489,
#     't_ask': 474,
#     't_bid': 489,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 15,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 492,
#     't_ask': 485,
#     't_bid': 492,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 7,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 495,
#     't_ask': 487,
#     't_bid': 495,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 8,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 498,
#     't_ask': 498,
#     't_bid': 498,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 499,
#     't_ask': 468,
#     't_bid': 499,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 31,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 500,
#     't_ask': 500,
#     't_bid': 500,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 501,
#     't_ask': 501,
#     't_bid': 467,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 34,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 502,
#     't_ask': 502,
#     't_bid': 502,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 503,
#     't_ask': 493,
#     't_bid': 503,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 10,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 504,
#     't_ask': 491,
#     't_bid': 504,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 13,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 507,
#     't_ask': 507,
#     't_bid': 490,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 17,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 521,
#     't_ask': 505,
#     't_bid': 521,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 16,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 523,
#     't_ask': 523,
#     't_bid': 522,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 524,
#     't_ask': 505,
#     't_bid': 524,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 19,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 540,
#     't_ask': 540,
#     't_bid': 504,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 36,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 541,
#     't_ask': 526,
#     't_bid': 541,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 15,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 542,
#     't_ask': 542,
#     't_bid': 541,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 547,
#     't_ask': 547,
#     't_bid': 500,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 47,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 549,
#     't_ask': 543,
#     't_bid': 549,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 6,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 550,
#     't_ask': 542,
#     't_bid': 550,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 8,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 550,
#     't_ask': 525,
#     't_bid': 550,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 25,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 551,
#     't_ask': 528,
#     't_bid': 551,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 23,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 553,
#     't_ask': 553,
#     't_bid': 514,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 39,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 558,
#     't_ask': 558,
#     't_bid': 551,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 7,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 559,
#     't_ask': 554,
#     't_bid': 559,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 5,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 560,
#     't_ask': 560,
#     't_bid': 560,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 561,
#     't_ask': 561,
#     't_bid': 559,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 562,
#     't_ask': 544,
#     't_bid': 562,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
# ...
#     'cost': 6,
#     'income': 6},
#    {'t': 787,
#     't_ask': 787,
#     't_bid': 778,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 9,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 788,
#     't_ask': 788,
#     't_bid': 786,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 792,
#     't_ask': 766,
#     't_bid': 792,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 26,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 792,
#     't_ask': 790,
#     't_bid': 792,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 2,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 793,
#     't_ask': 793,
#     't_bid': 765,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 28,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 794,
#     't_ask': 794,
#     't_bid': 794,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 794,
#     't_ask': 794,
#     't_bid': 785,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 9,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 795,
#     't_ask': 795,
#     't_bid': 763,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 32,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 800,
#     't_ask': 795,
#     't_bid': 800,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 5,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 813,
#     't_ask': 805,
#     't_bid': 813,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 8,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 814,
#     't_ask': 814,
#     't_bid': 814,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 828,
#     't_ask': 828,
#     't_bid': 819,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 9,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 832,
#     't_ask': 823,
#     't_bid': 832,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 9,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 834,
#     't_ask': 834,
#     't_bid': 833,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 835,
#     't_ask': 835,
#     't_bid': 801,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 34,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 835,
#     't_ask': 835,
#     't_bid': 815,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 20,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 836,
#     't_ask': 836,
#     't_bid': 836,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 836,
#     't_ask': 835,
#     't_bid': 836,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 1,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 837,
#     't_ask': 837,
#     't_bid': 793,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 44,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 838,
#     't_ask': 838,
#     't_bid': 838,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 839,
#     't_ask': 839,
#     't_bid': 839,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 843,
#     't_ask': 843,
#     't_bid': 838,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 5,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 848,
#     't_ask': 848,
#     't_bid': 848,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 848,
#     't_ask': 840,
#     't_bid': 848,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 8,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 849,
#     't_ask': 849,
#     't_bid': 845,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 850,
#     't_ask': 850,
#     't_bid': 839,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 11,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 851,
#     't_ask': 851,
#     't_bid': 851,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 851,
#     't_ask': 834,
#     't_bid': 851,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 17,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 852,
#     't_ask': 852,
#     't_bid': 852,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 853,
#     't_ask': 853,
#     't_bid': 853,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 854,
#     't_ask': 854,
#     't_bid': 854,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 882,
#     't_ask': 855,
#     't_bid': 882,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 27,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 884,
#     't_ask': 853,
#     't_bid': 884,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 31,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 891,
#     't_ask': 891,
#     't_bid': 855,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 36,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 892,
#     't_ask': 885,
#     't_bid': 892,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 7,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 892,
#     't_ask': 853,
#     't_bid': 892,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 39,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 894,
#     't_ask': 894,
#     't_bid': 893,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 895,
#     't_ask': 895,
#     't_bid': 849,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 46,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 898,
#     't_ask': 854,
#     't_bid': 898,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 44,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 902,
#     't_ask': 902,
#     't_bid': 900,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 903,
#     't_ask': 903,
#     't_bid': 901,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 904,
#     't_ask': 904,
#     't_bid': 904,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 910,
#     't_ask': 910,
#     't_bid': 908,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 911,
#     't_ask': 911,
#     't_bid': 911,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 912,
#     't_ask': 912,
#     't_bid': 897,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 15,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 913,
#     't_ask': 913,
#     't_bid': 899,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 14,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 915,
#     't_ask': 902,
#     't_bid': 915,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 13,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 916,
#     't_ask': 896,
#     't_bid': 916,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 20,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 916,
#     't_ask': 905,
#     't_bid': 916,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 11,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 917,
#     't_ask': 917,
#     't_bid': 917,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 936,
#     't_ask': 918,
#     't_bid': 936,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 18,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 953,
#     't_ask': 953,
#     't_bid': 937,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 16,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 954,
#     't_ask': 954,
#     't_bid': 944,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 10,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 955,
#     't_ask': 955,
#     't_bid': 914,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 41,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 956,
#     't_ask': 956,
#     't_bid': 917,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 39,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 957,
#     't_ask': 956,
#     't_bid': 957,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 1,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 988,
#     't_ask': 988,
#     't_bid': 958,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 30,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 995,
#     't_ask': 995,
#     't_bid': 986,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 9,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 997,
#     't_ask': 957,
#     't_bid': 997,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 40,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 998,
#     't_ask': 960,
#     't_bid': 998,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 38,
#     'price': 6,
#     'cost': 6,
#     'income': 6}]},
#  [{'t': 82, 'builder': 1, 'loc': [1, 5], 'income': 16.472372947006132},
#   {'t': 141, 'builder': 1, 'loc': [2, 3], 'income': 16.472372947006132},
#   {'t': 200, 'builder': 1, 'loc': [2, 2], 'income': 16.472372947006132},
#   {'t': 226, 'builder': 1, 'loc': [2, 4], 'income': 16.472372947006132},
#   {'t': 295, 'builder': 1, 'loc': [2, 5], 'income': 16.472372947006132},
#   {'t': 580, 'builder': 1, 'loc': [8, 5], 'income': 16.472372947006132},
#   {'t': 585, 'builder': 1, 'loc': [10, 4], 'income': 16.472372947006132},
#   {'t': 667, 'builder': 0, 'loc': [16, 2], 'income': 13.267112338979295},
#   {'t': 674, 'builder': 0, 'loc': [15, 2], 'income': 13.267112338979295},
#   {'t': 680, 'builder': 0, 'loc': [16, 3], 'income': 13.267112338979295},
#   {'t': 700, 'builder': 1, 'loc': [6, 0], 'income': 16.472372947006132},
#   {'t': 738, 'builder': 1, 'loc': [11, 0], 'income': 16.472372947006132},
#   {'t': 750, 'builder': 0, 'loc': [17, 0], 'income': 13.267112338979295},
#   {'t': 800, 'builder': 0, 'loc': [14, 3], 'income': 13.267112338979295},
#   {'t': 846, 'builder': 3, 'loc': [3, 4], 'income': 11.331640623590097},
#   {'t': 886, 'builder': 1, 'loc': [8, 3], 'income': 16.472372947006132},
#   {'t': 901, 'builder': 1, 'loc': [7, 3], 'income': 16.472372947006132},
#   {'t': 921, 'builder': 2, 'loc': [4, 20], 'income': 22.249614304395735},
#   {'t': 923, 'builder': 3, 'loc': [3, 11], 'income': 11.331640623590097},
#   {'t': 939, 'builder': 1, 'loc': [11, 5], 'income': 16.472372947006132},
#   {'t': 941, 'builder': 0, 'loc': [15, 0], 'income': 13.267112338979295},
#   {'t': 960, 'builder': 1, 'loc': [10, 1], 'income': 16.472372947006132},
#   {'t': 966, 'builder': 0, 'loc': [18, 3], 'income': 13.267112338979295},
#   {'t': 977, 'builder': 2, 'loc': [1, 22], 'income': 22.249614304395735},
#   {'t': 982, 'builder': 0, 'loc': [19, 3], 'income': 13.267112338979295},
#   {'t': 984, 'builder': 0, 'loc': [20, 3], 'income': 13.267112338979295},
#   {'t': 992, 'builder': 0, 'loc': [18, 4], 'income': 13.267112338979295},
#   {'t': 995, 'builder': 0, 'loc': [19, 4], 'income': 13.267112338979295}])

# %% [markdown]
# # Next
#
# Now that you've seen how to interact with the simulation and generate episodes, try the next tutorial ([economic_simulation_advanced.ipynb](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_advanced.ipynb)) that explains how the simulation is composed of low-level Components and Entities. This structure enables flexible extensions of the economic simulation.

# %% [markdown]
# # Split-Wold

# %%
#multi_zone/simple_wood_and_stone

# %%
from ai_economist import foundation

# --- 1. Configure the SPLIT-LAYOUT environment ---
env_config_split = {
    'scenario_name': 'split_layout/simple_wood_and_stone',

    'components': [
        ('Build', {'skill_dist': "pareto", 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],

    'env_layout_file': 'quadrant_25x25_20each_30clump.txt',
    'starting_agent_coin': 10,
    'fixed_four_skill_and_loc': False,

    'n_agents': 4,
    'world_size': [25, 25],
    'episode_length': 1000,

    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,

    'flatten_observations': False,
    'flatten_masks': True,
}

# --- 2. Create environment instance ---
split_env = foundation.make_env_instance(**env_config_split)

# --- 3. Run a random episode & visualize every 100 steps ---
play_random_episode(split_env, plot_every=100)

# %%
obs = split_env.reset(force_dense_logging=True)

for t in range(split_env.episode_length):
    actions = sample_random_actions(split_env, obs)
    obs, rew, done, info = split_env.step(actions)

# %%
dense_log_split = split_env.previous_episode_dense_log

plotting.breakdown(dense_log_split)
# Out:
# _______________:_ Agent  0 _____|_ Agent  1 _____|_ Agent  2 _____|_ Agent  3 ____
# Cost (Wood)    :   5.00 (n= 18) |   5.54 (n= 35) |   5.57 (n= 44) |   5.36 (n= 22)
# Cost (Stone)   :   4.77 (n= 57) |   4.84 (n= 69) |   4.17 (n= 70) |   3.96 (n= 49)
#
# Income (Wood)  :   4.58 (n= 26) |   6.03 (n= 32) |   5.42 (n= 40) |   5.62 (n= 21)
# Income (Stone) :   4.24 (n= 55) |   4.69 (n= 74) |   4.29 (n= 68) |   4.58 (n= 48)
# Income (Build) :  22.25 (n=  3) |  16.45 (n=  3) |  13.26 (n=  4) |  11.33 (n=  1)
# ((<Figure size 1600x300 with 5 Axes>,
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 1600x800 with 8 Axes>),
#  {'Sell Stone': [233, 347, 292, 220],
#   'Buy Stone': [-272, -334, -292, -194],
#   'Sell Wood': [119, 193, 217, 118],
#   'Buy Wood': [-90, -194, -245, -118],
#   'Build': [66.75802070295842,
#    49.33626671110757,
#    53.037554628154126,
#    11.326976108292328],
#   'Total': array([56.7580207 , 61.33626671, 25.03755463, 37.32697611])},
#  [66, 71, 35, 47],
#  {'Stone': [{'t': 55,
#     't_ask': 55,
#     't_bid': 55,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 56,
#     't_ask': 56,
#     't_bid': 55,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 60,
#     't_ask': 56,
#     't_bid': 60,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 4,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 62,
#     't_ask': 57,
#     't_bid': 62,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 5,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 117,
#     't_ask': 117,
#     't_bid': 70,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 47,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 119,
#     't_ask': 119,
#     't_bid': 116,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 3,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 120,
#     't_ask': 120,
#     't_bid': 115,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 5,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 157,
#     't_ask': 157,
#     't_bid': 142,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 15,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 161,
#     't_ask': 161,
#     't_bid': 117,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 2,
#     'bid_lifetime': 44,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 163,
#     't_ask': 163,
#     't_bid': 144,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 2,
#     'bid_lifetime': 19,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 169,
#     't_ask': 169,
#     't_bid': 165,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 231,
#     't_ask': 231,
#     't_bid': 215,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 16,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 233,
#     't_ask': 233,
#     't_bid': 228,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 234,
#     't_ask': 227,
#     't_bid': 234,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 7,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 274,
#     't_ask': 263,
#     't_bid': 274,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 11,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 275,
#     't_ask': 235,
#     't_bid': 275,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 40,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 276,
#     't_ask': 276,
#     't_bid': 229,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 47,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 277,
#     't_ask': 277,
#     't_bid': 234,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 43,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 279,
#     't_ask': 232,
#     't_bid': 279,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 47,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 306,
#     't_ask': 279,
#     't_bid': 306,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 27,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 307,
#     't_ask': 307,
#     't_bid': 281,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 26,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 326,
#     't_ask': 286,
#     't_bid': 326,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 40,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 329,
#     't_ask': 329,
#     't_bid': 307,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 22,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 333,
#     't_ask': 318,
#     't_bid': 333,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 15,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 334,
#     't_ask': 334,
#     't_bid': 331,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 3,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 335,
#     't_ask': 329,
#     't_bid': 335,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 6,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 337,
#     't_ask': 333,
#     't_bid': 337,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 4,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 338,
#     't_ask': 337,
#     't_bid': 338,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 1,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 360,
#     't_ask': 360,
#     't_bid': 340,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 20,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 361,
#     't_ask': 361,
#     't_bid': 338,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 362,
#     't_ask': 362,
#     't_bid': 336,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 26,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 390,
#     't_ask': 390,
#     't_bid': 381,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 9,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 391,
#     't_ask': 391,
#     't_bid': 364,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 27,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 392,
#     't_ask': 363,
#     't_bid': 392,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 29,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 397,
#     't_ask': 362,
#     't_bid': 397,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 35,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 427,
#     't_ask': 398,
#     't_bid': 427,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 29,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 429,
#     't_ask': 429,
#     't_bid': 428,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 431,
#     't_ask': 397,
#     't_bid': 431,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 34,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 432,
#     't_ask': 432,
#     't_bid': 390,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 42,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 433,
#     't_ask': 433,
#     't_bid': 429,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 433,
#     't_ask': 433,
#     't_bid': 433,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 434,
#     't_ask': 434,
#     't_bid': 393,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 41,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 435,
#     't_ask': 435,
#     't_bid': 398,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 37,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 435,
#     't_ask': 435,
#     't_bid': 411,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 2,
#     'bid_lifetime': 24,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 436,
#     't_ask': 432,
#     't_bid': 436,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 4,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 437,
#     't_ask': 437,
#     't_bid': 437,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 438,
#     't_ask': 438,
#     't_bid': 401,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 37,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 439,
#     't_ask': 438,
#     't_bid': 439,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 1,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 440,
#     't_ask': 437,
#     't_bid': 440,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 3,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 441,
#     't_ask': 394,
#     't_bid': 441,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 47,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 443,
#     't_ask': 443,
#     't_bid': 441,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 444,
#     't_ask': 444,
#     't_bid': 443,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 480,
#     't_ask': 480,
#     't_bid': 446,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 34,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 482,
#     't_ask': 482,
#     't_bid': 445,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 37,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 483,
#     't_ask': 483,
#     't_bid': 483,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 484,
#     't_ask': 449,
#     't_bid': 484,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 35,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 517,
#     't_ask': 489,
#     't_bid': 517,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 5,
#     'ask_lifetime': 28,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 519,
#     't_ask': 490,
#     't_bid': 519,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 29,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 521,
#     't_ask': 492,
#     't_bid': 521,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 29,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 542,
#     't_ask': 542,
#     't_bid': 540,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 544,
#     't_ask': 544,
#     't_bid': 543,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 547,
#     't_ask': 547,
#     't_bid': 545,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 548,
#     't_ask': 548,
#     't_bid': 548,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 548,
#     't_ask': 548,
#     't_bid': 532,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 16,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 549,
#     't_ask': 549,
#     't_bid': 549,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 550,
#     't_ask': 545,
#     't_bid': 550,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 5,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 551,
#     't_ask': 551,
#     't_bid': 540,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 11,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 579,
#     't_ask': 549,
#     't_bid': 579,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 30,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 580,
#     't_ask': 551,
#     't_bid': 580,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 29,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 582,
#     't_ask': 582,
#     't_bid': 582,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 585,
#     't_ask': 552,
#     't_bid': 585,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 33,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 587,
#     't_ask': 587,
#     't_bid': 583,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 588,
#     't_ask': 545,
#     't_bid': 588,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 43,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 589,
#     't_ask': 589,
#     't_bid': 589,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 596,
#     't_ask': 596,
#     't_bid': 583,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 13,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 597,
#     't_ask': 597,
#     't_bid': 547,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 50,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 602,
#     't_ask': 602,
#     't_bid': 590,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 12,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 627,
#     't_ask': 604,
#     't_bid': 627,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 23,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 628,
#     't_ask': 589,
#     't_bid': 628,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 39,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 645,
#     't_ask': 643,
#     't_bid': 645,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 646,
#     't_ask': 637,
#     't_bid': 646,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 9,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 648,
#     't_ask': 648,
#     't_bid': 636,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 12,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 648,
#     't_ask': 648,
#     't_bid': 626,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 22,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 650,
#     't_ask': 650,
#     't_bid': 628,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 22,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 651,
#     't_ask': 651,
#     't_bid': 648,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 652,
#     't_ask': 650,
#     't_bid': 652,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 2,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 653,
#     't_ask': 653,
#     't_bid': 653,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 654,
#     't_ask': 654,
#     't_bid': 654,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 656,
#     't_ask': 654,
#     't_bid': 656,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 657,
#     't_ask': 657,
#     't_bid': 632,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 2,
#     'bid_lifetime': 25,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 658,
#     't_ask': 658,
#     't_bid': 658,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 658,
#     't_ask': 629,
#     't_bid': 658,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 29,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 659,
#     't_ask': 659,
#     't_bid': 659,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 666,
#     't_ask': 651,
#     't_bid': 666,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 15,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 667,
#     't_ask': 649,
#     't_bid': 667,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 18,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 668,
#     't_ask': 649,
#     't_bid': 668,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 19,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 669,
#     't_ask': 655,
#     't_bid': 669,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 14,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 670,
#     't_ask': 670,
#     't_bid': 669,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 671,
#     't_ask': 671,
#     't_bid': 671,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 672,
#     't_ask': 672,
#     't_bid': 660,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 12,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 675,
#     't_ask': 675,
#     't_bid': 667,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 8,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 677,
#     't_ask': 677,
#     't_bid': 663,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 14,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 678,
#     't_ask': 678,
#     't_bid': 678,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 679,
#     't_ask': 679,
#     't_bid': 660,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 19,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 680,
#     't_ask': 659,
#     't_bid': 680,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 21,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 680,
#     't_ask': 660,
#     't_bid': 680,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 20,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 683,
#     't_ask': 676,
#     't_bid': 683,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 7,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 701,
#     't_ask': 697,
#     't_bid': 701,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 4,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 702,
#     't_ask': 702,
#     't_bid': 702,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 706,
#     't_ask': 657,
#     't_bid': 706,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 9,
#     'ask_lifetime': 49,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 707,
#     't_ask': 707,
#     't_bid': 702,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 5,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 708,
#     't_ask': 708,
#     't_bid': 703,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 708,
#     't_ask': 708,
#     't_bid': 704,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 709,
#     't_ask': 709,
#     't_bid': 709,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 710,
#     't_ask': 710,
#     't_bid': 663,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 47,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 712,
#     't_ask': 712,
#     't_bid': 712,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 713,
#     't_ask': 709,
#     't_bid': 713,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 4,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 714,
#     't_ask': 714,
#     't_bid': 714,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 715,
#     't_ask': 715,
#     't_bid': 715,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 716,
#     't_ask': 716,
#     't_bid': 716,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 717,
#     't_ask': 715,
#     't_bid': 717,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 2,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 719,
#     't_ask': 719,
#     't_bid': 718,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 723,
#     't_ask': 723,
#     't_bid': 723,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 730,
#     't_ask': 718,
#     't_bid': 730,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 12,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 732,
#     't_ask': 732,
#     't_bid': 732,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 733,
#     't_ask': 733,
#     't_bid': 724,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 9,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 733,
#     't_ask': 720,
#     't_bid': 733,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 13,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 735,
#     't_ask': 734,
#     't_bid': 735,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 1,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 736,
#     't_ask': 735,
#     't_bid': 736,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 1,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 736,
#     't_ask': 691,
#     't_bid': 736,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 45,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 739,
#     't_ask': 739,
#     't_bid': 738,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 742,
#     't_ask': 742,
#     't_bid': 734,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 8,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 743,
#     't_ask': 743,
#     't_bid': 740,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 3,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 743,
#     't_ask': 743,
#     't_bid': 724,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 19,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 744,
#     't_ask': 744,
#     't_bid': 744,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 745,
#     't_ask': 725,
#     't_bid': 745,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 20,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 746,
#     't_ask': 746,
#     't_bid': 746,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 748,
#     't_ask': 738,
#     't_bid': 748,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 10,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 760,
#     't_ask': 747,
#     't_bid': 760,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 13,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 761,
#     't_ask': 761,
#     't_bid': 750,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 11,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 768,
#     't_ask': 768,
#     't_bid': 762,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 6,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 771,
#     't_ask': 771,
#     't_bid': 770,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 772,
#     't_ask': 772,
#     't_bid': 772,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 774,
#     't_ask': 772,
#     't_bid': 774,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 775,
#     't_ask': 762,
#     't_bid': 775,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 13,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 776,
#     't_ask': 776,
#     't_bid': 750,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 26,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 776,
#     't_ask': 776,
#     't_bid': 774,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 777,
#     't_ask': 777,
#     't_bid': 769,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 8,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 779,
#     't_ask': 779,
#     't_bid': 778,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 780,
#     't_ask': 780,
#     't_bid': 779,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 781,
#     't_ask': 781,
#     't_bid': 780,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 783,
#     't_ask': 781,
#     't_bid': 783,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 2,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 787,
#     't_ask': 787,
#     't_bid': 785,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 2,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 788,
#     't_ask': 788,
#     't_bid': 747,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 41,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 789,
#     't_ask': 789,
#     't_bid': 789,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 789,
#     't_ask': 788,
#     't_bid': 789,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 1,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 791,
#     't_ask': 791,
#     't_bid': 791,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 793,
#     't_ask': 793,
#     't_bid': 790,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 794,
#     't_ask': 794,
#     't_bid': 749,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 45,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 797,
#     't_ask': 797,
#     't_bid': 797,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 798,
#     't_ask': 798,
#     't_bid': 763,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 35,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 799,
#     't_ask': 799,
#     't_bid': 799,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 800,
#     't_ask': 800,
#     't_bid': 800,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 801,
#     't_ask': 801,
#     't_bid': 776,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 3,
#     'bid_lifetime': 25,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 802,
#     't_ask': 802,
#     't_bid': 795,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 7,
#     'seller': 0,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 803,
#     't_ask': 803,
#     't_bid': 803,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 804,
#     't_ask': 802,
#     't_bid': 804,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 2,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 815,
#     't_ask': 815,
#     't_bid': 803,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 12,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 816,
#     't_ask': 816,
#     't_bid': 804,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 4,
#     'bid_lifetime': 12,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 836,
#     't_ask': 806,
#     't_bid': 836,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 30,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 837,
#     't_ask': 837,
#     't_bid': 828,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 9,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 837,
#     't_ask': 837,
#     't_bid': 791,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 3,
#     'bid_lifetime': 46,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 839,
#     't_ask': 836,
#     't_bid': 839,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 3,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 840,
#     't_ask': 840,
#     't_bid': 840,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 841,
#     't_ask': 792,
#     't_bid': 841,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 49,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 842,
#     't_ask': 842,
#     't_bid': 842,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 844,
#     't_ask': 844,
#     't_bid': 843,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 6,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 846,
#     't_ask': 846,
#     't_bid': 846,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 847,
#     't_ask': 847,
#     't_bid': 847,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 849,
#     't_ask': 816,
#     't_bid': 849,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 33,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 850,
#     't_ask': 850,
#     't_bid': 850,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 851,
#     't_ask': 851,
#     't_bid': 851,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 852,
#     't_ask': 852,
#     't_bid': 849,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 3,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 854,
#     't_ask': 854,
#     't_bid': 838,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 16,
#     'seller': 0,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 857,
#     't_ask': 854,
#     't_bid': 857,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 3,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 858,
#     't_ask': 858,
#     't_bid': 855,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 859,
#     't_ask': 859,
#     't_bid': 841,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 4,
#     'bid_lifetime': 18,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 860,
#     't_ask': 835,
#     't_bid': 860,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 25,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 862,
#     't_ask': 862,
#     't_bid': 862,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 863,
#     't_ask': 863,
#     't_bid': 863,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 865,
#     't_ask': 865,
#     't_bid': 838,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 27,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 867,
#     't_ask': 867,
#     't_bid': 848,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 2,
#     'bid_lifetime': 19,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 868,
#     't_ask': 868,
#     't_bid': 868,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 869,
#     't_ask': 869,
#     't_bid': 869,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 870,
#     't_ask': 862,
#     't_bid': 870,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 8,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 871,
#     't_ask': 871,
#     't_bid': 866,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 2,
#     'bid_lifetime': 5,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 872,
#     't_ask': 861,
#     't_bid': 872,
#     'commodity': 'Stone',
#     'buyer': 0,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 11,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 873,
#     't_ask': 868,
#     't_bid': 873,
#     'commodity': 'Stone',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 5,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 874,
#     't_ask': 874,
#     't_bid': 869,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 2,
#     'bid_lifetime': 5,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 885,
#     't_ask': 874,
#     't_bid': 885,
#     'commodity': 'Stone',
#     'buyer': 3,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 11,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 885,
#     't_ask': 875,
#     't_bid': 885,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 10,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 886,
#     't_ask': 886,
#     't_bid': 886,
#     'commodity': 'Stone',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 1,
#     'cost': 1,
#     'income': 1},
#    {'t': 888,
#     't_ask': 888,
#     't_bid': 888,
# ...
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 402,
#     't_ask': 360,
#     't_bid': 402,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 8,
#     'ask_lifetime': 42,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 403,
#     't_ask': 403,
#     't_bid': 365,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 38,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 429,
#     't_ask': 429,
#     't_bid': 408,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 21,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 430,
#     't_ask': 430,
#     't_bid': 407,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 3,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 449,
#     't_ask': 433,
#     't_bid': 449,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 16,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 452,
#     't_ask': 411,
#     't_bid': 452,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 41,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 453,
#     't_ask': 453,
#     't_bid': 453,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 453,
#     't_ask': 453,
#     't_bid': 430,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 23,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 454,
#     't_ask': 454,
#     't_bid': 454,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 454,
#     't_ask': 408,
#     't_bid': 454,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 46,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 455,
#     't_ask': 455,
#     't_bid': 455,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 457,
#     't_ask': 457,
#     't_bid': 456,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 1,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 457,
#     't_ask': 457,
#     't_bid': 449,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 8,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 459,
#     't_ask': 459,
#     't_bid': 419,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 40,
#     'seller': 1,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 462,
#     't_ask': 462,
#     't_bid': 462,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 465,
#     't_ask': 465,
#     't_bid': 465,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 466,
#     't_ask': 458,
#     't_bid': 466,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 8,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 467,
#     't_ask': 467,
#     't_bid': 461,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 6,
#     'seller': 1,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 509,
#     't_ask': 459,
#     't_bid': 509,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 50,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 510,
#     't_ask': 510,
#     't_bid': 466,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 44,
#     'seller': 3,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 511,
#     't_ask': 467,
#     't_bid': 511,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 44,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 512,
#     't_ask': 512,
#     't_bid': 509,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 3,
#     'seller': 2,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 515,
#     't_ask': 515,
#     't_bid': 511,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 516,
#     't_ask': 516,
#     't_bid': 513,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 3,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 517,
#     't_ask': 517,
#     't_bid': 513,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 1,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 518,
#     't_ask': 518,
#     't_bid': 514,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 6,
#     'bid_lifetime': 4,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 520,
#     't_ask': 520,
#     't_bid': 520,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 522,
#     't_ask': 522,
#     't_bid': 501,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 3,
#     'bid_lifetime': 21,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 524,
#     't_ask': 518,
#     't_bid': 524,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 6,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 524,
#     't_ask': 523,
#     't_bid': 524,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 1,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 525,
#     't_ask': 525,
#     't_bid': 525,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 3,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 527,
#     't_ask': 519,
#     't_bid': 527,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 8,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 528,
#     't_ask': 526,
#     't_bid': 528,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 530,
#     't_ask': 530,
#     't_bid': 502,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 3,
#     'bid_lifetime': 28,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 3,
#     'cost': 3,
#     'income': 3},
#    {'t': 531,
#     't_ask': 523,
#     't_bid': 531,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 8,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 532,
#     't_ask': 532,
#     't_bid': 531,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 0,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 534,
#     't_ask': 534,
#     't_bid': 532,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 4,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 535,
#     't_ask': 533,
#     't_bid': 535,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 2,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 538,
#     't_ask': 538,
#     't_bid': 536,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 2,
#     'seller': 2,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 539,
#     't_ask': 535,
#     't_bid': 539,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 4,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 541,
#     't_ask': 541,
#     't_bid': 541,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 6,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 577,
#     't_ask': 577,
#     't_bid': 563,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 14,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 578,
#     't_ask': 578,
#     't_bid': 572,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 6,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 580,
#     't_ask': 580,
#     't_bid': 555,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 25,
#     'seller': 3,
#     'ask': 6,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 594,
#     't_ask': 594,
#     't_bid': 582,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 12,
#     'seller': 1,
#     'ask': 7,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 613,
#     't_ask': 613,
#     't_bid': 593,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 20,
#     'seller': 2,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 9,
#     'cost': 9,
#     'income': 9},
#    {'t': 614,
#     't_ask': 614,
#     't_bid': 595,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 10,
#     'bid_lifetime': 19,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 614,
#     't_ask': 614,
#     't_bid': 581,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 33,
#     'seller': 2,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 615,
#     't_ask': 615,
#     't_bid': 587,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 6,
#     'bid_lifetime': 28,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 6,
#     'cost': 6,
#     'income': 6},
#    {'t': 616,
#     't_ask': 616,
#     't_bid': 595,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 7,
#     'bid_lifetime': 21,
#     'seller': 2,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 616,
#     't_ask': 616,
#     't_bid': 615,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 5,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 618,
#     't_ask': 618,
#     't_bid': 618,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 0,
#     'cost': 0,
#     'income': 0},
#    {'t': 619,
#     't_ask': 616,
#     't_bid': 619,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 3,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 621,
#     't_ask': 621,
#     't_bid': 584,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 4,
#     'bid_lifetime': 37,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 4,
#     'cost': 4,
#     'income': 4},
#    {'t': 635,
#     't_ask': 621,
#     't_bid': 635,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 9,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 8,
#     'ask_lifetime': 14,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 636,
#     't_ask': 620,
#     't_bid': 636,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 5,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 5,
#     'ask_lifetime': 16,
#     'price': 5,
#     'cost': 5,
#     'income': 5},
#    {'t': 637,
#     't_ask': 637,
#     't_bid': 637,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 7,
#     'bid_lifetime': 0,
#     'seller': 1,
#     'ask': 2,
#     'ask_lifetime': 0,
#     'price': 2,
#     'cost': 2,
#     'income': 2},
#    {'t': 638,
#     't_ask': 623,
#     't_bid': 638,
#     'commodity': 'Wood',
#     'buyer': 0,
#     'bid': 10,
#     'bid_lifetime': 0,
#     'seller': 2,
#     'ask': 8,
#     'ask_lifetime': 15,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 646,
#     't_ask': 640,
#     't_bid': 646,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 0,
#     'seller': 0,
#     'ask': 7,
#     'ask_lifetime': 6,
#     'price': 7,
#     'cost': 7,
#     'income': 7},
#    {'t': 727,
#     't_ask': 727,
#     't_bid': 721,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 6,
#     'seller': 2,
#     'ask': 0,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 731,
#     't_ask': 731,
#     't_bid': 728,
#     'commodity': 'Wood',
#     'buyer': 2,
#     'bid': 8,
#     'bid_lifetime': 3,
#     'seller': 1,
#     'ask': 1,
#     'ask_lifetime': 0,
#     'price': 8,
#     'cost': 8,
#     'income': 8},
#    {'t': 908,
#     't_ask': 908,
#     't_bid': 889,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 19,
#     'seller': 0,
#     'ask': 9,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 909,
#     't_ask': 909,
#     't_bid': 898,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 11,
#     'seller': 1,
#     'ask': 4,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 911,
#     't_ask': 911,
#     't_bid': 910,
#     'commodity': 'Wood',
#     'buyer': 1,
#     'bid': 10,
#     'bid_lifetime': 1,
#     'seller': 3,
#     'ask': 3,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10},
#    {'t': 933,
#     't_ask': 933,
#     't_bid': 900,
#     'commodity': 'Wood',
#     'buyer': 3,
#     'bid': 10,
#     'bid_lifetime': 33,
#     'seller': 1,
#     'ask': 10,
#     'ask_lifetime': 0,
#     'price': 10,
#     'cost': 10,
#     'income': 10}]},
#  [{'t': 198, 'builder': 2, 'loc': [24, 8], 'income': 13.259388657038532},
#   {'t': 266, 'builder': 2, 'loc': [24, 10], 'income': 13.259388657038532},
#   {'t': 399, 'builder': 2, 'loc': [24, 6], 'income': 13.259388657038532},
#   {'t': 554, 'builder': 1, 'loc': [19, 0], 'income': 16.445422237035856},
#   {'t': 613, 'builder': 1, 'loc': [23, 5], 'income': 16.445422237035856},
#   {'t': 639, 'builder': 0, 'loc': [4, 6], 'income': 22.252673567652806},
#   {'t': 665, 'builder': 0, 'loc': [2, 4], 'income': 22.252673567652806},
#   {'t': 692, 'builder': 1, 'loc': [23, 2], 'income': 16.445422237035856},
#   {'t': 712, 'builder': 0, 'loc': [6, 5], 'income': 22.252673567652806},
#   {'t': 735, 'builder': 2, 'loc': [13, 14], 'income': 13.259388657038532},
#   {'t': 941, 'builder': 3, 'loc': [22, 1], 'income': 11.326976108292328}])

# %%
env_config_split_big = {
    'scenario_name': 'split_layout/simple_wood_and_stone',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 4,
    'world_size': [60, 60],
    'episode_length': 1000,
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    'flatten_observations': False,
    'flatten_masks': True,

    # Layout controls
    'env_layout_file': 'random_60x60_ws.txt',
    'fixed_four_skill_and_loc': False,
    'starting_agent_coin': 10,

    # Logging
    'dense_log_frequency': 1,
}


split_env_big = foundation.make_env_instance(**env_config_split_big)


play_random_episode(split_env_big, plot_every=100)

# %%
env_config = {
    'scenario_name': 'layout_from_file/simple_wood_and_stone', #no waterline weeee
    'components': [
        ('Build', {'skill_dist':'pareto', 'payment_max_skill_multiplier':3}),
        ('ContinuousDoubleAuction', {'max_num_orders':5}),
        ('Gather', {})
    ],
    'n_agents': 4,
    'world_size': [25,25],
    'env_layout_file':'quadrant_25x25_20each_30clump.txt',

    # NEW: custom start positions
    'agent_start_locs': [(5,5), (5,20), (20,5), (20,20)],

    'starting_agent_coin': 10,
}
env = foundation.make_env_instance(**env_config)
env.reset()

print([agent.loc for agent in env.world.agents])

env = foundation.make_env_instance(**env_config)


play_random_episode(env, plot_every=100)

# %% [markdown]
# ## this next part might just be deleted

# %% [markdown]
# Creating file

# %%
import os
import numpy as np

def make_random_layout_file(
    H=60, W=60,
    p_wood=0.12, p_stone=0.12, p_water=0.00,
    seed=123,
    out_path="tutorials/map_txt/random_60x60_ws.txt",
):
    """
    Create a HxW layout text file with random W/S/@/space
    respecting the requested densities.
    Lines are joined by ';' (Foundation expects this format).
    """
    assert 0 <= p_wood <= 1 and 0 <= p_stone <= 1 and 0 <= p_water <= 1
    assert p_wood + p_stone + p_water <= 1.0, "Densities sum must be <= 1"
    rng = np.random.RandomState(seed)

    mask = rng.rand(H, W)
    th_w = p_wood
    th_s = p_wood + p_stone
    th_a = th_s   + p_water

    chars = np.full((H, W), ' ', dtype='<U1')
    chars[mask < th_w] = 'W'
    chars[(mask >= th_w) & (mask < th_s)] = 'S'
    chars[(mask >= th_s) & (mask < th_a)] = '@'

    rows = [''.join(chars[r, :].tolist()) for r in range(H)]
    text = ';'.join(rows)

    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    with open(out_path, "w") as f:
        f.write(text)
    return out_path, text

# --- Generate the file ---
#path, _ = make_random_layout_file(
    # H=60, W=60,
    # p_wood=0.12,
    # p_stone=0.12,
    # p_water=0.00,
    # seed=42,
    # out_path="DRL-IN-INTERNATIONAL-ECONOMY-AI-ECONOMIST-/ai_economist/foundation/scenarios/simple_wood_and_stone/map_txt/random_60x60_ws.txt",
#)
#print("Wrote:", path)

# %% [markdown]
# ### Debugging

# %%
env_config = {
    'scenario_name': 'layout_from_file/simple_wood_and_stone',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 4,
    'world_size': [60, 60],
    'episode_length': 1000,

    'randomize_layout': True,
    'wood_density': 0.15,
    'stone_density': 0.12,
    'water_density': 0.02,   # if you want some lakes in plain layout
    'rng_seed': 7,

    'agent_start_locs': None,
    'fixed_four_skill_and_loc': False,
}

env.reset()
print([tuple(a.loc) for a in env.world.agents])  # should match agent_start_locs order

mW = env.world.maps.get("Wood")
mS = env.world.maps.get("Stone")
mA = env.world.maps.get("Water")
H, W = env.world_size
print("World:", H, W)
print("Wood density:", mW.sum() / (H*W))
print("Stone density:", mS.sum() / (H*W))
print("Water density:", mA.sum() / (H*W))

mA = env.world.maps.get("Water")
print("Unique rows with water:", np.unique(np.where(mA>0)[0]))
# Out:
# [(5, 5), (5, 20), (20, 5), (20, 20)]
# World: 25 25
# Wood density: 0.032
# Stone density: 0.032
# Water density: 0.0528
# Unique rows with water: [ 0  1  2  3  4  9 10 11 12 13 14 15 20 21 22 23 24]

# %% [markdown]
# # begining my multi-world adventures

# %%
def clear_vertical_water_stripes(src_path, dst_path, cols_to_clear):
    # reads a ; separated map file, clears '@' in those columns, writes to new file
    with open(src_path, 'r', encoding='utf-8') as f:
        text = f.read().rstrip(';')
    rows = text.split(';')
    H = len(rows)
    W = max(len(r) for r in rows)
    rows = [r + ' '*(W - len(r)) for r in rows]
    arr = [list(r) for r in rows]
    for r in range(H):
        for c in cols_to_clear:
            if 0 <= c < W and arr[r][c] == '@':
                arr[r][c] = ' '
    rows_out = [''.join(arr[r]) for r in range(H)]
    with open(dst_path, 'w', encoding='utf-8') as f:
        f.write(';'.join(rows_out))

# # Example: clear column 25 if that’s your solid water column
# clear_vertical_water_stripes(
#     src_path='DRL-IN-INTERNATIONAL-ECONOMY-AI-ECONOMIST-/ai_economist/foundation/scenarios/simple_wood_and_stone/map_txt/multi_world_100x50.txt',
#     dst_path='DRL-IN-INTERNATIONAL-ECONOMY-AI-ECONOMIST-/ai_economist/foundation/scenarios/simple_wood_and_stone/map_txt/multi_world_100x50_noV.txt',
#     cols_to_clear=[25]
# )

# %% [markdown]
# I still need to deal with waterlines not showing up in splitwold - this is just changing the code

# %% [markdown]
# Height × Width = 100 × 50
# Wood tiles ≈ 168
# Stone tiles ≈ 160
# Water tiles ≈ 344

# %%
from ai_economist import foundation
import random

starting_loc= [(random.randint(1, 100), random.randint(1, 50)) for _ in range(20)]

env_config = {
    'scenario_name': 'split_layout/simple_wood_and_stone',  # or layout_from_file/...
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 20,
    'world_size': [100, 50],                 # must match the file
    'env_layout_file': 'multi_world_100x50.txt',
    'episode_length': 1000,
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    'flatten_observations': False,
    'flatten_masks': True,
    'starting_agent_coin': 10,
    'dense_log_frequency': 1,                # optional but handy for debugging
    'agent_start_locs': starting_loc,

}

env = foundation.make_env_instance(**env_config)
obs = env.reset(force_dense_logging=True)

play_random_episode(env, plot_every=100)

# %%
import random

num_players = 10

starting_loc= [(random.randint(1, 100-1), random.randint(1, 50-1)) for _ in range(num_players)]

env_config = {
    'scenario_name': 'custom/split_overlay_from_file',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': num_players,
    'world_size': [100, 50],
    'env_layout_file': 'multi_world_100x50.txt',

    # Preserve all file water; overlay only horizontal barrier at row 50
    'water_row': 50,
    'add_vertical_line': False,     # keep vertical line from the file itself

    # Put multiple top agents (e.g., top 2 skill ranks)
    'agent_start_locs': starting_loc,
    #'skill_rank_of_top_agents': [0, 2],


}
# 1) Confirm water preserved + overlay
WATER = env.world.maps.get("Water")
print("Water rows with any water:", np.unique(np.where(WATER > 0)[0])[:10], "...")

# 2) Confirm top-half placement by ranks
#    After reset, check agent y-coordinates vs chosen top ranks
top_ranks = [0,1]  # match what you set
agent_rows = [a.loc[0] for a in env.world.agents]
print("Rows:", agent_rows)  # expect 2 above water_row and 2 below

# 3) If using explicit starts, verify:
print([tuple(a.loc) for a in env.world.agents])

env = foundation.make_env_instance(**env_config)
#obs = env.reset(force_dense_logging=True)

play_random_episode(env, plot_every=100)

# %%
import random
from ai_economist import foundation
import numpy as np

H, W = 100, 50

# Avoid the horizontal waterline row 50, and stay inside the map.
def safe_random_start(H=100, W=50, avoid_rows={50}):
    while True:
        r = random.randrange(0, H)      # 0..H-1
        c = random.randrange(0, W)      # 0..W-1
        if r not in avoid_rows:
            return (r, c)

starting_loc = [safe_random_start(H, W, avoid_rows={50}) for _ in range(4)]

env_config = {
    'scenario_name': 'custom/split_overlay_from_file',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 4,
    'world_size': [H, W],
    'env_layout_file': 'multi_world_100x50.txt',

    # Overlay the split. Note:
    # - add_vertical_line=True overlays a *new* vertical line (it does NOT "keep from file").
    #   If your file already has a vertical line and you want to preserve it ONLY, set this to False.
    'water_row': 50,
    'add_vertical_line': True,

    # Custom starts
    'agent_start_locs': starting_loc,
}

env = foundation.make_env_instance(**env_config)
obs = env.reset(force_dense_logging=True)

# Now inspect *this* env, not an old 'env'
WATER = env.world.maps.get("Water")
print("Water rows with any water:", np.unique(np.where(WATER > 0)[0]))
print("Water cols with any water:", np.unique(np.where(WATER > 0)[1]))

print("Agent locs:", [tuple(a.loc) for a in env.world.agents])

# Run an episode
play_random_episode(env, plot_every=100)

# %%
from ai_economist import foundation
import numpy as np
import random

H, W = 100, 50

# Optional: pick safe custom starts (avoid row 50)
def safe_random_start(H, W, avoid_rows={50}):
    while True:
        r = random.randrange(0, H)
        c = random.randrange(0, W)
        if r not in avoid_rows:
            return (r, c)

starting_loc = [safe_random_start(H, W, avoid_rows={50}) for _ in range(4)]

env_config = {
    'scenario_name': 'custom/split_overlay_from_file',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 4,
    'world_size': [H, W],
    'env_layout_file': 'multi_world_100x50.txt',

    # Horizontal line with gaps only (no vertical line)
    'water_row': 50,
    'add_vertical_line': False,               # <- turn OFF
    'horizontal_gap_cols': [10, 25, 40],      # <- gaps at these columns
    'gap_width': 3,                           # <- each gap is 3 columns wide
    # or: 'random_gap_count': 3, 'random_gap_seed': 7,

    # (Optional) explicit custom starts
    'agent_start_locs': starting_loc,
}

env = foundation.make_env_instance(**env_config)
obs = env.reset(force_dense_logging=True)

# Verify there's *no* solid vertical wall
WATER = env.world.maps.get("Water")
print("Water rows:", np.unique(np.where(WATER > 0)[0])[:10], "...")
print("Water cols (should NOT be a solid column):",
      np.unique(np.where(WATER[:, :] > 0)[1])[:10], "...")

print("Agent locs:", [tuple(a.loc) for a in env.world.agents])

play_random_episode(env, plot_every=100)

# %%
from ai_economist import foundation
import random, numpy as np

H, W = 100, 50
def safe_random_start():
    while True:
        r = random.randrange(0, H)
        c = random.randrange(0, W)
        if r != 50:  # avoid horizontal split row
            return (r, c)

starting_loc = [safe_random_start() for _ in range(4)]

env_config = {
    'scenario_name': 'custom/split_overlay_from_file',
    'components': [
        ('Build', {'skill_dist': 'pareto', 'payment_max_skill_multiplier': 3}),
        ('ContinuousDoubleAuction', {'max_num_orders': 5}),
        ('Gather', {}),
    ],
    'n_agents': 4,
    'world_size': [H, W],
    'env_layout_file': 'multi_world_100x50.txt',

    # Horizontal split with gaps; NO vertical line:
    'water_row': 50,
    'add_vertical_line': False,             # ← NO vertical barrier
    'horizontal_gap_cols': [10, 25, 40],    # ← gap centers you want
    'gap_width': 3,                          # ← width of each gap in cols
    # or: 'random_gap_count': 3, 'random_gap_seed': 7,

    # Optional explicit starts:
    'agent_start_locs': starting_loc,
}

env = foundation.make_env_instance(**env_config)
obs = env.reset(force_dense_logging=True)

# Quick verify
WATER = env.world.maps.get("Water")
print("Water rows:", np.unique(np.where(WATER > 0)[0])[:10], "...")
print("Water cols (should NOT be a solid column):",
      np.unique(np.where(WATER > 0)[1])[:10], "...")
print("Agent locs:", [tuple(a.loc) for a in env.world.agents])

play_random_episode(env, plot_every=100)
